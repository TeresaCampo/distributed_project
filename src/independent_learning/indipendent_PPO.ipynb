# %%
import os, sys
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
sys.path.append(parent_dir)

# %% [markdown]
# ## Training with dense reward

# %%
# %load_ext autoreload
# %autoreload 2

from independent_learning.PPO.PPO import *
from myenv_5_dense_reward import MyGridWorld
# Out:
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %% [markdown]
# Train

# %%
GRID_SIZE = 15

model = PPOTrainer(grid_size=GRID_SIZE)
model.train()
# Out:
# --- Starting PPO Training (Grid 15 | Steps 100000) ---
# Using cpu device
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:78: UserWarning: The `render_mode` attribute is not defined in your environment. It will be set to None.
#   warnings.warn("The `render_mode` attribute is not defined in your environment. It will be set to None.")
# Logging to ./ppo_logs/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -32.4    |
# | time/              |          |
# |    fps             | 3095     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4096     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -28.7       |
# ...

# %% [markdown]
# Test

# %%
model.test()
# Out:
# ...
# PPO TEST PHASE
# Num testing episodes: 100
# ...
# Ep 1/100: Status=SUCCESS, Rew=196.2, Steps=11
# Ep 20/100: Status=SUCCESS, Rew=199.0, Steps=9
# Ep 40/100: Status=SUCCESS, Rew=198.7, Steps=12
# Ep 60/100: Status=SUCCESS, Rew=197.5, Steps=11
# Ep 80/100: Status=SUCCESS, Rew=197.5, Steps=11
# Ep 100/100: Status=SUCCESS, Rew=199.0, Steps=5
#
# ...
# TEST METRICS
# Success rate: 100.00%
# Avg reward: 197.56
# Avg steps: 9.12
# ...

# %% [markdown]
# ## Sparse reward

# %%
# %load_ext autoreload
# %autoreload 2

from myenv_5_sparse_reward import MyGridWorld
from independent_learning.PPO.PPO import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [autoreload of PPO failed: Traceback (most recent call last):
#   File "/home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     if not append_obj(module, old_objects, name, obj):
#   File "/home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 423, in append_obj
#     in_module = hasattr(obj, "__module__") and obj.__module__ == module.__name__
#   File "/home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/supersuit/__init__.py", line 65, in __getattr__
#     raise ImportError(f"cannot import name '{wrapper_name}' from 'supersuit'")
# ImportError: cannot import name '__module__' from 'supersuit'
# ]

# %%
GRID_SIZE = 15

model = PPOTrainer(grid_size=GRID_SIZE)
model.train()
# Out:
# --- Starting PPO Training (Grid 15 | Steps 100000) ---
# Using cpu device
# Logging to ./ppo_logs/PPO_2
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:78: UserWarning: The `render_mode` attribute is not defined in your environment. It will be set to None.
#   warnings.warn("The `render_mode` attribute is not defined in your environment. It will be set to None.")
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -34.3    |
# | time/              |          |
# |    fps             | 2799     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4096     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -30.6       |
# ...

# %%
model.test()
# Out:
# ...
# PPO TEST PHASE
# Num testing episodes: 100
# ...
# Ep 1/100: Status=SUCCESS, Rew=198.3, Steps=8
# Ep 20/100: Status=SUCCESS, Rew=199.5, Steps=7
# Ep 40/100: Status=SUCCESS, Rew=197.3, Steps=13
# Ep 60/100: Status=SUCCESS, Rew=196.4, Steps=12
# Ep 80/100: Status=SUCCESS, Rew=199.8, Steps=7
# Ep 100/100: Status=SUCCESS, Rew=199.8, Steps=3
#
# ...
# TEST METRICS
# Success rate: 100.00%
# Avg reward: 197.79
# Avg steps: 9.40
# ...
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
