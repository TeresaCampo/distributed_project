# %% [markdown]
# # **My custom env - dense reward**
#
# **Environment classe pasted here in order to make it accessible to all the workers of Ray.**
#
# It is equivalent to /myenv_6_dense_reward.py

# %%
under_examination = "looseplay_4agents_densereward"

# %%
import sys, os
from pathlib import Path

current_dir = Path(os.getcwd()) 
pointed_dir = current_dir

while True:
    if pointed_dir.is_dir() and "distributed_project" == str(pointed_dir).split("/")[-1]:
        project_dir = pointed_dir
        print(f"Project dir found: {project_dir}")
        break
    
    if pointed_dir == pointed_dir.parent:
        print("Error while looking for 'distributed_project', project dir")
        break
        
    pointed_dir = pointed_dir.parent
# Out:
# Project dir found: /home/terra/Desktop/unimore/distributed_project

# %%
import numpy as np
import functools
import gymnasium as gym
from gymnasium import spaces
from pettingzoo import ParallelEnv
import pygame 
import os
from collections import defaultdict
import random

SPRITES_DIR = f"{project_dir}/sprites"


class MyGridWorld(ParallelEnv):
    metadata = {"render_modes": ["human"], "name": "custom_grid_v0"}

    def __init__(self, render_mode=None, n_agents = 2, grid_size=15):
        if grid_size<8:
            print("Error, need to insert a grid size greater or equal to 8")
        self.grid_size = grid_size
        self.render_mode = render_mode

        ######## Agents, fixed components, and forbidden positions
        self.possible_agents = [f"agent{i}" for i in range(1, n_agents+1)]
        self.agents = self.possible_agents[:]
        self.gate_open = False

        self.fixed_components = {
            "button1":  {"pos": np.array([self.grid_size//2+2, 1+3+2]), "file": "button.png"},
            "button2":  {"pos": np.array([self.grid_size//2+2, 1+1]), "file": "button.png"},

            "gate_open":  {"pos": np.array([self.grid_size//2, 1+3]), "file": "gate_open.png"},
            "gate_close":  {"pos": np.array([self.grid_size//2, 1+3]), "file": "gate_close.png"}   
        }
        self.button1_pos = self.fixed_components["button1"]["pos"]
        self.button2_pos = self.fixed_components["button2"]["pos"]

        self.gate_pos = self.fixed_components["gate_open"]["pos"] 
        self.target_final_pos = self.gate_pos+[0, -1]

        self.x_range = (1, self.grid_size-1-1)
        self.y_range = (1+3+1, self.grid_size-1-1)
        self.forbidden_position = {tuple(self.button1_pos)}    

        self.max_cycles = 100
        self.current_cycles = 0
        ######## Pygame graphic configuration 
        self.window_size = 810
        self.cell_size = self.window_size // self.grid_size
        self.window = None
        self.clock = None
        
        # Walls
        self.grid_map = np.zeros((self.grid_size, self.grid_size))
        self.grid_map[0, :] = 1
        self.grid_map[:, 0] = 1
        self.grid_map[-1, :] = 1
        self.grid_map[:, -1] = 1
        self.grid_map[ :, 1+3] = 1

        # Sprites 
        self.agent_sprites = {}
        self.component_sprites = {}

        ######## Action space and observation space
        # Five possible actions in each grid: stay(0), up(1), down(2), left(3), right(4)
        self.action_spaces = {a: spaces.Discrete(5) for a in self.possible_agents}
        OBSERVATION_DIM = 2*(len(self.agents)-1)+3*2+1
        self.observation_spaces = {
            a: spaces.Box(low=-(self.grid_size-1), high=self.grid_size-1, shape=(OBSERVATION_DIM,), dtype=np.float32) 
            for a in self.possible_agents
        }
        self.state_spaces = {a: None for a in self.possible_agents}

    def state(self):
        observations = self.gather_observations()
        global_state = []
        
        for agent in self.possible_agents:
            if agent in observations:
                global_state.append(observations[agent])
            else:
                # Se l'agente è morto/uscito, usa zeri
                dim = self.observation_spaces[agent].shape[0]
                global_state.append(np.zeros(dim, dtype=np.float32))
                
        return np.concatenate(global_state)

    # Boilerplate PettingZoo
    def observation_space(self, agent): return self.observation_spaces[agent]
    def action_space(self, agent): return self.action_spaces[agent]

    '''
    Step in the environment
    '''
    def step(self, actions):
        if not self.agents: return {}, {}, {}, {}, {}
        self.current_cycles += 1
        
        rewards = {a: 0 for a in self.agents}

        terminations = {a: False for a in self.agents}
        truncations = {a: False for a in self.agents}
        infos = {a: {"is_success":False} for a in self.agents}
        
        desired_positions = {}      
        button_pressed = False
        agents_desire_gate = []
        for agent, action in actions.items():
            current_pos = self.agent_positions[agent].copy()
            target_pos = current_pos.copy()

            if action == 1: target_pos[1] -= 1 
            elif action == 2: target_pos[1] += 1
            elif action == 3: target_pos[0] -= 1
            elif action == 4: target_pos[0] += 1

            # Monitor button, gate and walls
            is_wall = self.grid_map[target_pos[0], target_pos[1]] == 1
            is_gate = (target_pos == self.gate_pos).all()
            is_button = (target_pos == self.button1_pos).all() or (target_pos == self.button2_pos).all()
            
            if is_button:
                button_pressed = True
            if is_gate:
                agents_desire_gate.append((agent, current_pos))
            
            if is_wall and not is_gate:
                desired_positions[agent] = current_pos 
            else:
                desired_positions[agent] = target_pos
                        
        # If gate was open remove a wall, if gate was closed update the position of those who wanted to cross it
        self.gate_open = button_pressed
        if self.gate_open:
            self.grid_map[self.gate_pos[0], self.gate_pos[1]] = 0
        else:
            self.grid_map[self.gate_pos[0], self.gate_pos[1]] = 1
            for a in agents_desire_gate:
                agent = a[0]
                current_pos = a[1]
                desired_positions[agent] = current_pos 

        # Check for conflicts (more than one agents have the same desired position)
        final_positions = self.agent_positions.copy()
        target_counts = defaultdict(list)         # Key: tuple(x, y) of desired positions, Value: list of agents desiring it
        for agent, pos in desired_positions.items():
            pos_tuple = tuple(pos)
            target_counts[pos_tuple].append(agent)

        # Solve eventual conflicts
        for pos_tuple, agents_at_target in target_counts.items():      
            # Case 1: no contended position
            if len(agents_at_target) == 1:
                agent = agents_at_target[0]
                final_positions[agent] = desired_positions[agent]
            
            # Case 2: contended position
            else:
                one_agent_already_here_not_moving = None
                for agent in agents_at_target:
                    if tuple(self.agent_positions[agent]) == pos_tuple:
                        one_agent_already_here_not_moving = agent
                        break
                
                winning_agent = one_agent_already_here_not_moving if one_agent_already_here_not_moving else random.choice(agents_at_target)
                final_positions[winning_agent] = desired_positions[winning_agent]
                
                agents_at_target.remove(winning_agent)
                for losing_agent in agents_at_target[:]:
                    final_positions[losing_agent] = self.agent_positions[losing_agent] 
        self.agent_positions = final_positions

        # Negative reward if an agent is on the bottom area and is not pressing the button
        agents_upper_area = 0
        for a, pos in self.agent_positions.items():
            dist_target = np.linalg.norm(pos - self.target_final_pos)
            if pos[1]<4:                                # Agent on upper area
                rewards[a] = +0.5
                agents_upper_area+=1

                if (pos == self.button2_pos).all():
                    rewards[a] +=0.3
            else:
                rewards[a] -= (dist_target * 0.05)      # Agent on bottom area

                if (pos == self.button1_pos).all():     # Agent on button
                    rewards[a] += 0.3     
       
        if agents_upper_area == len(self.agents):
            rewards = {a: +100 for a in self.agents}
            terminations = {a: True for a in self.agents}
            infos = {a: {"is_success":True} for a in self.agents}

        if self.current_cycles >= self.max_cycles:
            truncations= {a: True for a in self.agents}
            
        
        if self.render_mode == "human":
            self.render()
            
        final_obs = self.gather_observations()
        self.agents = [a for a in self.agents if not terminations[a]]
        return final_obs, rewards, terminations, truncations, infos
   
    '''
    Determines initial condition of the simulation
    '''

    def generate_valid_position(self):
        while True:
            x = np.random.randint(self.x_range[0], self.x_range[1])
            y = np.random.randint(self.y_range[0], self.y_range[1])
            new_position = tuple((x, y))

            if new_position not in self.forbidden_position:
                return new_position
            
    def generate_set_initial_positions(self):
        set_initial_positions = set()
        while len(set_initial_positions)<len(self.possible_agents):
            new_pos = self.generate_valid_position()
            set_initial_positions.add(new_pos)
        return set_initial_positions
    
    def generate_test_values(self, agent_num):
        if agent_num==1:
            return[7, 9]
        else:
            return [9,13]

    def reset(self, seed=None, options=None):
        self.agents = self.possible_agents[:]
        set_initial_positions = list(self.generate_set_initial_positions())
        self.current_cycles = 0

        self.agent_positions = {}
        for i, agent_id in enumerate(self.agents):
            self.agent_positions[agent_id] = np.array(set_initial_positions[i])
        
        # To visualize the reset position if "human" mode on
        if self.render_mode == "human":
            self.render()         

        return self.gather_observations(), {a: {} for a in self.agents}
    
    '''
    Observation: [my_cur_pos, (other_cur) x number of other agents, button_pos, gate_pos, gate_open (1|0)]    '''
    def gather_observations(self):
        gate_status_info = np.array([int(self.gate_open)], dtype=np.float32)
        observations = {}
        for observing_agent in self.agents:
            obs_segments = []
            observing_agent_pos = self.agent_positions[observing_agent]
            
            for other_agent in self.agents:
                if other_agent != observing_agent:
                    obs_segments.append(self.agent_positions[other_agent] - observing_agent_pos)
            obs_segments.append(self.button1_pos- observing_agent_pos)
            obs_segments.append(self.button2_pos- observing_agent_pos)
            obs_segments.append(self.gate_pos -observing_agent_pos)
            obs_segments.append(gate_status_info)
            observations[observing_agent] = np.concatenate(obs_segments, dtype=np.float32)
        return observations

    '''
    Functions for Sprite rendering and loading
    '''    
    def _create_missing_sprite(self, text, bg_color, border_color = (0,0,0)):  
        error_sprite = pygame.Surface((self.cell_size, self.cell_size), pygame.SRCALPHA)
        error_sprite.fill((0, 0, 0, 0))
        center = (self.cell_size // 2, self.cell_size // 2)
        radius = int(self.cell_size * 0.4)
        pygame.draw.circle(error_sprite, bg_color, center, radius) 
        pygame.draw.circle(error_sprite, border_color, center, radius, 2)
        
        # Add text label
        try:
            font_size = int(self.cell_size * 0.22)
            font = pygame.font.Font(None, font_size)   
            text_color = (0, 0, 0) if sum(bg_color) > 300 else (255, 255, 255) 
            text_surface = font.render(text, True, text_color)
            text_rect = text_surface.get_rect(center=center)
            error_sprite.blit(text_surface, text_rect)
            
        except Exception as e:
            print(f"WARNING: Error while writing text inside missing sprite {text}. A missing sprite without text label will be used for this simulation.")
            pass
            
        return error_sprite
    
    def _load_and_scale_sprite(self, filename, component_name):
        path = os.path.join(SPRITES_DIR, filename)
    
        try:
            image = pygame.image.load(path).convert_alpha() 
            scaled_size = int(self.cell_size )
            return pygame.transform.scale(image, (scaled_size, scaled_size))
            
        except (FileNotFoundError, pygame.error) as e:
            print(f"WARNING! Sprite image {path} not found. Using default sprite for this simulation.")
    
            text = component_name.upper() if component_name else "ERROR"
            bg_color = (100, 100, 255) if "AGENT" in text else (128,128,128) # Blue agent, Gray fixed components
            return self._create_missing_sprite(text, bg_color)

    def render(self):
        if self.render_mode is None:
            return

        if self.window is None:
            pygame.init()
            pygame.display.init()
            pygame.font.init()
            self.window = pygame.display.set_mode((self.window_size, self.window_size))
            
            for agent_name in self.agents:
               # self.agent_sprites[agent_name] = self._load_and_scale_sprite(f"{agent_name}.png", agent_name)
               self.agent_sprites[agent_name] = self._load_and_scale_sprite(".png", agent_name)

            for name, data in self.fixed_components.items():
                self.component_sprites[name] = self._load_and_scale_sprite(data["file"], name)

                 
        if self.clock is None:
            self.clock = pygame.time.Clock()

        canvas = pygame.Surface((self.window_size, self.window_size))
        canvas.fill((220, 220, 220)) 
        pix_square_size = self.cell_size 
        sprite_offset = (pix_square_size - int(pix_square_size * 0.8)) // 2

        # Render walls
        for x in range(self.grid_size):
            for y in range(self.grid_size):
                if self.grid_map[x, y] == 1:
                    pygame.draw.rect(
                        canvas, 
                        (50, 50, 50),
                        pygame.Rect(x * pix_square_size, y * pix_square_size, pix_square_size, pix_square_size)
                    )

        # Render fixed components and agents
        for name, data in self.fixed_components.items():
            if self.gate_open and name == "gate_close":
                continue
            pos = data["pos"]
            x_coord = pos[0] * pix_square_size + sprite_offset
            y_coord = pos[1] * pix_square_size + sprite_offset
            sprite = self.component_sprites[name]
            canvas.blit(sprite, (x_coord, y_coord))

        for agent in self.agents:
            pos = self.agent_positions[agent]            
            x_coord = pos[0] * pix_square_size + sprite_offset
            y_coord = pos[1] * pix_square_size + sprite_offset
            
            sprite = self.agent_sprites[agent]
            canvas.blit(sprite, (x_coord, y_coord))

        # Render the grid
        for x in range(self.grid_size + 1):
            pygame.draw.line(
                canvas, 0, (0, pix_square_size * x), (self.window_size, pix_square_size * x), width=2
            )
            pygame.draw.line(
                canvas, 0, (pix_square_size * x, 0), (pix_square_size * x, self.window_size), width=2
            )

        # Display the render
        self.window.blit(canvas, canvas.get_rect())
        pygame.event.pump()
        pygame.display.update()
        self.clock.tick(4) # FPS

    def close(self):
        if self.window is not None:
            pygame.display.quit()
            pygame.quit()
# Out:
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %% [markdown]
# **Wrap the envornment in a PettingZoo env (for compatibility with Ray) and register it on Ray lib**

# %%
from ray.rllib.env.wrappers.pettingzoo_env import ParallelPettingZooEnv
from ray.tune.registry import register_env

def env_creator(config):
    return ParallelPettingZooEnv(
        MyGridWorld(render_mode=None, n_agents=4)
    )

register_env("my_gridworld", env_creator)

# %% [markdown]
# ## **IPPO - loose play settings**

# %% [markdown]
# Callback to register episode success rate

# %%
from ray.rllib.algorithms.callbacks import DefaultCallbacks

class SuccessMetricCallback(DefaultCallbacks):
    def on_episode_end(self, *, worker, base_env, policies, episode, **kwargs):
        
        is_success = False
        one_agent_id = list(episode.get_agents())[-1]
        last_info = episode.last_info_for(one_agent_id)
        is_success = last_info["is_success"]
       
        episode.custom_metrics["success_rate"] = int(is_success)

# %%
from ray.rllib.algorithms.ppo import PPOConfig

dummy_env = env_creator({}) 
agent_ids = dummy_env.possible_agents 
print(f"Agents in the env: {agent_ids}")
dummy_env.close()

config = (
    PPOConfig()
    .environment(env="my_gridworld")
    .env_runners(num_env_runners=0)
    .callbacks(callbacks_class=SuccessMetricCallback)
    
    .multi_agent(
        policies=set(agent_ids),
        policy_mapping_fn=lambda agent_id, *args, **kwargs: agent_id,
    )
    
    .api_stack(
        enable_rl_module_and_learner=False,
        enable_env_runner_and_connector_v2=False
    )
    .evaluation(
        evaluation_interval=1,
        evaluation_duration=10,
        evaluation_duration_unit="episodes",
        evaluation_num_env_runners=1,
        evaluation_config={
            "explore": True,
        }
    )
    .training(
        lr=1e-4,
        train_batch_size_per_learner=4000, 
        num_epochs=10,        
        entropy_coeff=0.01,
        kl_coeff=0.2,
        kl_target=0.01
    )
)
# Out:
# Agents in the env: ['agent2', 'agent3', 'agent4', 'agent1']

# %% [markdown]
# ## **Wandb - One run of training**

# %%
import wandb
#wandb.init(project="gridworld_looseplay_2agents", name="densereward")
ppo = config.build_algo()
num_total_episodes = 0
for i in range(50):
    result = ppo.train()
    num_total_episodes += result['env_runners']['num_episodes']
    
    print(f"ITERATION {i}, num episode {num_total_episodes}".center(100,"-"))
    train_rew = round(result['env_runners']['episode_return_mean'], 2)
    train_steps_episode = round(result['env_runners']['episode_len_mean'], 2)
    train_success_rate = round(result['env_runners']['custom_metrics'].get('success_rate_mean', 0), 2) * 100
    print(f"""TRAINING\nRew:{train_rew} \nSteps per episode:{train_steps_episode} \nSuccess rate:{train_success_rate}%\n""")

    if 'evaluation' in result:
        testing_rew = round(result['evaluation']['env_runners']['episode_return_mean'], 2)
        testing_steps_episode = round(result['evaluation']['env_runners']['episode_len_mean'], 2)
        testing_success_rate = round(result['evaluation']['env_runners']['custom_metrics'].get('success_rate_mean', 0), 2) * 100
        print(f"""TESTING\nRew:{testing_rew} \nSteps per episode:{testing_steps_episode} \nSuccess rate:{testing_success_rate}%\n\n""")

    log_data = {
        "Episodes": num_total_episodes,

        "Training_steps_per_episode": train_steps_episode,
        "Training_success_rate_per_episode": train_success_rate,
        "Training_reward_per_episode": train_rew,

        "Testing_steps_per_episode": testing_steps_episode,
        "Testing_success_rate_per_episode": testing_success_rate,
        "Testing_reward_per_episode": testing_rew
    }
    #wandb.log(log_data)
#wandb.finish()

# %% [markdown]
# ## **Wandb, 3 runs of training to generate esteme**

# %%
import wandb
group_name = "dense"

for run_idx in range(1,4):
    print(f"\n{'='*40}")
    print(f"RUN NUMBER {run_idx}/3")
    print(f"{'='*40}\n")

    ppo = config.build_algo()
    wandb.init(
        project="gridworld_looseplay_4agents",
        group=group_name,           
        name=f"run_{run_idx}",    
        reinit=True 
    )
    file_name = f"{under_examination}_run_{run_idx}"
    
    num_total_episodes = 0
    for i in range(50):
        result = ppo.train()
        num_total_episodes += result['env_runners']['num_episodes']
        
        print(f"ITERATION {i}, num episode {num_total_episodes}".center(100,"-"))
        train_rew = round(result['env_runners']['episode_return_mean'], 2)
        train_steps_episode = round(result['env_runners']['episode_len_mean'], 2)
        train_success_rate = round(result['env_runners']['custom_metrics'].get('success_rate_mean', 0), 2) * 100
        print(f"""TRAINING\nRew:{train_rew} \nSteps per episode:{train_steps_episode} \nSuccess rate:{train_success_rate}%\n""")

        if 'evaluation' in result:
            testing_rew = round(result['evaluation']['env_runners']['episode_return_mean'], 2)
            testing_steps_episode = round(result['evaluation']['env_runners']['episode_len_mean'], 2)
            testing_success_rate = round(result['evaluation']['env_runners']['custom_metrics'].get('success_rate_mean', 0), 2) * 100
            print(f"""TESTING\nRew:{testing_rew} \nSteps per episode:{testing_steps_episode} \nSuccess rate:{testing_success_rate}%\n\n""")

        log_data = {
            "Episodes": num_total_episodes,

            "Training_steps_per_episode": train_steps_episode,
            "Training_success_rate_per_episode": train_success_rate,
            "Training_reward_per_episode": train_rew,

            "Testing_steps_per_episode": testing_steps_episode,
            "Testing_success_rate_per_episode": testing_success_rate,
            "Testing_reward_per_episode": testing_rew
        }
        wandb.log(log_data)
    save_model(ppo, file_name)
    wandb.finish()

print("FINISHED")
# Out:
# ========================================
# RUN NUMBER 1/3
# ========================================
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:527: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/google/api_core/_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2025-12-28 11:25:54,314	INFO worker.py:2007 -- Started a local Ray instance.
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/_private/worker.py:2046: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# [2025-12-28 11:25:56,241 E 3151941 3151941] core_worker.cc:2223: Actor with class name: 'RolloutWorker' and ID: 'd28489231f025939df46259401000000' has constructor arguments in the object store and max_restarts > 0. If the arguments in the object store go out of scope or are lost, the actor restart will fail. See https://github.com/ray-project/ray/issues/53727 for more details.
# (RolloutWorker pid=3152253) /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (RolloutWorker pid=3152253)   from pkg_resources import resource_stream, resource_exists
# 2025-12-28 11:25:59,347	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: 299011 (299011-unimore). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.17.9
# Run data is saved locally in <code>/home/terra/Desktop/unimore/distributed_project/src/policies/PPO/wandb/run-20251228_112600-atusvx6v</code>
# Syncing run <strong><a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/atusvx6v' target="_blank">run_1</a></strong> to <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_4agents</a>
#  View run at <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/atusvx6v' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/atusvx6v</a>
# 2025-12-28 11:26:21,644	WARNING sgd.py:55 -- DeprecationWarning: `_get_slice_indices` has been deprecated. This will raise an error in the future!
# (pid=gcs_server) [2025-12-28 11:26:23,527 E 3152081 3152081] (gcs_server) gcs_server.cc:303: Failed to establish connection to the event+metrics exporter agent. Events and metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (raylet) [2025-12-28 11:26:24,246 E 3152196 3152196] (raylet) main.cc:1032: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (RolloutWorker pid=3152253) [2025-12-28 11:26:24,960 E 3152253 3152368] core_worker_process.cc:842: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# [2025-12-28 11:26:25,171 E 3151941 3152249] core_worker_process.cc:842: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# ------------------------------------ITERATION 0, num episode 40-------------------------------------
# TRAINING
# Rew:-139.83
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-87.94
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 1, num episode 80-------------------------------------
# TRAINING
# Rew:-119.91
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-68.77
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 2, num episode 120------------------------------------
# TRAINING
# Rew:-93.09
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-41.4
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 3, num episode 160------------------------------------
# TRAINING
# Rew:-56.59
# Steps per episode:100.0
# Success rate:1.0%
#
# TESTING
# Rew:-30.49
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 4, num episode 200------------------------------------
# TRAINING
# Rew:-38.07
# Steps per episode:100.0
# Success rate:1.0%
#
# TESTING
# Rew:75.21
# Steps per episode:91.11
# Success rate:22.0%
#
#
# ------------------------------------ITERATION 5, num episode 240------------------------------------
# TRAINING
# Rew:-13.92
# Steps per episode:99.9
# Success rate:3.0%
#
# TESTING
# Rew:40.83
# Steps per episode:99.33
# Success rate:11.0%
#
#
# ------------------------------------ITERATION 6, num episode 280------------------------------------
# TRAINING
# Rew:3.97
# Steps per episode:99.6
# Success rate:5.0%
#
# TESTING
# Rew:22.98
# Steps per episode:98.67
# Success rate:11.0%
#
#
# ------------------------------------ITERATION 7, num episode 321------------------------------------
# TRAINING
# Rew:20.74
# Steps per episode:98.79
# Success rate:7.000000000000001%
#
# TESTING
# Rew:132.22
# Steps per episode:92.78
# Success rate:33.0%
#
#
# ------------------------------------ITERATION 8, num episode 362------------------------------------
# TRAINING
# Rew:35.48
# Steps per episode:97.94
# Success rate:10.0%
#
# TESTING
# Rew:131.05
# Steps per episode:93.33
# Success rate:33.0%
#
#
# ------------------------------------ITERATION 9, num episode 404------------------------------------
# TRAINING
# Rew:58.04
# Steps per episode:96.62
# Success rate:14.000000000000002%
#
# TESTING
# Rew:159.28
# Steps per episode:81.56
# Success rate:44.0%
#
#
# -----------------------------------ITERATION 10, num episode 448------------------------------------
# TRAINING
# Rew:115.06
# Steps per episode:93.78
# Success rate:27.0%
#
# TESTING
# Rew:191.8
# Steps per episode:97.0
# Success rate:44.0%
#
#
# -----------------------------------ITERATION 11, num episode 495------------------------------------
# TRAINING
# Rew:192.46
# Steps per episode:88.87
# Success rate:46.0%
#
# TESTING
# Rew:101.18
# Steps per episode:93.0
# Success rate:22.0%
#
#
# -----------------------------------ITERATION 12, num episode 544------------------------------------
# TRAINING
# Rew:268.96
# Steps per episode:83.2
# Success rate:64.0%
#
# TESTING
# Rew:274.73
# Steps per episode:71.44
# Success rate:67.0%
#
#
# -----------------------------------ITERATION 13, num episode 591------------------------------------
# TRAINING
# Rew:271.0
# Steps per episode:82.99
# Success rate:65.0%
#
# TESTING
# Rew:363.78
# Steps per episode:64.33
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 14, num episode 647------------------------------------
# TRAINING
# Rew:291.66
# Steps per episode:78.04
# Success rate:71.0%
#
# TESTING
# Rew:395.29
# Steps per episode:62.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 15, num episode 706------------------------------------
# TRAINING
# Rew:374.17
# Steps per episode:70.02
# Success rate:90.0%
#
# TESTING
# Rew:370.78
# Steps per episode:68.0
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 16, num episode 762------------------------------------
# TRAINING
# Rew:371.84
# Steps per episode:70.14
# Success rate:90.0%
#
# TESTING
# Rew:415.22
# Steps per episode:57.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 17, num episode 830------------------------------------
# TRAINING
# Rew:373.91
# Steps per episode:62.85
# Success rate:91.0%
#
# TESTING
# Rew:363.57
# Steps per episode:58.89
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 18, num episode 907------------------------------------
# TRAINING
# Rew:396.9
# Steps per episode:53.92
# Success rate:97.0%
#
# TESTING
# Rew:367.77
# Steps per episode:61.11
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 19, num episode 979------------------------------------
# TRAINING
# Rew:389.0
# Steps per episode:54.86
# Success rate:94.0%
#
# TESTING
# Rew:407.09
# Steps per episode:61.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 20, num episode 1052-----------------------------------
# TRAINING
# Rew:395.18
# Steps per episode:55.38
# Success rate:96.0%
#
# TESTING
# Rew:412.04
# Steps per episode:59.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 21, num episode 1130-----------------------------------
# TRAINING
# Rew:400.91
# Steps per episode:52.5
# Success rate:98.0%
#
# TESTING
# Rew:406.65
# Steps per episode:43.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 22, num episode 1213-----------------------------------
# TRAINING
# Rew:403.22
# Steps per episode:48.92
# Success rate:99.0%
#
# TESTING
# Rew:410.69
# Steps per episode:47.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 23, num episode 1295-----------------------------------
# TRAINING
# Rew:411.09
# Steps per episode:48.19
# Success rate:100.0%
#
# TESTING
# Rew:411.68
# Steps per episode:58.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 24, num episode 1387-----------------------------------
# TRAINING
# Rew:409.77
# Steps per episode:43.74
# Success rate:100.0%
#
# TESTING
# Rew:413.07
# Steps per episode:44.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 25, num episode 1481-----------------------------------
# TRAINING
# Rew:410.81
# Steps per episode:42.67
# Success rate:100.0%
#
# TESTING
# Rew:409.74
# Steps per episode:45.0
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 26, num episode 1580-----------------------------------
# TRAINING
# Rew:406.4
# Steps per episode:40.4
# Success rate:100.0%
#
# TESTING
# Rew:401.15
# Steps per episode:34.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 27, num episode 1676-----------------------------------
# TRAINING
# Rew:403.95
# Steps per episode:41.98
# Success rate:99.0%
#
# TESTING
# Rew:408.87
# Steps per episode:39.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 28, num episode 1784-----------------------------------
# TRAINING
# Rew:409.08
# Steps per episode:36.76
# Success rate:100.0%
#
# TESTING
# Rew:405.01
# Steps per episode:37.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 29, num episode 1884-----------------------------------
# TRAINING
# Rew:410.4
# Steps per episode:40.08
# Success rate:100.0%
#
# TESTING
# Rew:415.47
# Steps per episode:43.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 30, num episode 1987-----------------------------------
# TRAINING
# Rew:408.41
# Steps per episode:38.75
# Success rate:100.0%
#
# TESTING
# Rew:410.38
# Steps per episode:36.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 31, num episode 2095-----------------------------------
# TRAINING
# Rew:410.25
# Steps per episode:37.19
# Success rate:100.0%
#
# TESTING
# Rew:411.01
# Steps per episode:35.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 32, num episode 2206-----------------------------------
# TRAINING
# Rew:410.52
# Steps per episode:36.17
# Success rate:100.0%
#
# TESTING
# Rew:413.34
# Steps per episode:40.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 33, num episode 2314-----------------------------------
# TRAINING
# Rew:411.09
# Steps per episode:36.75
# Success rate:100.0%
#
# TESTING
# Rew:417.36
# Steps per episode:40.67
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 34, num episode 2421-----------------------------------
# TRAINING
# Rew:412.96
# Steps per episode:37.63
# Success rate:100.0%
#
# TESTING
# Rew:409.64
# Steps per episode:39.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 35, num episode 2516-----------------------------------
# TRAINING
# Rew:416.65
# Steps per episode:41.66
# Success rate:100.0%
#
# TESTING
# Rew:408.99
# Steps per episode:29.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 36, num episode 2620-----------------------------------
# TRAINING
# Rew:411.65
# Steps per episode:38.38
# Success rate:100.0%
#
# TESTING
# Rew:412.6
# Steps per episode:32.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 37, num episode 2735-----------------------------------
# TRAINING
# Rew:410.06
# Steps per episode:34.6
# Success rate:100.0%
#
# TESTING
# Rew:406.81
# Steps per episode:32.0
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 38, num episode 2853-----------------------------------
# TRAINING
# Rew:410.36
# Steps per episode:34.13
# Success rate:100.0%
#
# TESTING
# Rew:405.69
# Steps per episode:30.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 39, num episode 2974-----------------------------------
# TRAINING
# Rew:409.76
# Steps per episode:33.04
# Success rate:100.0%
#
# TESTING
# Rew:411.26
# Steps per episode:31.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 40, num episode 3094-----------------------------------
# TRAINING
# Rew:411.84
# Steps per episode:33.17
# Success rate:100.0%
#
# TESTING
# Rew:412.96
# Steps per episode:34.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 41, num episode 3226-----------------------------------
# TRAINING
# Rew:407.67
# Steps per episode:30.45
# Success rate:100.0%
#
# TESTING
# Rew:410.74
# Steps per episode:31.67
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 42, num episode 3364-----------------------------------
# TRAINING
# Rew:407.43
# Steps per episode:28.89
# Success rate:100.0%
#
# TESTING
# Rew:423.7
# Steps per episode:40.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 43, num episode 3486-----------------------------------
# TRAINING
# Rew:410.29
# Steps per episode:32.9
# Success rate:100.0%
#
# TESTING
# Rew:412.27
# Steps per episode:38.67
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 44, num episode 3610-----------------------------------
# TRAINING
# Rew:410.05
# Steps per episode:32.18
# Success rate:100.0%
#
# TESTING
# Rew:408.34
# Steps per episode:33.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 45, num episode 3738-----------------------------------
# TRAINING
# Rew:410.27
# Steps per episode:31.27
# Success rate:100.0%
#
# TESTING
# Rew:414.28
# Steps per episode:33.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 46, num episode 3860-----------------------------------
# TRAINING
# Rew:409.85
# Steps per episode:32.69
# Success rate:100.0%
#
# TESTING
# Rew:407.35
# Steps per episode:26.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 47, num episode 4000-----------------------------------
# TRAINING
# Rew:408.06
# Steps per episode:28.5
# Success rate:100.0%
#
# TESTING
# Rew:405.89
# Steps per episode:33.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 48, num episode 4142-----------------------------------
# TRAINING
# Rew:406.96
# Steps per episode:28.22
# Success rate:100.0%
#
# TESTING
# Rew:412.18
# Steps per episode:34.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 49, num episode 4273-----------------------------------
# TRAINING
# Rew:408.93
# Steps per episode:30.62
# Success rate:100.0%
#
# TESTING
# Rew:408.35
# Steps per episode:31.56
# Success rate:100.0%
#
#
# Model saved into /home/terra/Desktop/unimore/distributed_project/src/policies/PPO/models/looseplay_4agents_densereward_run_1
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇██</td></tr><tr><td>Testing_reward_per_episode</td><td>▁▁▂▂▃▃▄▄▅▄▆▇▇█▇▇████████████████████████</td></tr><tr><td>Testing_steps_per_episode</td><td>██████▇▇█▇▅▅▅▄▄▄▄▃▃▄▃▂▂▂▂▂▂▂▁▂▂▁▂▂▂▂▂▁▂▂</td></tr><tr><td>Testing_success_rate_per_episode</td><td>▁▁▁▁▂▂▃▃▄▃▆▇▇█▇▇████████████████████████</td></tr><tr><td>Training_reward_per_episode</td><td>▁▁▂▂▃▃▃▃▄▅▆▆▇▇▇█████████████████████████</td></tr><tr><td>Training_steps_per_episode</td><td>████████▇▇▆▆▅▅▄▃▄▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>Training_success_rate_per_episode</td><td>▁▁▁▁▁▁▁▂▃▄▅▆▇▇▇█████████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>4273</td></tr><tr><td>Testing_reward_per_episode</td><td>408.35</td></tr><tr><td>Testing_steps_per_episode</td><td>31.56</td></tr><tr><td>Testing_success_rate_per_episode</td><td>100.0</td></tr><tr><td>Training_reward_per_episode</td><td>408.93</td></tr><tr><td>Training_steps_per_episode</td><td>30.62</td></tr><tr><td>Training_success_rate_per_episode</td><td>100.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">run_1</strong> at: <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/atusvx6v' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/atusvx6v</a><br/> View project at: <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_4agents</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251228_112600-atusvx6v/logs</code>
# wandb version 0.23.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# ========================================
# RUN NUMBER 2/3
# ========================================
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:527: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# (RolloutWorker pid=3152251) /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (RolloutWorker pid=3152251)   from pkg_resources import resource_stream, resource_exists
# (pid=3152260) [2025-12-28 11:26:25,154 E 3152260 3152781] core_worker_process.cc:842: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14 [repeated 11x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# 2025-12-28 11:47:19,113	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Tracking run with wandb version 0.17.9
# Run data is saved locally in <code>/home/terra/Desktop/unimore/distributed_project/src/policies/PPO/wandb/run-20251228_114719-ttce3ads</code>
# Syncing run <strong><a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/ttce3ads' target="_blank">run_2</a></strong> to <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_4agents</a>
#  View run at <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/ttce3ads' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/ttce3ads</a>
# ------------------------------------ITERATION 0, num episode 40-------------------------------------
# TRAINING
# Rew:-139.72
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-102.36
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 1, num episode 80-------------------------------------
# TRAINING
# Rew:-122.77
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-67.72
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 2, num episode 120------------------------------------
# TRAINING
# Rew:-100.03
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-53.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 3, num episode 160------------------------------------
# TRAINING
# Rew:-68.84
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-42.7
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 4, num episode 200------------------------------------
# TRAINING
# Rew:-47.12
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:24.44
# Steps per episode:97.56
# Success rate:11.0%
#
#
# ------------------------------------ITERATION 5, num episode 240------------------------------------
# TRAINING
# Rew:-32.28
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-13.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 6, num episode 280------------------------------------
# TRAINING
# Rew:-16.93
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:84.63
# Steps per episode:98.33
# Success rate:22.0%
#
#
# ------------------------------------ITERATION 7, num episode 320------------------------------------
# TRAINING
# Rew:2.4
# Steps per episode:99.1
# Success rate:3.0%
#
# TESTING
# Rew:20.27
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 8, num episode 361------------------------------------
# TRAINING
# Rew:26.09
# Steps per episode:98.14
# Success rate:7.000000000000001%
#
# TESTING
# Rew:131.36
# Steps per episode:90.0
# Success rate:33.0%
#
#
# ------------------------------------ITERATION 9, num episode 402------------------------------------
# TRAINING
# Rew:37.52
# Steps per episode:98.08
# Success rate:8.0%
#
# TESTING
# Rew:-9.61
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 10, num episode 444------------------------------------
# TRAINING
# Rew:49.72
# Steps per episode:97.2
# Success rate:12.0%
#
# TESTING
# Rew:86.78
# Steps per episode:93.22
# Success rate:22.0%
#
#
# -----------------------------------ITERATION 11, num episode 487------------------------------------
# TRAINING
# Rew:77.93
# Steps per episode:94.61
# Success rate:19.0%
#
# TESTING
# Rew:187.2
# Steps per episode:81.56
# Success rate:44.0%
#
#
# -----------------------------------ITERATION 12, num episode 531------------------------------------
# TRAINING
# Rew:116.96
# Steps per episode:92.94
# Success rate:27.0%
#
# TESTING
# Rew:238.57
# Steps per episode:81.22
# Success rate:56.00000000000001%
#
#
# -----------------------------------ITERATION 13, num episode 576------------------------------------
# TRAINING
# Rew:158.7
# Steps per episode:91.38
# Success rate:36.0%
#
# TESTING
# Rew:285.14
# Steps per episode:87.89
# Success rate:67.0%
#
#
# -----------------------------------ITERATION 14, num episode 625------------------------------------
# TRAINING
# Rew:219.17
# Steps per episode:84.79
# Success rate:50.0%
#
# TESTING
# Rew:238.17
# Steps per episode:84.78
# Success rate:56.00000000000001%
#
#
# -----------------------------------ITERATION 15, num episode 676------------------------------------
# TRAINING
# Rew:237.31
# Steps per episode:80.18
# Success rate:54.0%
#
# TESTING
# Rew:287.53
# Steps per episode:74.22
# Success rate:67.0%
#
#
# -----------------------------------ITERATION 16, num episode 732------------------------------------
# TRAINING
# Rew:300.32
# Steps per episode:75.39
# Success rate:69.0%
#
# TESTING
# Rew:417.08
# Steps per episode:64.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 17, num episode 789------------------------------------
# TRAINING
# Rew:329.21
# Steps per episode:70.09
# Success rate:77.0%
#
# TESTING
# Rew:371.71
# Steps per episode:70.78
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 18, num episode 850------------------------------------
# TRAINING
# Rew:343.62
# Steps per episode:66.55
# Success rate:81.0%
#
# TESTING
# Rew:369.03
# Steps per episode:55.33
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 19, num episode 919------------------------------------
# TRAINING
# Rew:378.8
# Steps per episode:60.22
# Success rate:90.0%
#
# TESTING
# Rew:416.25
# Steps per episode:49.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 20, num episode 994------------------------------------
# TRAINING
# Rew:394.59
# Steps per episode:55.11
# Success rate:94.0%
#
# TESTING
# Rew:409.89
# Steps per episode:53.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 21, num episode 1071-----------------------------------
# TRAINING
# Rew:410.38
# Steps per episode:50.59
# Success rate:99.0%
#
# TESTING
# Rew:413.69
# Steps per episode:52.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 22, num episode 1149-----------------------------------
# TRAINING
# Rew:407.39
# Steps per episode:50.8
# Success rate:98.0%
#
# TESTING
# Rew:411.4
# Steps per episode:47.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 23, num episode 1237-----------------------------------
# TRAINING
# Rew:406.45
# Steps per episode:46.68
# Success rate:98.0%
#
# TESTING
# Rew:414.35
# Steps per episode:42.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 24, num episode 1324-----------------------------------
# TRAINING
# Rew:411.48
# Steps per episode:45.81
# Success rate:100.0%
#
# TESTING
# Rew:413.85
# Steps per episode:41.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 25, num episode 1409-----------------------------------
# TRAINING
# Rew:411.52
# Steps per episode:46.56
# Success rate:99.0%
#
# TESTING
# Rew:410.2
# Steps per episode:51.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 26, num episode 1500-----------------------------------
# TRAINING
# Rew:414.48
# Steps per episode:44.81
# Success rate:100.0%
#
# TESTING
# Rew:409.2
# Steps per episode:42.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 27, num episode 1590-----------------------------------
# TRAINING
# Rew:409.46
# Steps per episode:44.54
# Success rate:99.0%
#
# TESTING
# Rew:413.87
# Steps per episode:50.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 28, num episode 1690-----------------------------------
# TRAINING
# Rew:409.06
# Steps per episode:40.01
# Success rate:100.0%
#
# TESTING
# Rew:410.73
# Steps per episode:35.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 29, num episode 1792-----------------------------------
# TRAINING
# Rew:409.95
# Steps per episode:39.42
# Success rate:100.0%
#
# TESTING
# Rew:410.95
# Steps per episode:38.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 30, num episode 1898-----------------------------------
# TRAINING
# Rew:407.3
# Steps per episode:37.72
# Success rate:100.0%
#
# TESTING
# Rew:406.88
# Steps per episode:37.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 31, num episode 1993-----------------------------------
# TRAINING
# Rew:404.05
# Steps per episode:41.94
# Success rate:98.0%
#
# TESTING
# Rew:411.02
# Steps per episode:34.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 32, num episode 2095-----------------------------------
# TRAINING
# Rew:406.3
# Steps per episode:39.31
# Success rate:99.0%
#
# TESTING
# Rew:417.94
# Steps per episode:38.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 33, num episode 2198-----------------------------------
# TRAINING
# Rew:404.57
# Steps per episode:38.59
# Success rate:99.0%
#
# TESTING
# Rew:409.55
# Steps per episode:45.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 34, num episode 2317-----------------------------------
# TRAINING
# Rew:405.78
# Steps per episode:33.71
# Success rate:100.0%
#
# TESTING
# Rew:405.84
# Steps per episode:35.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 35, num episode 2431-----------------------------------
# TRAINING
# Rew:408.95
# Steps per episode:35.25
# Success rate:100.0%
#
# TESTING
# Rew:404.72
# Steps per episode:30.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 36, num episode 2556-----------------------------------
# TRAINING
# Rew:405.4
# Steps per episode:32.01
# Success rate:100.0%
#
# TESTING
# Rew:405.59
# Steps per episode:29.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 37, num episode 2685-----------------------------------
# TRAINING
# Rew:405.27
# Steps per episode:30.91
# Success rate:100.0%
#
# TESTING
# Rew:405.49
# Steps per episode:28.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 38, num episode 2820-----------------------------------
# TRAINING
# Rew:401.06
# Steps per episode:29.72
# Success rate:99.0%
#
# TESTING
# Rew:407.14
# Steps per episode:35.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 39, num episode 2953-----------------------------------
# TRAINING
# Rew:406.96
# Steps per episode:30.01
# Success rate:100.0%
#
# TESTING
# Rew:406.02
# Steps per episode:26.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 40, num episode 3088-----------------------------------
# TRAINING
# Rew:406.01
# Steps per episode:29.53
# Success rate:100.0%
#
# TESTING
# Rew:403.18
# Steps per episode:35.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 41, num episode 3229-----------------------------------
# TRAINING
# Rew:404.83
# Steps per episode:28.5
# Success rate:100.0%
#
# TESTING
# Rew:408.97
# Steps per episode:28.67
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 42, num episode 3364-----------------------------------
# TRAINING
# Rew:407.87
# Steps per episode:29.58
# Success rate:100.0%
#
# TESTING
# Rew:406.28
# Steps per episode:28.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 43, num episode 3510-----------------------------------
# TRAINING
# Rew:404.92
# Steps per episode:27.53
# Success rate:100.0%
#
# TESTING
# Rew:405.27
# Steps per episode:23.67
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 44, num episode 3662-----------------------------------
# TRAINING
# Rew:405.56
# Steps per episode:26.24
# Success rate:100.0%
#
# TESTING
# Rew:411.82
# Steps per episode:30.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 45, num episode 3793-----------------------------------
# TRAINING
# Rew:408.66
# Steps per episode:30.58
# Success rate:100.0%
#
# TESTING
# Rew:404.51
# Steps per episode:28.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 46, num episode 3934-----------------------------------
# TRAINING
# Rew:406.07
# Steps per episode:28.2
# Success rate:100.0%
#
# TESTING
# Rew:405.79
# Steps per episode:24.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 47, num episode 4083-----------------------------------
# TRAINING
# Rew:406.23
# Steps per episode:26.97
# Success rate:100.0%
#
# TESTING
# Rew:405.49
# Steps per episode:29.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 48, num episode 4234-----------------------------------
# TRAINING
# Rew:406.47
# Steps per episode:26.58
# Success rate:100.0%
#
# TESTING
# Rew:403.75
# Steps per episode:24.67
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 49, num episode 4382-----------------------------------
# TRAINING
# Rew:405.51
# Steps per episode:26.81
# Success rate:100.0%
#
# TESTING
# Rew:404.43
# Steps per episode:27.89
# Success rate:100.0%
#
#
# Model saved into /home/terra/Desktop/unimore/distributed_project/src/policies/PPO/models/looseplay_4agents_densereward_run_2
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>Testing_reward_per_episode</td><td>▁▁▂▂▂▄▃▄▄▅▆▆▆█▇▇████████████████████████</td></tr><tr><td>Testing_steps_per_episode</td><td>███████▇▇▆▆▇▆▅▅▄▄▄▃▃▄▃▃▂▂▂▂▃▂▁▁▂▂▁▁▁▁▁▂▁</td></tr><tr><td>Testing_success_rate_per_episode</td><td>▁▁▁▁▁▃▁▃▃▄▅▆▆█▇▇████████████████████████</td></tr><tr><td>Training_reward_per_episode</td><td>▁▁▂▂▂▃▃▃▃▄▄▅▆▇▇▇████████████████████████</td></tr><tr><td>Training_steps_per_episode</td><td>█████████▇▇▇▆▆▅▅▄▃▃▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Training_success_rate_per_episode</td><td>▁▁▁▁▁▁▁▁▂▂▃▄▅▆▆▇████████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>4382</td></tr><tr><td>Testing_reward_per_episode</td><td>404.43</td></tr><tr><td>Testing_steps_per_episode</td><td>27.89</td></tr><tr><td>Testing_success_rate_per_episode</td><td>100.0</td></tr><tr><td>Training_reward_per_episode</td><td>405.51</td></tr><tr><td>Training_steps_per_episode</td><td>26.81</td></tr><tr><td>Training_success_rate_per_episode</td><td>100.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">run_2</strong> at: <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/ttce3ads' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/ttce3ads</a><br/> View project at: <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_4agents</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251228_114719-ttce3ads/logs</code>
# wandb version 0.23.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# ========================================
# RUN NUMBER 3/3
# ========================================
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:527: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# (RolloutWorker pid=3152250) /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (RolloutWorker pid=3152250)   from pkg_resources import resource_stream, resource_exists
# 2025-12-28 12:08:36,172	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Tracking run with wandb version 0.17.9
# Run data is saved locally in <code>/home/terra/Desktop/unimore/distributed_project/src/policies/PPO/wandb/run-20251228_120836-vej79eel</code>
# Syncing run <strong><a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/vej79eel' target="_blank">run_3</a></strong> to <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_4agents</a>
#  View run at <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/vej79eel' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/vej79eel</a>
# ------------------------------------ITERATION 0, num episode 40-------------------------------------
# TRAINING
# Rew:-143.65
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-107.12
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 1, num episode 80-------------------------------------
# TRAINING
# Rew:-122.89
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-80.45
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 2, num episode 120------------------------------------
# TRAINING
# Rew:-100.07
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-61.29
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 3, num episode 160------------------------------------
# TRAINING
# Rew:-66.38
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-30.69
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 4, num episode 200------------------------------------
# TRAINING
# Rew:-41.65
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:28.14
# Steps per episode:99.78
# Success rate:11.0%
#
#
# ------------------------------------ITERATION 5, num episode 240------------------------------------
# TRAINING
# Rew:-26.16
# Steps per episode:99.76
# Success rate:1.0%
#
# TESTING
# Rew:-27.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 6, num episode 280------------------------------------
# TRAINING
# Rew:-16.32
# Steps per episode:99.4
# Success rate:2.0%
#
# TESTING
# Rew:58.05
# Steps per episode:93.78
# Success rate:11.0%
#
#
# ------------------------------------ITERATION 7, num episode 321------------------------------------
# TRAINING
# Rew:23.36
# Steps per episode:98.76
# Success rate:9.0%
#
# TESTING
# Rew:137.97
# Steps per episode:97.33
# Success rate:33.0%
#
#
# ------------------------------------ITERATION 8, num episode 363------------------------------------
# TRAINING
# Rew:37.59
# Steps per episode:97.54
# Success rate:12.0%
#
# TESTING
# Rew:0.92
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 9, num episode 405------------------------------------
# TRAINING
# Rew:76.72
# Steps per episode:95.7
# Success rate:19.0%
#
# TESTING
# Rew:247.35
# Steps per episode:86.33
# Success rate:56.00000000000001%
#
#
# -----------------------------------ITERATION 10, num episode 449------------------------------------
# TRAINING
# Rew:149.2
# Steps per episode:93.43
# Success rate:34.0%
#
# TESTING
# Rew:243.14
# Steps per episode:87.33
# Success rate:56.00000000000001%
#
#
# -----------------------------------ITERATION 11, num episode 496------------------------------------
# TRAINING
# Rew:217.05
# Steps per episode:87.84
# Success rate:49.0%
#
# TESTING
# Rew:142.67
# Steps per episode:87.0
# Success rate:33.0%
#
#
# -----------------------------------ITERATION 12, num episode 544------------------------------------
# TRAINING
# Rew:271.21
# Steps per episode:84.66
# Success rate:62.0%
#
# TESTING
# Rew:376.28
# Steps per episode:66.78
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 13, num episode 594------------------------------------
# TRAINING
# Rew:306.93
# Steps per episode:82.19
# Success rate:71.0%
#
# TESTING
# Rew:430.53
# Steps per episode:68.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 14, num episode 652------------------------------------
# TRAINING
# Rew:357.0
# Steps per episode:73.25
# Success rate:84.0%
#
# TESTING
# Rew:366.9
# Steps per episode:63.33
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 15, num episode 718------------------------------------
# TRAINING
# Rew:387.43
# Steps per episode:62.85
# Success rate:93.0%
#
# TESTING
# Rew:412.57
# Steps per episode:53.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 16, num episode 789------------------------------------
# TRAINING
# Rew:399.06
# Steps per episode:56.8
# Success rate:96.0%
#
# TESTING
# Rew:413.29
# Steps per episode:59.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 17, num episode 864------------------------------------
# TRAINING
# Rew:403.72
# Steps per episode:53.14
# Success rate:97.0%
#
# TESTING
# Rew:382.58
# Steps per episode:63.78
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 18, num episode 940------------------------------------
# TRAINING
# Rew:398.72
# Steps per episode:53.86
# Success rate:96.0%
#
# TESTING
# Rew:417.74
# Steps per episode:48.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 19, num episode 1028-----------------------------------
# TRAINING
# Rew:403.34
# Steps per episode:46.1
# Success rate:98.0%
#
# TESTING
# Rew:409.27
# Steps per episode:46.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 20, num episode 1115-----------------------------------
# TRAINING
# Rew:412.89
# Steps per episode:45.93
# Success rate:100.0%
#
# TESTING
# Rew:409.1
# Steps per episode:41.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 21, num episode 1217-----------------------------------
# TRAINING
# Rew:409.57
# Steps per episode:39.27
# Success rate:100.0%
#
# TESTING
# Rew:404.54
# Steps per episode:38.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 22, num episode 1315-----------------------------------
# TRAINING
# Rew:408.94
# Steps per episode:41.03
# Success rate:100.0%
#
# TESTING
# Rew:411.27
# Steps per episode:42.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 23, num episode 1413-----------------------------------
# TRAINING
# Rew:407.0
# Steps per episode:40.72
# Success rate:100.0%
#
# TESTING
# Rew:402.52
# Steps per episode:29.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 24, num episode 1523-----------------------------------
# TRAINING
# Rew:408.03
# Steps per episode:36.59
# Success rate:100.0%
#
# TESTING
# Rew:404.67
# Steps per episode:41.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 25, num episode 1635-----------------------------------
# TRAINING
# Rew:406.47
# Steps per episode:35.5
# Success rate:100.0%
#
# TESTING
# Rew:404.7
# Steps per episode:30.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 26, num episode 1747-----------------------------------
# TRAINING
# Rew:405.0
# Steps per episode:35.81
# Success rate:99.0%
#
# TESTING
# Rew:409.92
# Steps per episode:40.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 27, num episode 1861-----------------------------------
# TRAINING
# Rew:408.24
# Steps per episode:35.11
# Success rate:100.0%
#
# TESTING
# Rew:406.25
# Steps per episode:35.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 28, num episode 1977-----------------------------------
# TRAINING
# Rew:407.25
# Steps per episode:34.32
# Success rate:100.0%
#
# TESTING
# Rew:407.38
# Steps per episode:31.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 29, num episode 2097-----------------------------------
# TRAINING
# Rew:409.28
# Steps per episode:33.5
# Success rate:100.0%
#
# TESTING
# Rew:404.5
# Steps per episode:28.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 30, num episode 2211-----------------------------------
# TRAINING
# Rew:411.32
# Steps per episode:35.14
# Success rate:100.0%
#
# TESTING
# Rew:410.5
# Steps per episode:34.0
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 31, num episode 2326-----------------------------------
# TRAINING
# Rew:410.58
# Steps per episode:34.87
# Success rate:100.0%
#
# TESTING
# Rew:404.67
# Steps per episode:30.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 32, num episode 2452-----------------------------------
# TRAINING
# Rew:407.85
# Steps per episode:31.76
# Success rate:100.0%
#
# TESTING
# Rew:407.99
# Steps per episode:36.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 33, num episode 2574-----------------------------------
# TRAINING
# Rew:408.44
# Steps per episode:32.59
# Success rate:100.0%
#
# TESTING
# Rew:406.03
# Steps per episode:30.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 34, num episode 2707-----------------------------------
# TRAINING
# Rew:406.97
# Steps per episode:30.2
# Success rate:100.0%
#
# TESTING
# Rew:414.5
# Steps per episode:34.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 35, num episode 2834-----------------------------------
# TRAINING
# Rew:404.57
# Steps per episode:31.51
# Success rate:99.0%
#
# TESTING
# Rew:407.56
# Steps per episode:28.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 36, num episode 2963-----------------------------------
# TRAINING
# Rew:407.47
# Steps per episode:31.05
# Success rate:100.0%
#
# TESTING
# Rew:405.69
# Steps per episode:34.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 37, num episode 3081-----------------------------------
# TRAINING
# Rew:409.15
# Steps per episode:33.63
# Success rate:100.0%
#
# TESTING
# Rew:406.87
# Steps per episode:29.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 38, num episode 3209-----------------------------------
# TRAINING
# Rew:406.61
# Steps per episode:31.32
# Success rate:100.0%
#
# TESTING
# Rew:411.57
# Steps per episode:36.67
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 39, num episode 3335-----------------------------------
# TRAINING
# Rew:408.35
# Steps per episode:31.73
# Success rate:100.0%
#
# TESTING
# Rew:406.75
# Steps per episode:29.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 40, num episode 3462-----------------------------------
# TRAINING
# Rew:408.16
# Steps per episode:31.57
# Success rate:100.0%
#
# TESTING
# Rew:406.0
# Steps per episode:32.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 41, num episode 3566-----------------------------------
# TRAINING
# Rew:413.94
# Steps per episode:38.28
# Success rate:100.0%
#
# TESTING
# Rew:407.26
# Steps per episode:31.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 42, num episode 3693-----------------------------------
# TRAINING
# Rew:407.15
# Steps per episode:31.52
# Success rate:100.0%
#
# TESTING
# Rew:406.05
# Steps per episode:31.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 43, num episode 3808-----------------------------------
# TRAINING
# Rew:412.37
# Steps per episode:34.95
# Success rate:100.0%
#
# TESTING
# Rew:417.39
# Steps per episode:36.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 44, num episode 3948-----------------------------------
# TRAINING
# Rew:406.29
# Steps per episode:28.51
# Success rate:100.0%
#
# TESTING
# Rew:407.62
# Steps per episode:27.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 45, num episode 4091-----------------------------------
# TRAINING
# Rew:403.6
# Steps per episode:28.06
# Success rate:99.0%
#
# TESTING
# Rew:407.47
# Steps per episode:30.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 46, num episode 4234-----------------------------------
# TRAINING
# Rew:405.07
# Steps per episode:27.92
# Success rate:100.0%
#
# TESTING
# Rew:407.35
# Steps per episode:27.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 47, num episode 4378-----------------------------------
# TRAINING
# Rew:402.94
# Steps per episode:27.86
# Success rate:99.0%
#
# TESTING
# Rew:406.47
# Steps per episode:32.67
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 48, num episode 4514-----------------------------------
# TRAINING
# Rew:404.76
# Steps per episode:29.29
# Success rate:100.0%
#
# TESTING
# Rew:409.2
# Steps per episode:30.0
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 49, num episode 4653-----------------------------------
# TRAINING
# Rew:405.12
# Steps per episode:28.86
# Success rate:100.0%
#
# TESTING
# Rew:409.9
# Steps per episode:31.11
# Success rate:100.0%
#
#
# Model saved into /home/terra/Desktop/unimore/distributed_project/src/policies/PPO/models/looseplay_4agents_densereward_run_3
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>Testing_reward_per_episode</td><td>▁▁▂▂▂▃▄▂▆▄▇███▇█████████████████████████</td></tr><tr><td>Testing_steps_per_episode</td><td>█████▇██▇▇▅▅▄▄▄▃▂▂▂▁▁▂▂▁▂▁▂▁▁▂▁▂▂▁▁▂▁▁▁▁</td></tr><tr><td>Testing_success_rate_per_episode</td><td>▁▁▁▁▁▂▃▁▅▃▇███▇█████████████████████████</td></tr><tr><td>Training_reward_per_episode</td><td>▁▁▂▂▂▃▃▃▅▆▆▇████████████████████████████</td></tr><tr><td>Training_steps_per_episode</td><td>████████▇▇▇▆▄▄▃▄▃▂▂▂▂▂▂▂▂▂▁▁▁▁▂▁▁▂▁▂▁▁▁▁</td></tr><tr><td>Training_success_rate_per_episode</td><td>▁▁▁▁▁▁▂▂▃▄▅▆████████████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>4653</td></tr><tr><td>Testing_reward_per_episode</td><td>409.9</td></tr><tr><td>Testing_steps_per_episode</td><td>31.11</td></tr><tr><td>Testing_success_rate_per_episode</td><td>100.0</td></tr><tr><td>Training_reward_per_episode</td><td>405.12</td></tr><tr><td>Training_steps_per_episode</td><td>28.86</td></tr><tr><td>Training_success_rate_per_episode</td><td>100.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">run_3</strong> at: <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/vej79eel' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/vej79eel</a><br/> View project at: <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_4agents</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251228_120836-vej79eel/logs</code>
# wandb version 0.23.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# FINISHED

# %% [markdown]
# ## **Save the agents model**

# %%
import os
def save_model(ppo, file_name):
    current_dir = os.getcwd()
    model_dir = os.path.join(current_dir, "models")
    checkpoint_name = os.path.join(model_dir, file_name)
    ppo.save(checkpoint_name)

    print(f"Model saved into {checkpoint_name}")

# %% [markdown]
# ## **Load agents**

# %%
from ray.rllib.algorithms.ppo import PPO
import os

def load_model(file_name):
    current_dir = os.getcwd()
    model_dir = os.path.join(current_dir, "models")
    checkpoint_name = os.path.join(model_dir, file_name)

    ppo = PPO.from_checkpoint(checkpoint_name)
    return ppo

# %%
import os

current_dir = os.getcwd()
model_dir = os.path.join(current_dir, "models")

for filename in os.listdir(model_dir):
    if "best" in filename and under_examination in filename:
        matching_file = filename
        break

file_path = os.path.join(model_dir, matching_file)
ppo = load_model(file_path)
# Out:
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:527: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/google/api_core/_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2025-12-28 14:04:29,559	INFO worker.py:2007 -- Started a local Ray instance.
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/_private/worker.py:2046: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# [2025-12-28 14:04:31,791 E 3908479 3908479] core_worker.cc:2223: Actor with class name: 'RolloutWorker' and ID: '9c6b6b603ba90a76657abc5501000000' has constructor arguments in the object store and max_restarts > 0. If the arguments in the object store go out of scope or are lost, the actor restart will fail. See https://github.com/ray-project/ray/issues/53727 for more details.
# (RolloutWorker pid=3908690) /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (RolloutWorker pid=3908690)   from pkg_resources import resource_stream, resource_exists
# 2025-12-28 14:04:34,925	WARNING util.py:61 -- Install gputil for GPU system monitoring.

# %% [markdown]
# ## **Graphically test the agent**

# %%
env = MyGridWorld(grid_size=15, n_agents=4, render_mode="human")
obs, _ = env.reset()

i = 0
while i < 3:
    actions = {}

    for agent_id, agent_obs in obs.items():
        actions[agent_id] = ppo.compute_single_action(
            agent_obs,
            policy_id=agent_id,
            explore=True
        )

    obs, rewards, terminations, truncations, infos = env.step(actions)

    if any(terminations.values()) or any(truncations.values()):
        obs, _ = env.reset()
        i += 1

env.close()
# Out:
# WARNING! Sprite image /home/terra/Desktop/unimore/distributed_project/sprites/.png not found. Using default sprite for this simulation.
# WARNING! Sprite image /home/terra/Desktop/unimore/distributed_project/sprites/.png not found. Using default sprite for this simulation.
# WARNING! Sprite image /home/terra/Desktop/unimore/distributed_project/sprites/.png not found. Using default sprite for this simulation.
# WARNING! Sprite image /home/terra/Desktop/unimore/distributed_project/sprites/.png not found. Using default sprite for this simulation.
# 2025-12-28 14:04:36,351	WARNING 2794382817.py:9 -- DeprecationWarning: `compute_single_action` has been deprecated. `Algorithm.compute_single_action` should no longer be used. Get the RLModule instance through `Algorithm.get_module([module ID])`, then compute actions through `RLModule.forward_inference({'obs': [obs batch]})`. This will raise an error in the future!
# (pid=gcs_server) [2025-12-28 14:04:58,660 E 3908521 3908521] (gcs_server) gcs_server.cc:303: Failed to establish connection to the event+metrics exporter agent. Events and metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (raylet) [2025-12-28 14:04:59,490 E 3908636 3908636] (raylet) main.cc:1032: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (RolloutWorker pid=3908690) [2025-12-28 14:05:00,431 E 3908690 3908792] core_worker_process.cc:842: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (pid=3908699) [2025-12-28 14:05:00,656 E 3908699 3909056] core_worker_process.cc:842: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# [2025-12-28 14:05:00,777 E 3908479 3908689] core_worker_process.cc:842: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
