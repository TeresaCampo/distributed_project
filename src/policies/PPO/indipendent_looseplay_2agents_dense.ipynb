# %% [markdown]
# # **My custom env - dense reward**
#
# **Environment classe pasted here in order to make it accessible to all the workers of Ray.**
#
# It is equivalent to /myenv_6_dense_reward.py

# %%
under_examination = "looseplay_2agents_densereward"

# %%
import sys, os
from pathlib import Path

current_dir = Path(os.getcwd()) 
pointed_dir = current_dir

while True:
    if pointed_dir.is_dir() and "distributed_project" == str(pointed_dir).split("/")[-1]:
        project_dir = pointed_dir
        print(f"Project dir found: {project_dir}")
        break
    
    if pointed_dir == pointed_dir.parent:
        print("Error while looking for 'distributed_project', project dir")
        break
        
    pointed_dir = pointed_dir.parent
# Out:
# Project dir found: /home/terra/Desktop/unimore/distributed_project

# %%
import numpy as np
import functools
import gymnasium as gym
from gymnasium import spaces
from pettingzoo import ParallelEnv
import pygame 
import os
from collections import defaultdict
import random

SPRITES_DIR = f"{project_dir}/sprites"


class MyGridWorld(ParallelEnv):
    metadata = {"render_modes": ["human"], "name": "custom_grid_v0"}

    def __init__(self, render_mode=None, n_agents = 2, grid_size=15):
        if grid_size<8:
            print("Error, need to insert a grid size greater or equal to 8")
        self.grid_size = grid_size
        self.render_mode = render_mode

        ######## Agents, fixed components, and forbidden positions
        self.possible_agents = [f"agent{i}" for i in range(1, n_agents+1)]
        self.agents = self.possible_agents[:]
        self.gate_open = False

        self.fixed_components = {
            "button1":  {"pos": np.array([self.grid_size//2+2, 1+3+2]), "file": "button.png"},
            "button2":  {"pos": np.array([self.grid_size//2+2, 1+1]), "file": "button.png"},

            "gate_open":  {"pos": np.array([self.grid_size//2, 1+3]), "file": "gate_open.png"},
            "gate_close":  {"pos": np.array([self.grid_size//2, 1+3]), "file": "gate_close.png"}   
        }
        self.button1_pos = self.fixed_components["button1"]["pos"]
        self.button2_pos = self.fixed_components["button2"]["pos"]

        self.gate_pos = self.fixed_components["gate_open"]["pos"] 
        self.target_final_pos = self.gate_pos+[0, -1]

        self.x_range = (1, self.grid_size-1-1)
        self.y_range = (1+3+1, self.grid_size-1-1)
        self.forbidden_position = {tuple(self.button1_pos)}    

        self.max_cycles = 100
        self.current_cycles = 0
        ######## Pygame graphic configuration 
        self.window_size = 810
        self.cell_size = self.window_size // self.grid_size
        self.window = None
        self.clock = None
        
        # Walls
        self.grid_map = np.zeros((self.grid_size, self.grid_size))
        self.grid_map[0, :] = 1
        self.grid_map[:, 0] = 1
        self.grid_map[-1, :] = 1
        self.grid_map[:, -1] = 1
        self.grid_map[ :, 1+3] = 1

        # Sprites 
        self.agent_sprites = {}
        self.component_sprites = {}

        ######## Action space and observation space
        # Five possible actions in each grid: stay(0), up(1), down(2), left(3), right(4)
        self.action_spaces = {a: spaces.Discrete(5) for a in self.possible_agents}
        OBSERVATION_DIM = 2*(len(self.agents)-1)+3*2+1
        self.observation_spaces = {
            a: spaces.Box(low=-(self.grid_size-1), high=self.grid_size-1, shape=(OBSERVATION_DIM,), dtype=np.float32) 
            for a in self.possible_agents
        }
        self.state_spaces = {a: None for a in self.possible_agents}

    def state(self):
        observations = self.gather_observations()
        global_state = []
        
        for agent in self.possible_agents:
            if agent in observations:
                global_state.append(observations[agent])
            else:
                # Se l'agente è morto/uscito, usa zeri
                dim = self.observation_spaces[agent].shape[0]
                global_state.append(np.zeros(dim, dtype=np.float32))
                
        return np.concatenate(global_state)

    # Boilerplate PettingZoo
    def observation_space(self, agent): return self.observation_spaces[agent]
    def action_space(self, agent): return self.action_spaces[agent]

    '''
    Step in the environment
    '''
    def step(self, actions):
        if not self.agents: return {}, {}, {}, {}, {}
        self.current_cycles += 1
        
        rewards = {a: 0 for a in self.agents}

        terminations = {a: False for a in self.agents}
        truncations = {a: False for a in self.agents}
        infos = {a: {"is_success":False} for a in self.agents}
        
        desired_positions = {}      
        button_pressed = False
        agents_desire_gate = []
        for agent, action in actions.items():
            current_pos = self.agent_positions[agent].copy()
            target_pos = current_pos.copy()

            if action == 1: target_pos[1] -= 1 
            elif action == 2: target_pos[1] += 1
            elif action == 3: target_pos[0] -= 1
            elif action == 4: target_pos[0] += 1

            # Monitor button, gate and walls
            is_wall = self.grid_map[target_pos[0], target_pos[1]] == 1
            is_gate = (target_pos == self.gate_pos).all()
            is_button = (target_pos == self.button1_pos).all() or (target_pos == self.button2_pos).all()
            
            if is_button:
                button_pressed = True
            if is_gate:
                agents_desire_gate.append((agent, current_pos))
            
            if is_wall and not is_gate:
                desired_positions[agent] = current_pos 
            else:
                desired_positions[agent] = target_pos
                        
        # If gate was open remove a wall, if gate was closed update the position of those who wanted to cross it
        self.gate_open = button_pressed
        if self.gate_open:
            self.grid_map[self.gate_pos[0], self.gate_pos[1]] = 0
        else:
            self.grid_map[self.gate_pos[0], self.gate_pos[1]] = 1
            for a in agents_desire_gate:
                agent = a[0]
                current_pos = a[1]
                desired_positions[agent] = current_pos 

        # Check for conflicts (more than one agents have the same desired position)
        final_positions = self.agent_positions.copy()
        target_counts = defaultdict(list)         # Key: tuple(x, y) of desired positions, Value: list of agents desiring it
        for agent, pos in desired_positions.items():
            pos_tuple = tuple(pos)
            target_counts[pos_tuple].append(agent)

        # Solve eventual conflicts
        for pos_tuple, agents_at_target in target_counts.items():      
            # Case 1: no contended position
            if len(agents_at_target) == 1:
                agent = agents_at_target[0]
                final_positions[agent] = desired_positions[agent]
            
            # Case 2: contended position
            else:
                one_agent_already_here_not_moving = None
                for agent in agents_at_target:
                    if tuple(self.agent_positions[agent]) == pos_tuple:
                        one_agent_already_here_not_moving = agent
                        break
                
                winning_agent = one_agent_already_here_not_moving if one_agent_already_here_not_moving else random.choice(agents_at_target)
                final_positions[winning_agent] = desired_positions[winning_agent]
                
                agents_at_target.remove(winning_agent)
                for losing_agent in agents_at_target[:]:
                    final_positions[losing_agent] = self.agent_positions[losing_agent] 
        self.agent_positions = final_positions

        # Negative reward if an agent is on the bottom area and is not pressing the button
        agents_upper_area = 0
        for a, pos in self.agent_positions.items():
            dist_target = np.linalg.norm(pos - self.target_final_pos)
            if pos[1]<4:                                # Agent on upper area
                rewards[a] = +0.5
                agents_upper_area+=1

                if (pos == self.button2_pos).all():
                    rewards[a] +=0.3
            else:
                rewards[a] -= (dist_target * 0.05)      # Agent on bottom area

                if (pos == self.button1_pos).all():     # Agent on button
                    rewards[a] += 0.3     
       
        if agents_upper_area == len(self.agents):
            rewards = {a: +100 for a in self.agents}
            terminations = {a: True for a in self.agents}
            infos = {a: {"is_success":True} for a in self.agents}

        if self.current_cycles >= self.max_cycles:
            truncations= {a: True for a in self.agents}
            
        
        if self.render_mode == "human":
            self.render()
            
        final_obs = self.gather_observations()
        self.agents = [a for a in self.agents if not terminations[a]]
        return final_obs, rewards, terminations, truncations, infos
   
    '''
    Determines initial condition of the simulation
    '''

    def generate_valid_position(self):
        while True:
            x = np.random.randint(self.x_range[0], self.x_range[1])
            y = np.random.randint(self.y_range[0], self.y_range[1])
            new_position = tuple((x, y))

            if new_position not in self.forbidden_position:
                return new_position
            
    def generate_set_initial_positions(self):
        set_initial_positions = set()
        while len(set_initial_positions)<len(self.possible_agents):
            new_pos = self.generate_valid_position()
            set_initial_positions.add(new_pos)
        return set_initial_positions
    
    def generate_test_values(self, agent_num):
        if agent_num==1:
            return[7, 9]
        else:
            return [9,13]

    def reset(self, seed=None, options=None):
        self.agents = self.possible_agents[:]
        set_initial_positions = list(self.generate_set_initial_positions())
        self.current_cycles = 0

        self.agent_positions = {}
        for i, agent_id in enumerate(self.agents):
            self.agent_positions[agent_id] = np.array(set_initial_positions[i])
        
        # To visualize the reset position if "human" mode on
        if self.render_mode == "human":
            self.render()         

        return self.gather_observations(), {a: {} for a in self.agents}
    
    '''
    Observation: [my_cur_pos, (other_cur) x number of other agents, button_pos, gate_pos, gate_open (1|0)]    '''
    def gather_observations(self):
        gate_status_info = np.array([int(self.gate_open)], dtype=np.float32)
        observations = {}
        for observing_agent in self.agents:
            obs_segments = []
            observing_agent_pos = self.agent_positions[observing_agent]
            
            for other_agent in self.agents:
                if other_agent != observing_agent:
                    obs_segments.append(self.agent_positions[other_agent] - observing_agent_pos)
            obs_segments.append(self.button1_pos- observing_agent_pos)
            obs_segments.append(self.button2_pos- observing_agent_pos)
            obs_segments.append(self.gate_pos -observing_agent_pos)
            obs_segments.append(gate_status_info)
            observations[observing_agent] = np.concatenate(obs_segments, dtype=np.float32)
        return observations

    '''
    Functions for Sprite rendering and loading
    '''    
    def _create_missing_sprite(self, text, bg_color, border_color = (0,0,0)):  
        error_sprite = pygame.Surface((self.cell_size, self.cell_size), pygame.SRCALPHA)
        error_sprite.fill((0, 0, 0, 0))
        center = (self.cell_size // 2, self.cell_size // 2)
        radius = int(self.cell_size * 0.4)
        pygame.draw.circle(error_sprite, bg_color, center, radius) 
        pygame.draw.circle(error_sprite, border_color, center, radius, 2)
        
        # Add text label
        try:
            font_size = int(self.cell_size * 0.22)
            font = pygame.font.Font(None, font_size)   
            text_color = (0, 0, 0) if sum(bg_color) > 300 else (255, 255, 255) 
            text_surface = font.render(text, True, text_color)
            text_rect = text_surface.get_rect(center=center)
            error_sprite.blit(text_surface, text_rect)
            
        except Exception as e:
            print(f"WARNING: Error while writing text inside missing sprite {text}. A missing sprite without text label will be used for this simulation.")
            pass
            
        return error_sprite
    
    def _load_and_scale_sprite(self, filename, component_name):
        path = os.path.join(SPRITES_DIR, filename)
    
        try:
            image = pygame.image.load(path).convert_alpha() 
            scaled_size = int(self.cell_size )
            return pygame.transform.scale(image, (scaled_size, scaled_size))
            
        except (FileNotFoundError, pygame.error) as e:
            print(f"WARNING! Sprite image {path} not found. Using default sprite for this simulation.")
    
            text = component_name.upper() if component_name else "ERROR"
            bg_color = (100, 100, 255) if "AGENT" in text else (128,128,128) # Blue agent, Gray fixed components
            return self._create_missing_sprite(text, bg_color)

    def render(self):
        if self.render_mode is None:
            return

        if self.window is None:
            pygame.init()
            pygame.display.init()
            pygame.font.init()
            self.window = pygame.display.set_mode((self.window_size, self.window_size))
            
            for agent_name in self.agents:
               # self.agent_sprites[agent_name] = self._load_and_scale_sprite(f"{agent_name}.png", agent_name)
               self.agent_sprites[agent_name] = self._load_and_scale_sprite(".png", agent_name)

            for name, data in self.fixed_components.items():
                self.component_sprites[name] = self._load_and_scale_sprite(data["file"], name)

                 
        if self.clock is None:
            self.clock = pygame.time.Clock()

        canvas = pygame.Surface((self.window_size, self.window_size))
        canvas.fill((220, 220, 220)) 
        pix_square_size = self.cell_size 
        sprite_offset = (pix_square_size - int(pix_square_size * 0.8)) // 2

        # Render walls
        for x in range(self.grid_size):
            for y in range(self.grid_size):
                if self.grid_map[x, y] == 1:
                    pygame.draw.rect(
                        canvas, 
                        (50, 50, 50),
                        pygame.Rect(x * pix_square_size, y * pix_square_size, pix_square_size, pix_square_size)
                    )

        # Render fixed components and agents
        for name, data in self.fixed_components.items():
            if self.gate_open and name == "gate_close":
                continue
            pos = data["pos"]
            x_coord = pos[0] * pix_square_size + sprite_offset
            y_coord = pos[1] * pix_square_size + sprite_offset
            sprite = self.component_sprites[name]
            canvas.blit(sprite, (x_coord, y_coord))

        for agent in self.agents:
            pos = self.agent_positions[agent]            
            x_coord = pos[0] * pix_square_size + sprite_offset
            y_coord = pos[1] * pix_square_size + sprite_offset
            
            sprite = self.agent_sprites[agent]
            canvas.blit(sprite, (x_coord, y_coord))

        # Render the grid
        for x in range(self.grid_size + 1):
            pygame.draw.line(
                canvas, 0, (0, pix_square_size * x), (self.window_size, pix_square_size * x), width=2
            )
            pygame.draw.line(
                canvas, 0, (pix_square_size * x, 0), (pix_square_size * x, self.window_size), width=2
            )

        # Display the render
        self.window.blit(canvas, canvas.get_rect())
        pygame.event.pump()
        pygame.display.update()
        self.clock.tick(4) # FPS

    def close(self):
        if self.window is not None:
            pygame.display.quit()
            pygame.quit()
# Out:
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %% [markdown]
# **Wrap the envornment in a PettingZoo env (for compatibility with Ray) and register it on Ray lib**

# %%
from ray.rllib.env.wrappers.pettingzoo_env import ParallelPettingZooEnv
from ray.tune.registry import register_env

def env_creator(config):
    return ParallelPettingZooEnv(
        MyGridWorld(render_mode=None, n_agents=2)
    )

register_env("my_gridworld", env_creator)

# %% [markdown]
# ## **IPPO - loose play settings**

# %% [markdown]
# Callback to register episode success rate

# %%
from ray.rllib.algorithms.callbacks import DefaultCallbacks

class SuccessMetricCallback(DefaultCallbacks):
    def on_episode_end(self, *, worker, base_env, policies, episode, **kwargs):
        
        is_success = False
        one_agent_id = list(episode.get_agents())[-1]
        last_info = episode.last_info_for(one_agent_id)
        is_success = last_info["is_success"]
       
        episode.custom_metrics["success_rate"] = int(is_success)

# %%
from ray.rllib.algorithms.ppo import PPOConfig

dummy_env = env_creator({}) 
agent_ids = dummy_env.possible_agents 
print(f"Agents in the env: {agent_ids}")
dummy_env.close()

config = (
    PPOConfig()
    .environment(env="my_gridworld")
    .env_runners(num_env_runners=0)
    .callbacks(callbacks_class=SuccessMetricCallback)
    
    .multi_agent(
        policies=set(agent_ids),
        policy_mapping_fn=lambda agent_id, *args, **kwargs: agent_id,
    )
    
    .api_stack(
        enable_rl_module_and_learner=False,
        enable_env_runner_and_connector_v2=False
    )
    .evaluation(
        evaluation_interval=1,
        evaluation_duration=10,
        evaluation_duration_unit="episodes",
        evaluation_num_env_runners=1,
        evaluation_config={
            "explore": True,
        }
    )
    .training(
        lr=1e-4,
        train_batch_size_per_learner=4000, 
        num_epochs=10,        
        entropy_coeff=0.01,
        kl_coeff=0.2,
        kl_target=0.01
    )
)
# Out:
# Agents in the env: ['agent2', 'agent1']

# %% [markdown]
# ## **Wandb - One run of training**

# %%
import wandb
#wandb.init(project="gridworld_looseplay_2agents", name="densereward")
ppo = config.build_algo()
num_total_episodes = 0
for i in range(50):
    result = ppo.train()
    num_total_episodes += result['env_runners']['num_episodes']
    
    print(f"ITERATION {i}, num episode {num_total_episodes}".center(100,"-"))
    train_rew = round(result['env_runners']['episode_return_mean'], 2)
    train_steps_episode = round(result['env_runners']['episode_len_mean'], 2)
    train_success_rate = round(result['env_runners']['custom_metrics'].get('success_rate_mean', 0), 2) * 100
    print(f"""TRAINING\nRew:{train_rew} \nSteps per episode:{train_steps_episode} \nSuccess rate:{train_success_rate}%\n""")

    if 'evaluation' in result:
        testing_rew = round(result['evaluation']['env_runners']['episode_return_mean'], 2)
        testing_steps_episode = round(result['evaluation']['env_runners']['episode_len_mean'], 2)
        testing_success_rate = round(result['evaluation']['env_runners']['custom_metrics'].get('success_rate_mean', 0), 2) * 100
        print(f"""TESTING\nRew:{testing_rew} \nSteps per episode:{testing_steps_episode} \nSuccess rate:{testing_success_rate}%\n\n""")

    log_data = {
        "Episodes": num_total_episodes,

        "Training_steps_per_episode": train_steps_episode,
        "Training_success_rate_per_episode": train_success_rate,
        "Training_reward_per_episode": train_rew,

        "Testing_steps_per_episode": testing_steps_episode,
        "Testing_success_rate_per_episode": testing_success_rate,
        "Testing_reward_per_episode": testing_rew
    }
    #wandb.log(log_data)
#wandb.finish()

# %% [markdown]
# ## **Wandb, 3 runs of training to generate esteme**

# %%
import wandb
group_name = "dense"

for run_idx in range(1,4):
    print(f"\n{'='*40}")
    print(f"RUN NUMBER {run_idx}/3")
    print(f"{'='*40}\n")

    ppo = config.build_algo()
    wandb.init(
        project="gridworld_looseplay_2agents",
        group=group_name,           
        name=f"run_{run_idx}",    
        reinit=True 
    )
    file_name = f"{under_examination}_run_{run_idx}"
    
    num_total_episodes = 0
    for i in range(50):
        result = ppo.train()
        num_total_episodes += result['env_runners']['num_episodes']
        
        print(f"ITERATION {i}, num episode {num_total_episodes}".center(100,"-"))
        train_rew = round(result['env_runners']['episode_return_mean'], 2)
        train_steps_episode = round(result['env_runners']['episode_len_mean'], 2)
        train_success_rate = round(result['env_runners']['custom_metrics'].get('success_rate_mean', 0), 2) * 100
        print(f"""TRAINING\nRew:{train_rew} \nSteps per episode:{train_steps_episode} \nSuccess rate:{train_success_rate}%\n""")

        if 'evaluation' in result:
            testing_rew = round(result['evaluation']['env_runners']['episode_return_mean'], 2)
            testing_steps_episode = round(result['evaluation']['env_runners']['episode_len_mean'], 2)
            testing_success_rate = round(result['evaluation']['env_runners']['custom_metrics'].get('success_rate_mean', 0), 2) * 100
            print(f"""TESTING\nRew:{testing_rew} \nSteps per episode:{testing_steps_episode} \nSuccess rate:{testing_success_rate}%\n\n""")

        log_data = {
            "Episodes": num_total_episodes,

            "Training_steps_per_episode": train_steps_episode,
            "Training_success_rate_per_episode": train_success_rate,
            "Training_reward_per_episode": train_rew,

            "Testing_steps_per_episode": testing_steps_episode,
            "Testing_success_rate_per_episode": testing_success_rate,
            "Testing_reward_per_episode": testing_rew
        }
        wandb.log(log_data)
    save_model(ppo, file_name)
    wandb.finish()

print("FINISHED")
# Out:
# ========================================
# RUN NUMBER 1/3
# ========================================
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:527: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/google/api_core/_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2025-12-28 01:58:25,119	INFO worker.py:2007 -- Started a local Ray instance.
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/_private/worker.py:2046: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# [2025-12-28 01:58:27,028 E 2762223 2762223] core_worker.cc:2223: Actor with class name: 'RolloutWorker' and ID: '85ecace3e009362a67d9ddb601000000' has constructor arguments in the object store and max_restarts > 0. If the arguments in the object store go out of scope or are lost, the actor restart will fail. See https://github.com/ray-project/ray/issues/53727 for more details.
# (RolloutWorker pid=2762520) /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (RolloutWorker pid=2762520)   from pkg_resources import resource_stream, resource_exists
# 2025-12-28 01:58:30,161	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: 299011 (299011-unimore). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.17.9
# Run data is saved locally in <code>/home/terra/Desktop/unimore/distributed_project/src/policies/PPO/wandb/run-20251228_015831-4c9hy0yz</code>
# Syncing run <strong><a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/4c9hy0yz' target="_blank">run_1</a></strong> to <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_2agents</a>
#  View run at <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/4c9hy0yz' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/4c9hy0yz</a>
# 2025-12-28 01:58:43,350	WARNING sgd.py:55 -- DeprecationWarning: `_get_slice_indices` has been deprecated. This will raise an error in the future!
# ------------------------------------ITERATION 0, num episode 40-------------------------------------
# TRAINING
# Rew:-65.44
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-50.29
# Steps per episode:100.0
# Success rate:0.0%
# (pid=gcs_server) [2025-12-28 01:58:54,312 E 2762348 2762348] (gcs_server) gcs_server.cc:303: Failed to establish connection to the event+metrics exporter agent. Events and metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (raylet) [2025-12-28 01:58:55,044 E 2762463 2762463] (raylet) main.cc:1032: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (RolloutWorker pid=2762520) [2025-12-28 01:58:55,812 E 2762520 2762634] core_worker_process.cc:842: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# [2025-12-28 01:58:56,027 E 2762223 2762516] core_worker_process.cc:842: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# ------------------------------------ITERATION 1, num episode 80-------------------------------------
# TRAINING
# Rew:-56.53
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-27.58
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 2, num episode 120------------------------------------
# TRAINING
# Rew:-46.61
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-25.84
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 3, num episode 160------------------------------------
# TRAINING
# Rew:-34.07
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:14.24
# Steps per episode:99.67
# Success rate:11.0%
#
#
# ------------------------------------ITERATION 4, num episode 200------------------------------------
# TRAINING
# Rew:-25.31
# Steps per episode:99.6
# Success rate:1.0%
#
# TESTING
# Rew:-19.24
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 5, num episode 240------------------------------------
# TRAINING
# Rew:-16.29
# Steps per episode:99.13
# Success rate:3.0%
#
# TESTING
# Rew:-0.77
# Steps per episode:98.78
# Success rate:11.0%
#
#
# ------------------------------------ITERATION 6, num episode 282------------------------------------
# TRAINING
# Rew:0.52
# Steps per episode:97.37
# Success rate:10.0%
#
# TESTING
# Rew:-19.18
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 7, num episode 325------------------------------------
# TRAINING
# Rew:16.3
# Steps per episode:95.63
# Success rate:16.0%
#
# TESTING
# Rew:28.29
# Steps per episode:90.0
# Success rate:22.0%
#
#
# ------------------------------------ITERATION 8, num episode 368------------------------------------
# TRAINING
# Rew:32.87
# Steps per episode:93.1
# Success rate:23.0%
#
# TESTING
# Rew:20.12
# Steps per episode:95.56
# Success rate:22.0%
#
#
# ------------------------------------ITERATION 9, num episode 412------------------------------------
# TRAINING
# Rew:36.37
# Steps per episode:91.43
# Success rate:25.0%
#
# TESTING
# Rew:177.74
# Steps per episode:59.89
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 10, num episode 464------------------------------------
# TRAINING
# Rew:78.39
# Steps per episode:84.7
# Success rate:44.0%
#
# TESTING
# Rew:145.49
# Steps per episode:68.78
# Success rate:78.0%
#
#
# -----------------------------------ITERATION 11, num episode 515------------------------------------
# TRAINING
# Rew:123.54
# Steps per episode:78.12
# Success rate:66.0%
#
# TESTING
# Rew:168.65
# Steps per episode:51.67
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 12, num episode 571------------------------------------
# TRAINING
# Rew:138.96
# Steps per episode:74.7
# Success rate:73.0%
#
# TESTING
# Rew:169.24
# Steps per episode:57.0
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 13, num episode 638------------------------------------
# TRAINING
# Rew:164.75
# Steps per episode:63.72
# Success rate:84.0%
#
# TESTING
# Rew:203.25
# Steps per episode:47.0
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 14, num episode 724------------------------------------
# TRAINING
# Rew:196.96
# Steps per episode:47.85
# Success rate:99.0%
#
# TESTING
# Rew:197.98
# Steps per episode:43.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 15, num episode 829------------------------------------
# TRAINING
# Rew:198.19
# Steps per episode:38.37
# Success rate:100.0%
#
# TESTING
# Rew:200.8
# Steps per episode:24.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 16, num episode 957------------------------------------
# TRAINING
# Rew:198.84
# Steps per episode:31.15
# Success rate:100.0%
#
# TESTING
# Rew:197.48
# Steps per episode:27.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 17, num episode 1085-----------------------------------
# TRAINING
# Rew:197.7
# Steps per episode:31.31
# Success rate:100.0%
#
# TESTING
# Rew:201.02
# Steps per episode:27.67
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 18, num episode 1218-----------------------------------
# TRAINING
# Rew:199.68
# Steps per episode:30.15
# Success rate:100.0%
#
# TESTING
# Rew:201.7
# Steps per episode:26.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 19, num episode 1377-----------------------------------
# TRAINING
# Rew:198.68
# Steps per episode:25.23
# Success rate:100.0%
#
# TESTING
# Rew:199.74
# Steps per episode:26.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 20, num episode 1538-----------------------------------
# TRAINING
# Rew:199.04
# Steps per episode:24.78
# Success rate:100.0%
#
# TESTING
# Rew:198.81
# Steps per episode:28.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 21, num episode 1705-----------------------------------
# TRAINING
# Rew:199.53
# Steps per episode:24.0
# Success rate:100.0%
#
# TESTING
# Rew:198.93
# Steps per episode:21.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 22, num episode 1878-----------------------------------
# TRAINING
# Rew:199.84
# Steps per episode:23.16
# Success rate:100.0%
#
# TESTING
# Rew:181.07
# Steps per episode:36.44
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 23, num episode 2048-----------------------------------
# TRAINING
# Rew:198.28
# Steps per episode:23.48
# Success rate:99.0%
#
# TESTING
# Rew:199.58
# Steps per episode:20.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 24, num episode 2229-----------------------------------
# TRAINING
# Rew:199.01
# Steps per episode:21.99
# Success rate:100.0%
#
# TESTING
# Rew:199.66
# Steps per episode:22.0
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 25, num episode 2412-----------------------------------
# TRAINING
# Rew:199.62
# Steps per episode:22.02
# Success rate:100.0%
#
# TESTING
# Rew:197.29
# Steps per episode:21.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 26, num episode 2603-----------------------------------
# TRAINING
# Rew:198.88
# Steps per episode:20.9
# Success rate:100.0%
#
# TESTING
# Rew:202.58
# Steps per episode:25.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 27, num episode 2788-----------------------------------
# TRAINING
# Rew:199.42
# Steps per episode:21.65
# Success rate:100.0%
#
# TESTING
# Rew:201.07
# Steps per episode:26.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 28, num episode 2946-----------------------------------
# TRAINING
# Rew:201.3
# Steps per episode:25.27
# Success rate:100.0%
#
# TESTING
# Rew:199.16
# Steps per episode:24.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 29, num episode 3093-----------------------------------
# TRAINING
# Rew:200.7
# Steps per episode:27.18
# Success rate:100.0%
#
# TESTING
# Rew:199.71
# Steps per episode:20.67
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 30, num episode 3275-----------------------------------
# TRAINING
# Rew:199.38
# Steps per episode:22.02
# Success rate:100.0%
#
# TESTING
# Rew:201.06
# Steps per episode:27.0
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 31, num episode 3445-----------------------------------
# TRAINING
# Rew:199.6
# Steps per episode:23.49
# Success rate:100.0%
#
# TESTING
# Rew:198.76
# Steps per episode:24.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 32, num episode 3634-----------------------------------
# TRAINING
# Rew:199.55
# Steps per episode:21.2
# Success rate:100.0%
#
# TESTING
# Rew:197.86
# Steps per episode:19.67
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 33, num episode 3826-----------------------------------
# TRAINING
# Rew:199.41
# Steps per episode:20.78
# Success rate:100.0%
#
# TESTING
# Rew:198.34
# Steps per episode:19.0
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 34, num episode 4022-----------------------------------
# TRAINING
# Rew:199.15
# Steps per episode:20.49
# Success rate:100.0%
#
# TESTING
# Rew:198.44
# Steps per episode:20.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 35, num episode 4225-----------------------------------
# TRAINING
# Rew:199.14
# Steps per episode:19.68
# Success rate:100.0%
#
# TESTING
# Rew:199.14
# Steps per episode:23.0
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 36, num episode 4426-----------------------------------
# TRAINING
# Rew:199.37
# Steps per episode:19.91
# Success rate:100.0%
#
# TESTING
# Rew:200.53
# Steps per episode:18.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 37, num episode 4633-----------------------------------
# TRAINING
# Rew:198.84
# Steps per episode:19.3
# Success rate:100.0%
#
# TESTING
# Rew:200.54
# Steps per episode:28.0
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 38, num episode 4816-----------------------------------
# TRAINING
# Rew:199.35
# Steps per episode:21.89
# Success rate:100.0%
#
# TESTING
# Rew:198.02
# Steps per episode:19.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 39, num episode 5018-----------------------------------
# TRAINING
# Rew:198.96
# Steps per episode:19.8
# Success rate:100.0%
#
# TESTING
# Rew:199.18
# Steps per episode:19.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 40, num episode 5215-----------------------------------
# TRAINING
# Rew:199.3
# Steps per episode:20.3
# Success rate:100.0%
#
# TESTING
# Rew:197.0
# Steps per episode:20.0
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 41, num episode 5414-----------------------------------
# TRAINING
# Rew:198.77
# Steps per episode:20.06
# Success rate:100.0%
#
# TESTING
# Rew:198.99
# Steps per episode:18.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 42, num episode 5611-----------------------------------
# TRAINING
# Rew:198.34
# Steps per episode:20.32
# Success rate:100.0%
#
# TESTING
# Rew:199.09
# Steps per episode:18.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 43, num episode 5817-----------------------------------
# TRAINING
# Rew:198.89
# Steps per episode:19.43
# Success rate:100.0%
#
# TESTING
# Rew:199.89
# Steps per episode:25.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 44, num episode 5984-----------------------------------
# TRAINING
# Rew:200.1
# Steps per episode:23.99
# Success rate:100.0%
#
# TESTING
# Rew:199.13
# Steps per episode:21.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 45, num episode 6161-----------------------------------
# TRAINING
# Rew:199.39
# Steps per episode:22.49
# Success rate:100.0%
#
# TESTING
# Rew:198.55
# Steps per episode:22.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 46, num episode 6364-----------------------------------
# TRAINING
# Rew:199.12
# Steps per episode:19.73
# Success rate:100.0%
#
# TESTING
# Rew:199.0
# Steps per episode:20.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 47, num episode 6565-----------------------------------
# TRAINING
# Rew:198.63
# Steps per episode:19.92
# Success rate:100.0%
#
# TESTING
# Rew:198.64
# Steps per episode:21.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 48, num episode 6758-----------------------------------
# TRAINING
# Rew:198.86
# Steps per episode:20.73
# Success rate:100.0%
#
# TESTING
# Rew:200.9
# Steps per episode:20.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 49, num episode 6955-----------------------------------
# TRAINING
# Rew:199.27
# Steps per episode:20.21
# Success rate:100.0%
#
# TESTING
# Rew:201.72
# Steps per episode:20.67
# Success rate:100.0%
#
#
# Model saved into /home/terra/Desktop/unimore/distributed_project/src/policies/PPO/models/looseplay_2agents_densereward_run_1
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>Testing_reward_per_episode</td><td>▁▂▂▃▂▂▃▃▆▇▇███████▇█████████████████████</td></tr><tr><td>Testing_steps_per_episode</td><td>██████▇█▅▄▄▃▂▂▂▂▂▁▃▁▁▂▂▂▂▂▁▁▁▁▂▁▁▁▁▂▁▁▁▁</td></tr><tr><td>Testing_success_rate_per_episode</td><td>▁▁▁▂▂▁▃▃▆▇▇███████▇█████████████████████</td></tr><tr><td>Training_reward_per_episode</td><td>▁▁▁▂▂▃▃▄▅▆▆▇████████████████████████████</td></tr><tr><td>Training_steps_per_episode</td><td>███████▇▇▆▆▅▃▂▂▂▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Training_success_rate_per_episode</td><td>▁▁▁▁▁▂▂▃▄▆▆▇████████████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>6955</td></tr><tr><td>Testing_reward_per_episode</td><td>201.72</td></tr><tr><td>Testing_steps_per_episode</td><td>20.67</td></tr><tr><td>Testing_success_rate_per_episode</td><td>100.0</td></tr><tr><td>Training_reward_per_episode</td><td>199.27</td></tr><tr><td>Training_steps_per_episode</td><td>20.21</td></tr><tr><td>Training_success_rate_per_episode</td><td>100.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">run_1</strong> at: <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/4c9hy0yz' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/4c9hy0yz</a><br/> View project at: <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_2agents</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251228_015831-4c9hy0yz/logs</code>
# wandb version 0.23.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# ========================================
# RUN NUMBER 2/3
# ========================================
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:527: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# (RolloutWorker pid=2762525) /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (RolloutWorker pid=2762525)   from pkg_resources import resource_stream, resource_exists
# (pid=2762526) [2025-12-28 01:58:56,021 E 2762526 2763052] core_worker_process.cc:842: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14 [repeated 11x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# 2025-12-28 02:09:18,979	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Tracking run with wandb version 0.17.9
# Run data is saved locally in <code>/home/terra/Desktop/unimore/distributed_project/src/policies/PPO/wandb/run-20251228_020918-fpehmck5</code>
# Syncing run <strong><a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/fpehmck5' target="_blank">run_2</a></strong> to <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_2agents</a>
#  View run at <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/fpehmck5' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/fpehmck5</a>
# ------------------------------------ITERATION 0, num episode 40-------------------------------------
# TRAINING
# Rew:-67.44
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-60.25
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 1, num episode 80-------------------------------------
# TRAINING
# Rew:-61.88
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-45.93
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 2, num episode 120------------------------------------
# TRAINING
# Rew:-52.9
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-32.92
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 3, num episode 160------------------------------------
# TRAINING
# Rew:-40.64
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-27.06
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 4, num episode 200------------------------------------
# TRAINING
# Rew:-31.07
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-24.15
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 5, num episode 240------------------------------------
# TRAINING
# Rew:-23.23
# Steps per episode:99.65
# Success rate:1.0%
#
# TESTING
# Rew:-27.74
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 6, num episode 280------------------------------------
# TRAINING
# Rew:-21.89
# Steps per episode:99.65
# Success rate:1.0%
#
# TESTING
# Rew:-24.24
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 7, num episode 320------------------------------------
# TRAINING
# Rew:-22.88
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-20.53
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 8, num episode 360------------------------------------
# TRAINING
# Rew:-15.82
# Steps per episode:99.95
# Success rate:2.0%
#
# TESTING
# Rew:-20.95
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 9, num episode 402------------------------------------
# TRAINING
# Rew:-8.05
# Steps per episode:98.22
# Success rate:5.0%
#
# TESTING
# Rew:-16.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 10, num episode 445------------------------------------
# TRAINING
# Rew:10.71
# Steps per episode:94.69
# Success rate:13.0%
#
# TESTING
# Rew:11.36
# Steps per episode:98.56
# Success rate:11.0%
#
#
# -----------------------------------ITERATION 11, num episode 488------------------------------------
# TRAINING
# Rew:29.05
# Steps per episode:92.46
# Success rate:20.0%
#
# TESTING
# Rew:151.61
# Steps per episode:53.89
# Success rate:78.0%
#
#
# -----------------------------------ITERATION 12, num episode 539------------------------------------
# TRAINING
# Rew:58.12
# Steps per episode:86.51
# Success rate:33.0%
#
# TESTING
# Rew:153.08
# Steps per episode:60.67
# Success rate:78.0%
#
#
# -----------------------------------ITERATION 13, num episode 593------------------------------------
# TRAINING
# Rew:126.19
# Steps per episode:75.76
# Success rate:64.0%
#
# TESTING
# Rew:160.57
# Steps per episode:69.78
# Success rate:78.0%
#
#
# -----------------------------------ITERATION 14, num episode 654------------------------------------
# TRAINING
# Rew:160.8
# Steps per episode:69.01
# Success rate:80.0%
#
# TESTING
# Rew:175.86
# Steps per episode:48.78
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 15, num episode 731------------------------------------
# TRAINING
# Rew:186.05
# Steps per episode:55.16
# Success rate:93.0%
#
# TESTING
# Rew:197.76
# Steps per episode:49.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 16, num episode 826------------------------------------
# TRAINING
# Rew:197.35
# Steps per episode:43.56
# Success rate:99.0%
#
# TESTING
# Rew:202.7
# Steps per episode:35.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 17, num episode 934------------------------------------
# TRAINING
# Rew:199.86
# Steps per episode:37.02
# Success rate:100.0%
#
# TESTING
# Rew:198.63
# Steps per episode:25.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 18, num episode 1073-----------------------------------
# TRAINING
# Rew:199.81
# Steps per episode:28.63
# Success rate:100.0%
#
# TESTING
# Rew:200.02
# Steps per episode:25.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 19, num episode 1220-----------------------------------
# TRAINING
# Rew:199.7
# Steps per episode:27.37
# Success rate:100.0%
#
# TESTING
# Rew:198.26
# Steps per episode:21.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 20, num episode 1393-----------------------------------
# TRAINING
# Rew:199.16
# Steps per episode:23.06
# Success rate:100.0%
#
# TESTING
# Rew:200.38
# Steps per episode:23.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 21, num episode 1583-----------------------------------
# TRAINING
# Rew:198.83
# Steps per episode:21.08
# Success rate:100.0%
#
# TESTING
# Rew:198.6
# Steps per episode:25.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 22, num episode 1776-----------------------------------
# TRAINING
# Rew:199.04
# Steps per episode:20.67
# Success rate:100.0%
#
# TESTING
# Rew:199.89
# Steps per episode:22.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 23, num episode 1967-----------------------------------
# TRAINING
# Rew:199.13
# Steps per episode:20.95
# Success rate:100.0%
#
# TESTING
# Rew:199.47
# Steps per episode:20.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 24, num episode 2167-----------------------------------
# TRAINING
# Rew:199.39
# Steps per episode:20.07
# Success rate:100.0%
#
# TESTING
# Rew:199.33
# Steps per episode:21.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 25, num episode 2355-----------------------------------
# TRAINING
# Rew:199.85
# Steps per episode:21.17
# Success rate:100.0%
#
# TESTING
# Rew:197.88
# Steps per episode:20.67
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 26, num episode 2545-----------------------------------
# TRAINING
# Rew:199.06
# Steps per episode:21.07
# Success rate:100.0%
#
# TESTING
# Rew:200.28
# Steps per episode:20.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 27, num episode 2731-----------------------------------
# TRAINING
# Rew:199.24
# Steps per episode:21.6
# Success rate:100.0%
#
# TESTING
# Rew:199.25
# Steps per episode:22.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 28, num episode 2932-----------------------------------
# TRAINING
# Rew:199.27
# Steps per episode:19.87
# Success rate:100.0%
#
# TESTING
# Rew:199.99
# Steps per episode:15.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 29, num episode 3132-----------------------------------
# TRAINING
# Rew:199.74
# Steps per episode:19.94
# Success rate:100.0%
#
# TESTING
# Rew:199.37
# Steps per episode:15.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 30, num episode 3338-----------------------------------
# TRAINING
# Rew:198.8
# Steps per episode:19.41
# Success rate:100.0%
#
# TESTING
# Rew:200.5
# Steps per episode:20.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 31, num episode 3543-----------------------------------
# TRAINING
# Rew:199.49
# Steps per episode:19.57
# Success rate:100.0%
#
# TESTING
# Rew:198.22
# Steps per episode:19.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 32, num episode 3745-----------------------------------
# TRAINING
# Rew:199.59
# Steps per episode:19.85
# Success rate:100.0%
#
# TESTING
# Rew:200.31
# Steps per episode:25.0
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 33, num episode 3943-----------------------------------
# TRAINING
# Rew:199.5
# Steps per episode:20.21
# Success rate:100.0%
#
# TESTING
# Rew:199.85
# Steps per episode:19.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 34, num episode 4124-----------------------------------
# TRAINING
# Rew:200.14
# Steps per episode:22.07
# Success rate:100.0%
#
# TESTING
# Rew:200.43
# Steps per episode:21.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 35, num episode 4325-----------------------------------
# TRAINING
# Rew:199.44
# Steps per episode:19.91
# Success rate:100.0%
#
# TESTING
# Rew:199.53
# Steps per episode:19.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 36, num episode 4521-----------------------------------
# TRAINING
# Rew:199.65
# Steps per episode:20.41
# Success rate:100.0%
#
# TESTING
# Rew:200.22
# Steps per episode:19.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 37, num episode 4724-----------------------------------
# TRAINING
# Rew:199.42
# Steps per episode:19.66
# Success rate:100.0%
#
# TESTING
# Rew:199.29
# Steps per episode:21.67
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 38, num episode 4928-----------------------------------
# TRAINING
# Rew:199.69
# Steps per episode:19.64
# Success rate:100.0%
#
# TESTING
# Rew:199.03
# Steps per episode:18.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 39, num episode 5130-----------------------------------
# TRAINING
# Rew:199.46
# Steps per episode:19.79
# Success rate:100.0%
#
# TESTING
# Rew:198.15
# Steps per episode:16.67
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 40, num episode 5342-----------------------------------
# TRAINING
# Rew:198.82
# Steps per episode:18.86
# Success rate:100.0%
#
# TESTING
# Rew:198.94
# Steps per episode:21.0
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 41, num episode 5545-----------------------------------
# TRAINING
# Rew:199.56
# Steps per episode:19.68
# Success rate:100.0%
#
# TESTING
# Rew:198.89
# Steps per episode:20.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 42, num episode 5741-----------------------------------
# TRAINING
# Rew:199.43
# Steps per episode:20.46
# Success rate:100.0%
#
# TESTING
# Rew:199.13
# Steps per episode:24.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 43, num episode 5916-----------------------------------
# TRAINING
# Rew:200.28
# Steps per episode:22.82
# Success rate:100.0%
#
# TESTING
# Rew:201.43
# Steps per episode:25.0
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 44, num episode 6080-----------------------------------
# TRAINING
# Rew:201.49
# Steps per episode:24.36
# Success rate:100.0%
#
# TESTING
# Rew:198.41
# Steps per episode:20.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 45, num episode 6292-----------------------------------
# TRAINING
# Rew:199.46
# Steps per episode:18.93
# Success rate:100.0%
#
# TESTING
# Rew:200.57
# Steps per episode:20.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 46, num episode 6494-----------------------------------
# TRAINING
# Rew:199.55
# Steps per episode:19.79
# Success rate:100.0%
#
# TESTING
# Rew:199.09
# Steps per episode:18.67
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 47, num episode 6711-----------------------------------
# TRAINING
# Rew:199.34
# Steps per episode:18.43
# Success rate:100.0%
#
# TESTING
# Rew:199.62
# Steps per episode:20.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 48, num episode 6905-----------------------------------
# TRAINING
# Rew:199.94
# Steps per episode:20.54
# Success rate:100.0%
#
# TESTING
# Rew:200.09
# Steps per episode:23.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 49, num episode 7082-----------------------------------
# TRAINING
# Rew:200.63
# Steps per episode:22.64
# Success rate:100.0%
#
# TESTING
# Rew:199.15
# Steps per episode:16.56
# Success rate:100.0%
#
#
# Model saved into /home/terra/Desktop/unimore/distributed_project/src/policies/PPO/models/looseplay_2agents_densereward_run_2
# VBox(children=(Label(value='0.002 MB of 0.015 MB uploaded\r'), FloatProgress(value=0.14963343567892726, max=1.…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>Testing_reward_per_episode</td><td>▁▁▂▂▂▂▂▂▃▇▇▇████████████████████████████</td></tr><tr><td>Testing_steps_per_episode</td><td>█████████▄▅▅▄▃▂▂▂▂▂▁▁▁▂▁▁▁▂▁▁▁▁▁▁▁▂▂▁▁▁▁</td></tr><tr><td>Testing_success_rate_per_episode</td><td>▁▁▁▁▁▁▁▁▂▆▆▆████████████████████████████</td></tr><tr><td>Training_reward_per_episode</td><td>▁▁▁▂▂▂▂▂▃▄▄▆████████████████████████████</td></tr><tr><td>Training_steps_per_episode</td><td>█████████▇▇▆▄▃▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Training_success_rate_per_episode</td><td>▁▁▁▁▁▁▁▁▂▂▃▅████████████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>7082</td></tr><tr><td>Testing_reward_per_episode</td><td>199.15</td></tr><tr><td>Testing_steps_per_episode</td><td>16.56</td></tr><tr><td>Testing_success_rate_per_episode</td><td>100.0</td></tr><tr><td>Training_reward_per_episode</td><td>200.63</td></tr><tr><td>Training_steps_per_episode</td><td>22.64</td></tr><tr><td>Training_success_rate_per_episode</td><td>100.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">run_2</strong> at: <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/fpehmck5' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/fpehmck5</a><br/> View project at: <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_2agents</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251228_020918-fpehmck5/logs</code>
# wandb version 0.23.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# ========================================
# RUN NUMBER 3/3
# ========================================
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:527: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# (RolloutWorker pid=2762518) /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (RolloutWorker pid=2762518)   from pkg_resources import resource_stream, resource_exists
# 2025-12-28 02:20:05,082	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Tracking run with wandb version 0.17.9
# Run data is saved locally in <code>/home/terra/Desktop/unimore/distributed_project/src/policies/PPO/wandb/run-20251228_022005-xefiqcew</code>
# Syncing run <strong><a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/xefiqcew' target="_blank">run_3</a></strong> to <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_2agents</a>
#  View run at <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/xefiqcew' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/xefiqcew</a>
# ------------------------------------ITERATION 0, num episode 40-------------------------------------
# TRAINING
# Rew:-69.2
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-50.62
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 1, num episode 80-------------------------------------
# TRAINING
# Rew:-61.22
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-27.77
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 2, num episode 120------------------------------------
# TRAINING
# Rew:-50.27
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-32.8
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 3, num episode 160------------------------------------
# TRAINING
# Rew:-38.16
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-27.9
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 4, num episode 200------------------------------------
# TRAINING
# Rew:-27.14
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-12.5
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 5, num episode 240------------------------------------
# TRAINING
# Rew:-18.78
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:0.47
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 6, num episode 280------------------------------------
# TRAINING
# Rew:-13.26
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:18.19
# Steps per episode:95.78
# Success rate:11.0%
#
#
# ------------------------------------ITERATION 7, num episode 320------------------------------------
# TRAINING
# Rew:-9.28
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:1.81
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 8, num episode 360------------------------------------
# TRAINING
# Rew:-3.93
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:49.82
# Steps per episode:98.22
# Success rate:22.0%
#
#
# ------------------------------------ITERATION 9, num episode 400------------------------------------
# TRAINING
# Rew:0.9
# Steps per episode:99.54
# Success rate:1.0%
#
# TESTING
# Rew:41.4
# Steps per episode:87.56
# Success rate:22.0%
#
#
# -----------------------------------ITERATION 10, num episode 441------------------------------------
# TRAINING
# Rew:12.45
# Steps per episode:98.71
# Success rate:4.0%
#
# TESTING
# Rew:76.11
# Steps per episode:94.33
# Success rate:33.0%
#
#
# -----------------------------------ITERATION 11, num episode 487------------------------------------
# TRAINING
# Rew:48.55
# Steps per episode:93.44
# Success rate:20.0%
#
# TESTING
# Rew:179.59
# Steps per episode:68.89
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 12, num episode 541------------------------------------
# TRAINING
# Rew:115.99
# Steps per episode:79.65
# Success rate:53.0%
#
# TESTING
# Rew:184.24
# Steps per episode:47.78
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 13, num episode 609------------------------------------
# TRAINING
# Rew:166.83
# Steps per episode:63.93
# Success rate:80.0%
#
# TESTING
# Rew:206.61
# Steps per episode:57.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 14, num episode 694------------------------------------
# TRAINING
# Rew:187.42
# Steps per episode:49.31
# Success rate:92.0%
#
# TESTING
# Rew:201.97
# Steps per episode:35.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 15, num episode 788------------------------------------
# TRAINING
# Rew:197.98
# Steps per episode:43.07
# Success rate:98.0%
#
# TESTING
# Rew:181.95
# Steps per episode:41.11
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 16, num episode 898------------------------------------
# TRAINING
# Rew:198.65
# Steps per episode:36.18
# Success rate:98.0%
#
# TESTING
# Rew:201.9
# Steps per episode:28.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 17, num episode 1027-----------------------------------
# TRAINING
# Rew:199.14
# Steps per episode:31.06
# Success rate:99.0%
#
# TESTING
# Rew:201.13
# Steps per episode:27.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 18, num episode 1170-----------------------------------
# TRAINING
# Rew:200.78
# Steps per episode:27.91
# Success rate:100.0%
#
# TESTING
# Rew:200.39
# Steps per episode:26.0
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 19, num episode 1318-----------------------------------
# TRAINING
# Rew:200.91
# Steps per episode:27.07
# Success rate:100.0%
#
# TESTING
# Rew:204.29
# Steps per episode:30.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 20, num episode 1464-----------------------------------
# TRAINING
# Rew:197.23
# Steps per episode:27.44
# Success rate:98.0%
#
# TESTING
# Rew:199.42
# Steps per episode:23.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 21, num episode 1628-----------------------------------
# TRAINING
# Rew:200.43
# Steps per episode:24.45
# Success rate:100.0%
#
# TESTING
# Rew:202.08
# Steps per episode:29.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 22, num episode 1792-----------------------------------
# TRAINING
# Rew:200.97
# Steps per episode:24.41
# Success rate:100.0%
#
# TESTING
# Rew:200.4
# Steps per episode:21.0
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 23, num episode 1977-----------------------------------
# TRAINING
# Rew:200.12
# Steps per episode:21.55
# Success rate:100.0%
#
# TESTING
# Rew:200.44
# Steps per episode:21.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 24, num episode 2148-----------------------------------
# TRAINING
# Rew:200.73
# Steps per episode:23.4
# Success rate:100.0%
#
# TESTING
# Rew:199.82
# Steps per episode:18.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 25, num episode 2334-----------------------------------
# TRAINING
# Rew:200.09
# Steps per episode:21.49
# Success rate:100.0%
#
# TESTING
# Rew:201.06
# Steps per episode:24.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 26, num episode 2521-----------------------------------
# TRAINING
# Rew:200.46
# Steps per episode:21.48
# Success rate:100.0%
#
# TESTING
# Rew:201.42
# Steps per episode:19.0
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 27, num episode 2696-----------------------------------
# TRAINING
# Rew:199.42
# Steps per episode:22.75
# Success rate:99.0%
#
# TESTING
# Rew:199.65
# Steps per episode:22.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 28, num episode 2879-----------------------------------
# TRAINING
# Rew:200.62
# Steps per episode:21.92
# Success rate:100.0%
#
# TESTING
# Rew:199.43
# Steps per episode:20.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 29, num episode 3035-----------------------------------
# TRAINING
# Rew:200.13
# Steps per episode:25.67
# Success rate:99.0%
#
# TESTING
# Rew:199.67
# Steps per episode:24.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 30, num episode 3226-----------------------------------
# TRAINING
# Rew:200.04
# Steps per episode:20.91
# Success rate:100.0%
#
# TESTING
# Rew:203.96
# Steps per episode:30.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 31, num episode 3387-----------------------------------
# TRAINING
# Rew:201.42
# Steps per episode:24.8
# Success rate:100.0%
#
# TESTING
# Rew:200.62
# Steps per episode:19.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 32, num episode 3558-----------------------------------
# TRAINING
# Rew:200.8
# Steps per episode:23.43
# Success rate:100.0%
#
# TESTING
# Rew:201.71
# Steps per episode:24.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 33, num episode 3722-----------------------------------
# TRAINING
# Rew:201.66
# Steps per episode:24.41
# Success rate:100.0%
#
# TESTING
# Rew:199.4
# Steps per episode:22.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 34, num episode 3887-----------------------------------
# TRAINING
# Rew:201.93
# Steps per episode:24.21
# Success rate:100.0%
#
# TESTING
# Rew:199.93
# Steps per episode:18.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 35, num episode 4075-----------------------------------
# TRAINING
# Rew:200.02
# Steps per episode:21.27
# Success rate:100.0%
#
# TESTING
# Rew:199.9
# Steps per episode:19.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 36, num episode 4262-----------------------------------
# TRAINING
# Rew:200.19
# Steps per episode:21.45
# Success rate:100.0%
#
# TESTING
# Rew:200.99
# Steps per episode:20.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 37, num episode 4411-----------------------------------
# TRAINING
# Rew:202.92
# Steps per episode:26.79
# Success rate:100.0%
#
# TESTING
# Rew:201.6
# Steps per episode:23.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 38, num episode 4600-----------------------------------
# TRAINING
# Rew:198.36
# Steps per episode:21.12
# Success rate:99.0%
#
# TESTING
# Rew:199.21
# Steps per episode:22.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 39, num episode 4786-----------------------------------
# TRAINING
# Rew:200.38
# Steps per episode:21.45
# Success rate:100.0%
#
# TESTING
# Rew:200.96
# Steps per episode:21.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 40, num episode 4959-----------------------------------
# TRAINING
# Rew:200.75
# Steps per episode:23.2
# Success rate:100.0%
#
# TESTING
# Rew:200.25
# Steps per episode:21.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 41, num episode 5164-----------------------------------
# TRAINING
# Rew:200.09
# Steps per episode:19.57
# Success rate:100.0%
#
# TESTING
# Rew:200.34
# Steps per episode:22.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 42, num episode 5367-----------------------------------
# TRAINING
# Rew:199.37
# Steps per episode:19.68
# Success rate:100.0%
#
# TESTING
# Rew:199.09
# Steps per episode:16.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 43, num episode 5574-----------------------------------
# TRAINING
# Rew:199.16
# Steps per episode:19.28
# Success rate:100.0%
#
# TESTING
# Rew:199.91
# Steps per episode:17.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 44, num episode 5786-----------------------------------
# TRAINING
# Rew:199.23
# Steps per episode:18.85
# Success rate:100.0%
#
# TESTING
# Rew:199.26
# Steps per episode:19.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 45, num episode 5996-----------------------------------
# TRAINING
# Rew:199.1
# Steps per episode:19.14
# Success rate:100.0%
#
# TESTING
# Rew:200.54
# Steps per episode:21.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 46, num episode 6185-----------------------------------
# TRAINING
# Rew:200.57
# Steps per episode:21.15
# Success rate:100.0%
#
# TESTING
# Rew:200.75
# Steps per episode:21.67
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 47, num episode 6374-----------------------------------
# TRAINING
# Rew:200.72
# Steps per episode:21.08
# Success rate:100.0%
#
# TESTING
# Rew:199.59
# Steps per episode:17.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 48, num episode 6582-----------------------------------
# TRAINING
# Rew:200.06
# Steps per episode:19.25
# Success rate:100.0%
#
# TESTING
# Rew:200.39
# Steps per episode:21.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 49, num episode 6790-----------------------------------
# TRAINING
# Rew:200.03
# Steps per episode:19.21
# Success rate:100.0%
#
# TESTING
# Rew:200.43
# Steps per episode:20.33
# Success rate:100.0%
#
#
# Model saved into /home/terra/Desktop/unimore/distributed_project/src/policies/PPO/models/looseplay_2agents_densereward_run_3
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>Testing_reward_per_episode</td><td>▁▂▁▂▂▃▂▄▄▇▇█▇███████████████████████████</td></tr><tr><td>Testing_steps_per_episode</td><td>█████████▅▄▄▃▂▂▂▂▂▁▁▂▁▂▁▂▁▂▂▁▁▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Testing_success_rate_per_episode</td><td>▁▁▁▁▁▂▁▃▃▇▇█▇███████████████████████████</td></tr><tr><td>Training_reward_per_episode</td><td>▁▁▁▂▂▂▃▃▃▄▆▇████████████████████████████</td></tr><tr><td>Training_steps_per_episode</td><td>█████████▇▆▅▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Training_success_rate_per_episode</td><td>▁▁▁▁▁▁▁▁▁▂▅▇████████████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>6790</td></tr><tr><td>Testing_reward_per_episode</td><td>200.43</td></tr><tr><td>Testing_steps_per_episode</td><td>20.33</td></tr><tr><td>Testing_success_rate_per_episode</td><td>100.0</td></tr><tr><td>Training_reward_per_episode</td><td>200.03</td></tr><tr><td>Training_steps_per_episode</td><td>19.21</td></tr><tr><td>Training_success_rate_per_episode</td><td>100.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">run_3</strong> at: <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/xefiqcew' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/xefiqcew</a><br/> View project at: <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_2agents</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251228_022005-xefiqcew/logs</code>
# wandb version 0.23.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# FINISHED

# %% [markdown]
# ## **Save the agents model**

# %%
import os
def save_model(ppo, file_name):
    current_dir = os.getcwd()
    model_dir = os.path.join(current_dir, "models")
    checkpoint_name = os.path.join(model_dir, file_name)
    ppo.save(checkpoint_name)

    print(f"Model saved into {checkpoint_name}")

# %% [markdown]
# ## **Load agents**

# %%
from ray.rllib.algorithms.ppo import PPO
import os

def load_model(file_name):
    current_dir = os.getcwd()
    model_dir = os.path.join(current_dir, "models")
    checkpoint_name = os.path.join(model_dir, file_name)

    ppo = PPO.from_checkpoint(checkpoint_name)
    return ppo

# %%
import os

current_dir = os.getcwd()
model_dir = os.path.join(current_dir, "models")

for filename in os.listdir(model_dir):
    if "best" in filename and under_examination in filename:
        matching_file = filename
        break

file_path = os.path.join(model_dir, matching_file)
ppo = load_model(file_path)

# %% [markdown]
# ## **Graphically test the agent**

# %%
env = MyGridWorld(grid_size=15, n_agents=4, render_mode="human")
obs, _ = env.reset()

i = 0
while i < 3:
    actions = {}

    for agent_id, agent_obs in obs.items():
        actions[agent_id] = ppo.compute_single_action(
            agent_obs,
            policy_id=agent_id,
            explore=True
        )

    obs, rewards, terminations, truncations, infos = env.step(actions)

    if any(terminations.values()) or any(truncations.values()):
        obs, _ = env.reset()
        i += 1

env.close()
