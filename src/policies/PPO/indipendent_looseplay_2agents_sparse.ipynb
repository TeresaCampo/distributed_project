# %% [markdown]
# # **My custom env - dense reward**
#
# **Environment classe pasted here in order to make it accessible to all the workers of Ray.**
#
# It is equivalent to /myenv_6_dense_reward.py

# %%
under_examination = "looseplay_2agents_sparsereward"

# %%
import sys, os
from pathlib import Path

current_dir = Path(os.getcwd()) 
pointed_dir = current_dir

while True:
    if pointed_dir.is_dir() and "distributed_project" == str(pointed_dir).split("/")[-1]:
        project_dir = pointed_dir
        print(f"Project dir found: {project_dir}")
        break
    
    if pointed_dir == pointed_dir.parent:
        print("Error while looking for 'distributed_project', project dir")
        break
        
    pointed_dir = pointed_dir.parent
# Out:
# Project dir found: /home/terra/Desktop/unimore/distributed_project

# %%
import numpy as np
import functools
import gymnasium as gym
from gymnasium import spaces
from pettingzoo import ParallelEnv
import pygame 
import os
from collections import defaultdict
import random

SPRITES_DIR = f"{project_dir}/sprites"

class MyGridWorld(ParallelEnv):
    metadata = {"render_modes": ["human"], "name": "custom_grid_v0"}

    def __init__(self, render_mode=None, n_agents = 2, grid_size=15):
        if grid_size<8:
            print("Error, need to insert a grid size greater or equal to 8")
        self.grid_size = grid_size
        self.render_mode = render_mode

        ######## Agents, fixed components, and forbidden positions
        self.possible_agents = [f"agent{i}" for i in range(1, n_agents+1)]
        self.agents = self.possible_agents[:]
        self.gate_open = False

        self.fixed_components = {
            "button1":  {"pos": np.array([self.grid_size//2+2, 1+3+2]), "file": "button.png"},
            "button2":  {"pos": np.array([self.grid_size//2+2, 1+1]), "file": "button.png"},

            "gate_open":  {"pos": np.array([self.grid_size//2, 1+3]), "file": "gate_open.png"},
            "gate_close":  {"pos": np.array([self.grid_size//2, 1+3]), "file": "gate_close.png"}   
        }
        self.button1_pos = self.fixed_components["button1"]["pos"]
        self.button2_pos = self.fixed_components["button2"]["pos"]

        self.gate_pos = self.fixed_components["gate_open"]["pos"] 
        self.target_final_pos = self.gate_pos+[0, -1]

        self.x_range = (1, self.grid_size-1-1)
        self.y_range = (1+3+1, self.grid_size-1-1)
        self.forbidden_position = {tuple(self.button1_pos)}    

        self.max_cycles = 100
        self.current_cycles = 0
        ######## Pygame graphic configuration 
        self.window_size = 810
        self.cell_size = self.window_size // self.grid_size
        self.window = None
        self.clock = None
        
        # Walls
        self.grid_map = np.zeros((self.grid_size, self.grid_size))
        self.grid_map[0, :] = 1
        self.grid_map[:, 0] = 1
        self.grid_map[-1, :] = 1
        self.grid_map[:, -1] = 1
        self.grid_map[ :, 1+3] = 1

        # Sprites 
        self.agent_sprites = {}
        self.component_sprites = {}

        ######## Action space and observation space
        # Five possible actions in each grid: stay(0), up(1), down(2), left(3), right(4)
        self.action_spaces = {a: spaces.Discrete(5) for a in self.possible_agents}
        OBSERVATION_DIM = 2*(len(self.agents)-1)+3*2+1
        self.observation_spaces = {
            a: spaces.Box(low=-(self.grid_size-1), high=self.grid_size-1, shape=(OBSERVATION_DIM,), dtype=np.float32) 
            for a in self.possible_agents
        }
        self.state_spaces = {a: None for a in self.possible_agents}

    def state(self):
        observations = self.gather_observations()
        global_state = []
        
        for agent in self.possible_agents:
            if agent in observations:
                global_state.append(observations[agent])
            else:
                # Se l'agente è morto/uscito, usa zeri
                dim = self.observation_spaces[agent].shape[0]
                global_state.append(np.zeros(dim, dtype=np.float32))
                
        return np.concatenate(global_state)

    # Boilerplate PettingZoo
    def observation_space(self, agent): return self.observation_spaces[agent]
    def action_space(self, agent): return self.action_spaces[agent]

    '''
    Step in the environment
    '''
    def step(self, actions):
        if not self.agents: return {}, {}, {}, {}, {}
        self.current_cycles += 1
        
        rewards = {a: -1 for a in self.agents}

        terminations = {a: False for a in self.agents}
        truncations = {a: False for a in self.agents}
        infos = {a: {"is_success":False} for a in self.agents}
        
        desired_positions = {}      
        button_pressed = False
        agents_desire_gate = []
        for agent, action in actions.items():
            current_pos = self.agent_positions[agent].copy()
            target_pos = current_pos.copy()

            if action == 1: target_pos[1] -= 1 
            elif action == 2: target_pos[1] += 1
            elif action == 3: target_pos[0] -= 1
            elif action == 4: target_pos[0] += 1

            # Monitor button, gate and walls
            is_wall = self.grid_map[target_pos[0], target_pos[1]] == 1
            is_gate = (target_pos == self.gate_pos).all()
            is_button = (target_pos == self.button1_pos).all() or (target_pos == self.button2_pos).all()
            
            if is_button:
                button_pressed = True
            if is_gate:
                agents_desire_gate.append((agent, current_pos))
            
            if is_wall and not is_gate:
                desired_positions[agent] = current_pos 
            else:
                desired_positions[agent] = target_pos
                        
        # If gate was open remove a wall, if gate was closed update the position of those who wanted to cross it
        self.gate_open = button_pressed
        if self.gate_open:
            self.grid_map[self.gate_pos[0], self.gate_pos[1]] = 0
        else:
            self.grid_map[self.gate_pos[0], self.gate_pos[1]] = 1
            for a in agents_desire_gate:
                agent = a[0]
                current_pos = a[1]
                desired_positions[agent] = current_pos 

        # Check for conflicts (more than one agents have the same desired position)
        final_positions = self.agent_positions.copy()
        target_counts = defaultdict(list)         # Key: tuple(x, y) of desired positions, Value: list of agents desiring it
        for agent, pos in desired_positions.items():
            pos_tuple = tuple(pos)
            target_counts[pos_tuple].append(agent)

        # Solve eventual conflicts
        for pos_tuple, agents_at_target in target_counts.items():      
            # Case 1: no contended position
            if len(agents_at_target) == 1:
                agent = agents_at_target[0]
                final_positions[agent] = desired_positions[agent]
            
            # Case 2: contended position
            else:
                one_agent_already_here_not_moving = None
                for agent in agents_at_target:
                    if tuple(self.agent_positions[agent]) == pos_tuple:
                        one_agent_already_here_not_moving = agent
                        break
                
                winning_agent = one_agent_already_here_not_moving if one_agent_already_here_not_moving else random.choice(agents_at_target)
                final_positions[winning_agent] = desired_positions[winning_agent]
                
                agents_at_target.remove(winning_agent)
                for losing_agent in agents_at_target[:]:
                    final_positions[losing_agent] = self.agent_positions[losing_agent] 
        self.agent_positions = final_positions

        # Negative reward if an agent is on the bottom area and is not pressing the button
        agents_upper_area = 0
        for a, pos in self.agent_positions.items():
            dist_target = np.linalg.norm(pos - self.target_final_pos)
            if pos[1]<4:                                # Agent on upper area
                rewards[a] = +1
                agents_upper_area+=1
            if (pos == self.button2_pos).all():     # Agent on button
                rewards[a] +=1
            if (pos == self.button1_pos).all():     # Agent on button
                rewards[a] += 1    
       
        if agents_upper_area == len(self.agents):
            rewards = {a: +100 for a in self.agents}
            terminations = {a: True for a in self.agents}
            infos = {a: {"is_success":True} for a in self.agents}

        if self.current_cycles >= self.max_cycles:
            truncations= {a: True for a in self.agents}
            rewards = {a: -100 for a in self.agents}

            
        
        if self.render_mode == "human":
            self.render()
            
        final_obs = self.gather_observations()
        self.agents = [a for a in self.agents if not terminations[a]]
        return final_obs, rewards, terminations, truncations, infos
   
    '''
    Determines initial condition of the simulation
    '''

    def generate_valid_position(self):
        while True:
            x = np.random.randint(self.x_range[0], self.x_range[1])
            y = np.random.randint(self.y_range[0], self.y_range[1])
            new_position = tuple((x, y))

            if new_position not in self.forbidden_position:
                return new_position
            
    def generate_set_initial_positions(self):
        set_initial_positions = set()
        while len(set_initial_positions)<len(self.possible_agents):
            new_pos = self.generate_valid_position()
            set_initial_positions.add(new_pos)
        return set_initial_positions
    
    def generate_test_values(self, agent_num):
        if agent_num==1:
            return[7, 9]
        else:
            return [9,13]

    def reset(self, seed=None, options=None):
        self.agents = self.possible_agents[:]
        set_initial_positions = list(self.generate_set_initial_positions())
        self.current_cycles = 0

        self.agent_positions = {}
        for i, agent_id in enumerate(self.agents):
            self.agent_positions[agent_id] = np.array(set_initial_positions[i])
        
        # To visualize the reset position if "human" mode on
        if self.render_mode == "human":
            self.render()         

        return self.gather_observations(), {a: {} for a in self.agents}
    
    '''
    Observation: [my_cur_pos, (other_cur) x number of other agents, button_pos, gate_pos, gate_open (1|0)]    '''
    def gather_observations(self):
        gate_status_info = np.array([int(self.gate_open)], dtype=np.float32)
        observations = {}
        for observing_agent in self.agents:
            obs_segments = []
            observing_agent_pos = self.agent_positions[observing_agent]
            
            for other_agent in self.agents:
                if other_agent != observing_agent:
                    obs_segments.append(self.agent_positions[other_agent] - observing_agent_pos)
            obs_segments.append(self.button1_pos- observing_agent_pos)
            obs_segments.append(self.button2_pos- observing_agent_pos)
            obs_segments.append(self.gate_pos -observing_agent_pos)
            obs_segments.append(gate_status_info)
            observations[observing_agent] = np.concatenate(obs_segments, dtype=np.float32)
        return observations

    '''
    Functions for Sprite rendering and loading
    '''    
    def _create_missing_sprite(self, text, bg_color, border_color = (0,0,0)):  
        error_sprite = pygame.Surface((self.cell_size, self.cell_size), pygame.SRCALPHA)
        error_sprite.fill((0, 0, 0, 0))
        center = (self.cell_size // 2, self.cell_size // 2)
        radius = int(self.cell_size * 0.4)
        pygame.draw.circle(error_sprite, bg_color, center, radius) 
        pygame.draw.circle(error_sprite, border_color, center, radius, 2)
        
        # Add text label
        try:
            font_size = int(self.cell_size * 0.22)
            font = pygame.font.Font(None, font_size)   
            text_color = (0, 0, 0) if sum(bg_color) > 300 else (255, 255, 255) 
            text_surface = font.render(text, True, text_color)
            text_rect = text_surface.get_rect(center=center)
            error_sprite.blit(text_surface, text_rect)
            
        except Exception as e:
            print(f"WARNING: Error while writing text inside missing sprite {text}. A missing sprite without text label will be used for this simulation.")
            pass
            
        return error_sprite
    
    def _load_and_scale_sprite(self, filename, component_name):
        path = os.path.join(SPRITES_DIR, filename)
    
        try:
            image = pygame.image.load(path).convert_alpha() 
            scaled_size = int(self.cell_size )
            return pygame.transform.scale(image, (scaled_size, scaled_size))
            
        except (FileNotFoundError, pygame.error) as e:
            print(f"WARNING! Sprite image {path} not found. Using default sprite for this simulation.")
    
            text = component_name.upper() if component_name else "ERROR"
            bg_color = (100, 100, 255) if "AGENT" in text else (128,128,128) # Blue agent, Gray fixed components
            return self._create_missing_sprite(text, bg_color)

    def render(self):
        if self.render_mode is None:
            return

        if self.window is None:
            pygame.init()
            pygame.display.init()
            pygame.font.init()
            self.window = pygame.display.set_mode((self.window_size, self.window_size))
            
            for agent_name in self.agents:
               # self.agent_sprites[agent_name] = self._load_and_scale_sprite(f"{agent_name}.png", agent_name)
               self.agent_sprites[agent_name] = self._load_and_scale_sprite(".png", agent_name)

            for name, data in self.fixed_components.items():
                self.component_sprites[name] = self._load_and_scale_sprite(data["file"], name)

                 
        if self.clock is None:
            self.clock = pygame.time.Clock()

        canvas = pygame.Surface((self.window_size, self.window_size))
        canvas.fill((220, 220, 220)) 
        pix_square_size = self.cell_size 
        sprite_offset = (pix_square_size - int(pix_square_size * 0.8)) // 2

        # Render walls
        for x in range(self.grid_size):
            for y in range(self.grid_size):
                if self.grid_map[x, y] == 1:
                    pygame.draw.rect(
                        canvas, 
                        (50, 50, 50),
                        pygame.Rect(x * pix_square_size, y * pix_square_size, pix_square_size, pix_square_size)
                    )

        # Render fixed components and agents
        for name, data in self.fixed_components.items():
            if self.gate_open and name == "gate_close":
                continue
            pos = data["pos"]
            x_coord = pos[0] * pix_square_size + sprite_offset
            y_coord = pos[1] * pix_square_size + sprite_offset
            sprite = self.component_sprites[name]
            canvas.blit(sprite, (x_coord, y_coord))

        for agent in self.agents:
            pos = self.agent_positions[agent]            
            x_coord = pos[0] * pix_square_size + sprite_offset
            y_coord = pos[1] * pix_square_size + sprite_offset
            
            sprite = self.agent_sprites[agent]
            canvas.blit(sprite, (x_coord, y_coord))

        # Render the grid
        for x in range(self.grid_size + 1):
            pygame.draw.line(
                canvas, 0, (0, pix_square_size * x), (self.window_size, pix_square_size * x), width=2
            )
            pygame.draw.line(
                canvas, 0, (pix_square_size * x, 0), (pix_square_size * x, self.window_size), width=2
            )

        # Display the render
        self.window.blit(canvas, canvas.get_rect())
        pygame.event.pump()
        pygame.display.update()
        self.clock.tick(4) # FPS

    def close(self):
        if self.window is not None:
            pygame.display.quit()
            pygame.quit()

# %% [markdown]
# **Wrap the envornment in a PettingZoo env (for compatibility with Ray) and register it on Ray lib**

# %%
from ray.rllib.env.wrappers.pettingzoo_env import ParallelPettingZooEnv
from ray.tune.registry import register_env

def env_creator(config):
    return ParallelPettingZooEnv(
        MyGridWorld(render_mode=None, n_agents=2)
    )

register_env("my_gridworld", env_creator)

# %% [markdown]
# ## **IPPO - loose play settings**

# %% [markdown]
# Callback to register episode success rate

# %%
from ray.rllib.algorithms.callbacks import DefaultCallbacks

class SuccessMetricCallback(DefaultCallbacks):
    def on_episode_end(self, *, worker, base_env, policies, episode, **kwargs):
        
        is_success = False
        one_agent_id = list(episode.get_agents())[-1]
        last_info = episode.last_info_for(one_agent_id)
        is_success = last_info["is_success"]
       
        episode.custom_metrics["success_rate"] = int(is_success)

# %%
from ray.rllib.algorithms.ppo import PPOConfig

dummy_env = env_creator({}) 
agent_ids = dummy_env.possible_agents 
print(f"Agents in the env: {agent_ids}")
dummy_env.close()

config = (
    PPOConfig()
    .environment(env="my_gridworld")
    .env_runners(num_env_runners=0)
    .callbacks(callbacks_class=SuccessMetricCallback)
    
    .multi_agent(
        policies=set(agent_ids),
        policy_mapping_fn=lambda agent_id, *args, **kwargs: agent_id,
    )
    
    .api_stack(
        enable_rl_module_and_learner=False,
        enable_env_runner_and_connector_v2=False
    )
    .evaluation(
        evaluation_interval=1,
        evaluation_duration=10,
        evaluation_duration_unit="episodes",
        evaluation_num_env_runners=1,
        evaluation_config={
            "explore": True,
        }
    )
    .training(
        lr=1e-4,
        train_batch_size_per_learner=4000, 
        num_epochs=10,        
        entropy_coeff=0.01,
        kl_coeff=0.2,
        kl_target=0.01,
        gamma=0.995

    )
)
# Out:
# Agents in the env: ['agent1', 'agent2']

# %% [markdown]
# ## **Wandb - One run of training**

# %%
import wandb
#wandb.init(project="gridworld_looseplay_2agents", name="densereward")
ppo = config.build_algo()
num_total_episodes = 0
for i in range(50):
    result = ppo.train()
    num_total_episodes += result['env_runners']['num_episodes']
    
    print(f"ITERATION {i}, num episode {num_total_episodes}".center(100,"-"))
    train_rew = round(result['env_runners']['episode_return_mean'], 2)
    train_steps_episode = round(result['env_runners']['episode_len_mean'], 2)
    train_success_rate = round(result['env_runners']['custom_metrics'].get('success_rate_mean', 0), 2) * 100
    print(f"""TRAINING\nRew:{train_rew} \nSteps per episode:{train_steps_episode} \nSuccess rate:{train_success_rate}%\n""")

    if 'evaluation' in result:
        testing_rew = round(result['evaluation']['env_runners']['episode_return_mean'], 2)
        testing_steps_episode = round(result['evaluation']['env_runners']['episode_len_mean'], 2)
        testing_success_rate = round(result['evaluation']['env_runners']['custom_metrics'].get('success_rate_mean', 0), 2) * 100
        print(f"""TESTING\nRew:{testing_rew} \nSteps per episode:{testing_steps_episode} \nSuccess rate:{testing_success_rate}%\n\n""")

    log_data = {
        "Episodes": num_total_episodes,

        "Training_steps_per_episode": train_steps_episode,
        "Training_success_rate_per_episode": train_success_rate,
        "Training_reward_per_episode": train_rew,

        "Testing_steps_per_episode": testing_steps_episode,
        "Testing_success_rate_per_episode": testing_success_rate,
        "Testing_reward_per_episode": testing_rew
    }
    #wandb.log(log_data)
#wandb.finish()

# %% [markdown]
# ## **Wandb, 3 runs of training to generate esteme**

# %%
import wandb
group_name = "sparse"

for run_idx in range(1,4):
    print(f"\n{'='*40}")
    print(f"RUN NUMBER {run_idx}/3")
    print(f"{'='*40}\n")

    ppo = config.build_algo()
    wandb.init(
        project="gridworld_looseplay_2agents",
        group=group_name,           
        name=f"run_{run_idx}",    
        reinit=True 
    )
    file_name = f"{under_examination}_run_{run_idx}"
    
    num_total_episodes = 0
    for i in range(50):
        result = ppo.train()
        num_total_episodes += result['env_runners']['num_episodes']
        
        print(f"ITERATION {i}, num episode {num_total_episodes}".center(100,"-"))
        train_rew = round(result['env_runners']['episode_return_mean'], 2)
        train_steps_episode = round(result['env_runners']['episode_len_mean'], 2)
        train_success_rate = round(result['env_runners']['custom_metrics'].get('success_rate_mean', 0), 2) * 100
        print(f"""TRAINING\nRew:{train_rew} \nSteps per episode:{train_steps_episode} \nSuccess rate:{train_success_rate}%\n""")

        if 'evaluation' in result:
            testing_rew = round(result['evaluation']['env_runners']['episode_return_mean'], 2)
            testing_steps_episode = round(result['evaluation']['env_runners']['episode_len_mean'], 2)
            testing_success_rate = round(result['evaluation']['env_runners']['custom_metrics'].get('success_rate_mean', 0), 2) * 100
            print(f"""TESTING\nRew:{testing_rew} \nSteps per episode:{testing_steps_episode} \nSuccess rate:{testing_success_rate}%\n\n""")

        log_data = {
            "Episodes": num_total_episodes,

            "Training_steps_per_episode": train_steps_episode,
            "Training_success_rate_per_episode": train_success_rate,
            "Training_reward_per_episode": train_rew,

            "Testing_steps_per_episode": testing_steps_episode,
            "Testing_success_rate_per_episode": testing_success_rate,
            "Testing_reward_per_episode": testing_rew
        }
        wandb.log(log_data)
    save_model(ppo, file_name)
    wandb.finish()

print("FINISHED")
# Out:
# ========================================
# RUN NUMBER 1/3
# ========================================
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:527: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/google/api_core/_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2025-12-28 02:33:51,268	INFO worker.py:2007 -- Started a local Ray instance.
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/_private/worker.py:2046: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# [2025-12-28 02:33:53,193 E 2950242 2950242] core_worker.cc:2223: Actor with class name: 'RolloutWorker' and ID: 'eea6afdb1a362ec46578ee8801000000' has constructor arguments in the object store and max_restarts > 0. If the arguments in the object store go out of scope or are lost, the actor restart will fail. See https://github.com/ray-project/ray/issues/53727 for more details.
# (RolloutWorker pid=2950466) /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (RolloutWorker pid=2950466)   from pkg_resources import resource_stream, resource_exists
# 2025-12-28 02:33:56,436	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: 299011 (299011-unimore). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.17.9
# Run data is saved locally in <code>/home/terra/Desktop/unimore/distributed_project/src/policies/PPO/wandb/run-20251228_023357-q4mb7qf0</code>
# Syncing run <strong><a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/q4mb7qf0' target="_blank">run_1</a></strong> to <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_2agents</a>
#  View run at <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/q4mb7qf0' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/q4mb7qf0</a>
# 2025-12-28 02:34:09,393	WARNING sgd.py:55 -- DeprecationWarning: `_get_slice_indices` has been deprecated. This will raise an error in the future!
# ------------------------------------ITERATION 0, num episode 40-------------------------------------
# TRAINING
# Rew:-395.62
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-397.1
# Steps per episode:100.0
# Success rate:0.0%
# (pid=gcs_server) [2025-12-28 02:34:20,478 E 2950294 2950294] (gcs_server) gcs_server.cc:303: Failed to establish connection to the event+metrics exporter agent. Events and metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (raylet) [2025-12-28 02:34:21,193 E 2950408 2950408] (raylet) main.cc:1032: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (RolloutWorker pid=2950466) [2025-12-28 02:34:21,905 E 2950466 2950599] core_worker_process.cc:842: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# [2025-12-28 02:34:22,141 E 2950242 2950461] core_worker_process.cc:842: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# ------------------------------------ITERATION 1, num episode 80-------------------------------------
# TRAINING
# Rew:-396.26
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-397.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 2, num episode 120------------------------------------
# TRAINING
# Rew:-396.75
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-396.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 3, num episode 160------------------------------------
# TRAINING
# Rew:-396.97
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-395.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 4, num episode 200------------------------------------
# TRAINING
# Rew:-396.85
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-395.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 5, num episode 240------------------------------------
# TRAINING
# Rew:-396.55
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-396.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 6, num episode 280------------------------------------
# TRAINING
# Rew:-396.02
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-395.44
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 7, num episode 320------------------------------------
# TRAINING
# Rew:-394.69
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-395.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 8, num episode 360------------------------------------
# TRAINING
# Rew:-394.33
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-393.44
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 9, num episode 400------------------------------------
# TRAINING
# Rew:-392.61
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-394.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 10, num episode 440------------------------------------
# TRAINING
# Rew:-391.73
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-380.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 11, num episode 480------------------------------------
# TRAINING
# Rew:-388.31
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-380.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 12, num episode 520------------------------------------
# TRAINING
# Rew:-382.39
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-394.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 13, num episode 560------------------------------------
# TRAINING
# Rew:-382.45
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-393.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 14, num episode 600------------------------------------
# TRAINING
# Rew:-381.61
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-378.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 15, num episode 640------------------------------------
# TRAINING
# Rew:-378.74
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-359.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 16, num episode 680------------------------------------
# TRAINING
# Rew:-372.39
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-300.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 17, num episode 720------------------------------------
# TRAINING
# Rew:-350.09
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-269.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 18, num episode 760------------------------------------
# TRAINING
# Rew:-322.16
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-251.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 19, num episode 800------------------------------------
# TRAINING
# Rew:-290.5
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-248.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 20, num episode 840------------------------------------
# TRAINING
# Rew:-273.99
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-259.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 21, num episode 880------------------------------------
# TRAINING
# Rew:-267.88
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-274.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 22, num episode 920------------------------------------
# TRAINING
# Rew:-271.73
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-308.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 23, num episode 960------------------------------------
# TRAINING
# Rew:-270.05
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-259.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 24, num episode 1000-----------------------------------
# TRAINING
# Rew:-260.65
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-250.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 25, num episode 1040-----------------------------------
# TRAINING
# Rew:-241.87
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-197.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 26, num episode 1080-----------------------------------
# TRAINING
# Rew:-222.57
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-207.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 27, num episode 1120-----------------------------------
# TRAINING
# Rew:-209.06
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-186.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 28, num episode 1160-----------------------------------
# TRAINING
# Rew:-197.56
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-171.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 29, num episode 1200-----------------------------------
# TRAINING
# Rew:-179.43
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-147.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 30, num episode 1240-----------------------------------
# TRAINING
# Rew:-164.15
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-146.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 31, num episode 1280-----------------------------------
# TRAINING
# Rew:-150.95
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-133.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 32, num episode 1320-----------------------------------
# TRAINING
# Rew:-141.2
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-133.44
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 33, num episode 1360-----------------------------------
# TRAINING
# Rew:-133.56
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-134.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 34, num episode 1400-----------------------------------
# TRAINING
# Rew:-127.98
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-124.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 35, num episode 1440-----------------------------------
# TRAINING
# Rew:-123.37
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-124.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 36, num episode 1480-----------------------------------
# TRAINING
# Rew:-118.69
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-110.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 37, num episode 1520-----------------------------------
# TRAINING
# Rew:-115.72
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-113.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 38, num episode 1560-----------------------------------
# TRAINING
# Rew:-115.85
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-110.44
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 39, num episode 1600-----------------------------------
# TRAINING
# Rew:-113.21
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-104.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 40, num episode 1640-----------------------------------
# TRAINING
# Rew:-111.22
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-113.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 41, num episode 1680-----------------------------------
# TRAINING
# Rew:-108.35
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-110.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 42, num episode 1720-----------------------------------
# TRAINING
# Rew:-106.69
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-95.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 43, num episode 1760-----------------------------------
# TRAINING
# Rew:-103.35
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-103.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 44, num episode 1800-----------------------------------
# TRAINING
# Rew:-104.09
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-109.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 45, num episode 1840-----------------------------------
# TRAINING
# Rew:-105.36
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-106.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 46, num episode 1880-----------------------------------
# TRAINING
# Rew:-105.54
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-96.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 47, num episode 1920-----------------------------------
# TRAINING
# Rew:-102.66
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-92.44
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 48, num episode 1960-----------------------------------
# TRAINING
# Rew:-98.06
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-98.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 49, num episode 2000-----------------------------------
# TRAINING
# Rew:-97.3
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-95.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# Model saved into /home/terra/Desktop/unimore/distributed_project/src/policies/PPO/models/looseplay_2agents_sparsereward_run_1
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>Testing_reward_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▂▃▄▄▄▄▃▄▆▅▆▆▇▇▇▇▇███████████</td></tr><tr><td>Testing_steps_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Testing_success_rate_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Training_reward_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▃▄▄▄▄▅▅▅▆▆▇▇▇▇███████████</td></tr><tr><td>Training_steps_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Training_success_rate_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>2000</td></tr><tr><td>Testing_reward_per_episode</td><td>-95.78</td></tr><tr><td>Testing_steps_per_episode</td><td>100.0</td></tr><tr><td>Testing_success_rate_per_episode</td><td>0.0</td></tr><tr><td>Training_reward_per_episode</td><td>-97.3</td></tr><tr><td>Training_steps_per_episode</td><td>100.0</td></tr><tr><td>Training_success_rate_per_episode</td><td>0.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">run_1</strong> at: <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/q4mb7qf0' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/q4mb7qf0</a><br/> View project at: <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_2agents</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251228_023357-q4mb7qf0/logs</code>
# wandb version 0.23.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# ========================================
# RUN NUMBER 2/3
# ========================================
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:527: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# (RolloutWorker pid=2950463) /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (RolloutWorker pid=2950463)   from pkg_resources import resource_stream, resource_exists
# (pid=2950471) [2025-12-28 02:34:22,097 E 2950471 2950968] core_worker_process.cc:842: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14 [repeated 11x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# 2025-12-28 02:45:54,160	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Tracking run with wandb version 0.17.9
# Run data is saved locally in <code>/home/terra/Desktop/unimore/distributed_project/src/policies/PPO/wandb/run-20251228_024554-2fdfbtbb</code>
# Syncing run <strong><a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/2fdfbtbb' target="_blank">run_2</a></strong> to <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_2agents</a>
#  View run at <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/2fdfbtbb' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/2fdfbtbb</a>
# ------------------------------------ITERATION 0, num episode 40-------------------------------------
# TRAINING
# Rew:-395.85
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-396.6
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 1, num episode 80-------------------------------------
# TRAINING
# Rew:-395.3
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-397.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 2, num episode 120------------------------------------
# TRAINING
# Rew:-395.3
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-396.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 3, num episode 160------------------------------------
# TRAINING
# Rew:-393.17
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-393.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 4, num episode 200------------------------------------
# TRAINING
# Rew:-392.86
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-390.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 5, num episode 240------------------------------------
# TRAINING
# Rew:-392.42
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-389.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 6, num episode 280------------------------------------
# TRAINING
# Rew:-391.5
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-387.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 7, num episode 320------------------------------------
# TRAINING
# Rew:-388.52
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-367.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 8, num episode 360------------------------------------
# TRAINING
# Rew:-383.76
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-363.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 9, num episode 400------------------------------------
# TRAINING
# Rew:-375.78
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-344.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 10, num episode 440------------------------------------
# TRAINING
# Rew:-369.29
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-351.44
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 11, num episode 480------------------------------------
# TRAINING
# Rew:-353.43
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-292.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 12, num episode 520------------------------------------
# TRAINING
# Rew:-327.46
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-238.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 13, num episode 560------------------------------------
# TRAINING
# Rew:-288.6
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-235.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 14, num episode 600------------------------------------
# TRAINING
# Rew:-259.71
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-218.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 15, num episode 640------------------------------------
# TRAINING
# Rew:-237.54
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-213.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 16, num episode 680------------------------------------
# TRAINING
# Rew:-219.23
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-195.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 17, num episode 720------------------------------------
# TRAINING
# Rew:-205.31
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-179.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 18, num episode 760------------------------------------
# TRAINING
# Rew:-187.51
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-159.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 19, num episode 800------------------------------------
# TRAINING
# Rew:-175.83
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-149.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 20, num episode 840------------------------------------
# TRAINING
# Rew:-162.88
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-145.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 21, num episode 880------------------------------------
# TRAINING
# Rew:-152.93
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-150.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 22, num episode 920------------------------------------
# TRAINING
# Rew:-145.49
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-129.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 23, num episode 960------------------------------------
# TRAINING
# Rew:-140.69
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-132.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 24, num episode 1000-----------------------------------
# TRAINING
# Rew:-138.57
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-135.44
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 25, num episode 1040-----------------------------------
# TRAINING
# Rew:-135.16
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-131.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 26, num episode 1080-----------------------------------
# TRAINING
# Rew:-131.46
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-128.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 27, num episode 1120-----------------------------------
# TRAINING
# Rew:-128.8
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-124.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 28, num episode 1160-----------------------------------
# TRAINING
# Rew:-126.55
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-123.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 29, num episode 1200-----------------------------------
# TRAINING
# Rew:-122.79
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-120.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 30, num episode 1240-----------------------------------
# TRAINING
# Rew:-120.76
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-120.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 31, num episode 1280-----------------------------------
# TRAINING
# Rew:-121.37
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-117.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 32, num episode 1320-----------------------------------
# TRAINING
# Rew:-120.83
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-117.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 33, num episode 1360-----------------------------------
# TRAINING
# Rew:-119.9
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-119.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 34, num episode 1400-----------------------------------
# TRAINING
# Rew:-119.01
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-114.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 35, num episode 1440-----------------------------------
# TRAINING
# Rew:-116.19
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-114.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 36, num episode 1480-----------------------------------
# TRAINING
# Rew:-115.25
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-108.44
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 37, num episode 1520-----------------------------------
# TRAINING
# Rew:-113.68
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-105.44
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 38, num episode 1560-----------------------------------
# TRAINING
# Rew:-112.95
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-133.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 39, num episode 1600-----------------------------------
# TRAINING
# Rew:-120.6
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-130.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 40, num episode 1640-----------------------------------
# TRAINING
# Rew:-127.82
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-128.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 41, num episode 1680-----------------------------------
# TRAINING
# Rew:-130.09
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-118.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 42, num episode 1720-----------------------------------
# TRAINING
# Rew:-125.95
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-114.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 43, num episode 1760-----------------------------------
# TRAINING
# Rew:-120.37
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-117.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 44, num episode 1800-----------------------------------
# TRAINING
# Rew:-115.25
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-120.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 45, num episode 1840-----------------------------------
# TRAINING
# Rew:-113.92
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-114.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 46, num episode 1880-----------------------------------
# TRAINING
# Rew:-116.63
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-113.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 47, num episode 1920-----------------------------------
# TRAINING
# Rew:-117.73
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-114.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 48, num episode 1960-----------------------------------
# TRAINING
# Rew:-118.41
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-115.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 49, num episode 2000-----------------------------------
# TRAINING
# Rew:-116.82
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-113.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# Model saved into /home/terra/Desktop/unimore/distributed_project/src/policies/PPO/models/looseplay_2agents_sparsereward_run_2
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>Testing_reward_per_episode</td><td>▁▁▁▁▁▁▂▂▂▄▅▅▅▆▆▇▇▇▇▇▇▇█████████▇▇███████</td></tr><tr><td>Testing_steps_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Testing_success_rate_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Training_reward_per_episode</td><td>▁▁▁▁▁▁▁▁▂▂▃▄▅▅▆▆▇▇▇▇▇███████████████████</td></tr><tr><td>Training_steps_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Training_success_rate_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>2000</td></tr><tr><td>Testing_reward_per_episode</td><td>-113.0</td></tr><tr><td>Testing_steps_per_episode</td><td>100.0</td></tr><tr><td>Testing_success_rate_per_episode</td><td>0.0</td></tr><tr><td>Training_reward_per_episode</td><td>-116.82</td></tr><tr><td>Training_steps_per_episode</td><td>100.0</td></tr><tr><td>Training_success_rate_per_episode</td><td>0.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">run_2</strong> at: <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/2fdfbtbb' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/2fdfbtbb</a><br/> View project at: <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_2agents</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251228_024554-2fdfbtbb/logs</code>
# wandb version 0.23.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# ========================================
# RUN NUMBER 3/3
# ========================================
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:527: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# (RolloutWorker pid=2950468) /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (RolloutWorker pid=2950468)   from pkg_resources import resource_stream, resource_exists
# 2025-12-28 02:57:32,045	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Tracking run with wandb version 0.17.9
# Run data is saved locally in <code>/home/terra/Desktop/unimore/distributed_project/src/policies/PPO/wandb/run-20251228_025732-f8m2v322</code>
# Syncing run <strong><a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/f8m2v322' target="_blank">run_3</a></strong> to <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_2agents</a>
#  View run at <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/f8m2v322' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/f8m2v322</a>
# ------------------------------------ITERATION 0, num episode 40-------------------------------------
# TRAINING
# Rew:-396.0
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-396.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 1, num episode 80-------------------------------------
# TRAINING
# Rew:-396.24
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-396.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 2, num episode 120------------------------------------
# TRAINING
# Rew:-396.14
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-395.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 3, num episode 160------------------------------------
# TRAINING
# Rew:-396.31
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-396.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 4, num episode 200------------------------------------
# TRAINING
# Rew:-396.23
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-396.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 5, num episode 240------------------------------------
# TRAINING
# Rew:-396.34
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-395.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 6, num episode 280------------------------------------
# TRAINING
# Rew:-395.82
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-395.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 7, num episode 320------------------------------------
# TRAINING
# Rew:-394.89
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-393.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 8, num episode 360------------------------------------
# TRAINING
# Rew:-394.51
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-393.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 9, num episode 400------------------------------------
# TRAINING
# Rew:-393.86
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-393.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 10, num episode 440------------------------------------
# TRAINING
# Rew:-393.54
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-393.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 11, num episode 480------------------------------------
# TRAINING
# Rew:-393.66
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-393.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 12, num episode 520------------------------------------
# TRAINING
# Rew:-391.99
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-388.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 13, num episode 560------------------------------------
# TRAINING
# Rew:-390.42
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-387.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 14, num episode 600------------------------------------
# TRAINING
# Rew:-389.43
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-388.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 15, num episode 640------------------------------------
# TRAINING
# Rew:-388.41
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-385.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 16, num episode 680------------------------------------
# TRAINING
# Rew:-386.71
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-383.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 17, num episode 720------------------------------------
# TRAINING
# Rew:-385.56
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-385.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 18, num episode 760------------------------------------
# TRAINING
# Rew:-383.99
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-380.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 19, num episode 800------------------------------------
# TRAINING
# Rew:-381.68
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-384.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 20, num episode 840------------------------------------
# TRAINING
# Rew:-379.16
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-359.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 21, num episode 880------------------------------------
# TRAINING
# Rew:-378.95
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-372.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 22, num episode 920------------------------------------
# TRAINING
# Rew:-378.41
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-369.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 23, num episode 960------------------------------------
# TRAINING
# Rew:-373.78
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-361.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 24, num episode 1000-----------------------------------
# TRAINING
# Rew:-365.48
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-361.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 25, num episode 1040-----------------------------------
# TRAINING
# Rew:-362.28
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-357.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 26, num episode 1080-----------------------------------
# TRAINING
# Rew:-360.1
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-346.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 27, num episode 1120-----------------------------------
# TRAINING
# Rew:-354.72
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-336.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 28, num episode 1160-----------------------------------
# TRAINING
# Rew:-343.62
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-317.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 29, num episode 1200-----------------------------------
# TRAINING
# Rew:-335.87
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-321.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 30, num episode 1240-----------------------------------
# TRAINING
# Rew:-332.12
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-331.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 31, num episode 1280-----------------------------------
# TRAINING
# Rew:-320.55
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-284.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 32, num episode 1320-----------------------------------
# TRAINING
# Rew:-303.4
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-230.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 33, num episode 1360-----------------------------------
# TRAINING
# Rew:-273.35
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-189.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 34, num episode 1400-----------------------------------
# TRAINING
# Rew:-238.27
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-187.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 35, num episode 1440-----------------------------------
# TRAINING
# Rew:-204.44
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-185.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 36, num episode 1480-----------------------------------
# TRAINING
# Rew:-182.69
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-161.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 37, num episode 1520-----------------------------------
# TRAINING
# Rew:-168.79
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-154.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 38, num episode 1560-----------------------------------
# TRAINING
# Rew:-158.5
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-145.44
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 39, num episode 1600-----------------------------------
# TRAINING
# Rew:-151.73
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-147.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 40, num episode 1640-----------------------------------
# TRAINING
# Rew:-146.36
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-137.44
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 41, num episode 1680-----------------------------------
# TRAINING
# Rew:-140.4
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-135.44
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 42, num episode 1720-----------------------------------
# TRAINING
# Rew:-141.1
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-134.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 43, num episode 1760-----------------------------------
# TRAINING
# Rew:-135.65
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-143.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 44, num episode 1800-----------------------------------
# TRAINING
# Rew:-139.78
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-141.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 45, num episode 1840-----------------------------------
# TRAINING
# Rew:-141.48
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-135.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 46, num episode 1880-----------------------------------
# TRAINING
# Rew:-142.65
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-138.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 47, num episode 1920-----------------------------------
# TRAINING
# Rew:-138.8
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-134.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 48, num episode 1960-----------------------------------
# TRAINING
# Rew:-134.62
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-130.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 49, num episode 2000-----------------------------------
# TRAINING
# Rew:-132.79
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-129.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# Model saved into /home/terra/Desktop/unimore/distributed_project/src/policies/PPO/models/looseplay_2agents_sparsereward_run_3
# VBox(children=(Label(value='0.002 MB of 0.027 MB uploaded\r'), FloatProgress(value=0.08588890886212475, max=1.…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>Testing_reward_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▃▃▃▄▅▆▇▇▇█████████</td></tr><tr><td>Testing_steps_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Testing_success_rate_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Training_reward_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▃▃▃▄▆▇▇▇████████</td></tr><tr><td>Training_steps_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Training_success_rate_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>2000</td></tr><tr><td>Testing_reward_per_episode</td><td>-129.78</td></tr><tr><td>Testing_steps_per_episode</td><td>100.0</td></tr><tr><td>Testing_success_rate_per_episode</td><td>0.0</td></tr><tr><td>Training_reward_per_episode</td><td>-132.79</td></tr><tr><td>Training_steps_per_episode</td><td>100.0</td></tr><tr><td>Training_success_rate_per_episode</td><td>0.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">run_3</strong> at: <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/f8m2v322' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_2agents/runs/f8m2v322</a><br/> View project at: <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_2agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_2agents</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251228_025732-f8m2v322/logs</code>
# wandb version 0.23.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# FINISHED

# %% [markdown]
# ## **Save the agents model**

# %%
import os
def save_model(ppo, file_name):
    current_dir = os.getcwd()
    model_dir = os.path.join(current_dir, "models")
    checkpoint_name = os.path.join(model_dir, file_name)
    ppo.save(checkpoint_name)

    print(f"Model saved into {checkpoint_name}")

# %% [markdown]
# ## **Load agents**

# %%
from ray.rllib.algorithms.ppo import PPO
import os

def load_model(file_name):
    current_dir = os.getcwd()
    model_dir = os.path.join(current_dir, "models")
    checkpoint_name = os.path.join(model_dir, file_name)

    ppo = PPO.from_checkpoint(checkpoint_name)
    return ppo

# %%
import os

current_dir = os.getcwd()
model_dir = os.path.join(current_dir, "models")

for filename in os.listdir(model_dir):
    if "best" in filename and under_examination in filename:
        matching_file = filename
        break

file_path = os.path.join(model_dir, matching_file)
ppo = load_model(file_path)

# %% [markdown]
# ## **Graphically test the agent**

# %%
env = MyGridWorld(grid_size=15, n_agents=4, render_mode="human")
obs, _ = env.reset()

i = 0
while i < 3:
    actions = {}

    for agent_id, agent_obs in obs.items():
        actions[agent_id] = ppo.compute_single_action(
            agent_obs,
            policy_id=agent_id,
            explore=True
        )

    obs, rewards, terminations, truncations, infos = env.step(actions)

    if any(terminations.values()) or any(truncations.values()):
        obs, _ = env.reset()
        i += 1

env.close()
