# %% [markdown]
# # **My custom env - sparse reward**
#
# **Environment classe pasted here in order to make it accessible to all the workers of Ray.**
#
# It is equivalent to /myenv_6_dense_reward.py

# %%
under_examination = "strictplay_4agents_sparsereward"

# %%
import sys, os
from pathlib import Path

current_dir = Path(os.getcwd()) 
pointed_dir = current_dir

while True:
    if pointed_dir.is_dir() and "distributed_project" == str(pointed_dir).split("/")[-1]:
        project_dir = pointed_dir
        print(f"Project dir found: {project_dir}")
        break
    
    if pointed_dir == pointed_dir.parent:
        print("Error while looking for 'distributed_project', project dir")
        break
        
    pointed_dir = pointed_dir.parent
# Out:
# Project dir found: /home/terra/Desktop/unimore/distributed_project

# %%
import numpy as np
import functools
import gymnasium as gym
from gymnasium import spaces
from pettingzoo import ParallelEnv
import pygame 
import os
from collections import defaultdict
import random

SPRITES_DIR = "./sprites"


class MyGridWorld(ParallelEnv):
    metadata = {"render_modes": ["human"], "name": "custom_grid_v0"}

    def __init__(self, render_mode=None, n_agents = 2, grid_size=15):
        if grid_size<8:
            print("Error, need to insert a grid size greater or equal to 8")
        self.grid_size = grid_size
        self.render_mode = render_mode

        ######## Agents, fixed components, and forbidden positions
        self.possible_agents = [f"agent{i}" for i in range(1, n_agents+1)]
        self.agents = self.possible_agents[:]
        self.gate_open = False

        self.fixed_components = {
            "button1":  {"pos": np.array([self.grid_size//2+2, 1+3+2]), "file": "button.png"},
            "button2":  {"pos": np.array([self.grid_size//2+2, 1+1]), "file": "button.png"},

            "gate_open":  {"pos": np.array([self.grid_size//2, 1+3]), "file": "gate_open.png"},
            "gate_close":  {"pos": np.array([self.grid_size//2, 1+3]), "file": "gate_close.png"}   
        }
        self.button1_pos = self.fixed_components["button1"]["pos"]
        self.button2_pos = self.fixed_components["button2"]["pos"]

        self.gate_pos = self.fixed_components["gate_open"]["pos"] 
        self.target_final_pos = self.gate_pos+[0, -1]

        self.x_range = (1, self.grid_size-1-1)
        self.y_range = (1+3+1, self.grid_size-1-1)
        self.forbidden_position = {tuple(self.button1_pos)}    

        self.max_cycles = 100
        self.current_cycles = 0
        ######## Pygame graphic configuration 
        self.window_size = 810
        self.cell_size = self.window_size // self.grid_size
        self.window = None
        self.clock = None
        
        # Walls
        self.grid_map = np.zeros((self.grid_size, self.grid_size))
        self.grid_map[0, :] = 1
        self.grid_map[:, 0] = 1
        self.grid_map[-1, :] = 1
        self.grid_map[:, -1] = 1
        self.grid_map[ :, 1+3] = 1

        # Sprites 
        self.agent_sprites = {}
        self.component_sprites = {}

        ######## Action space and observation space
        # Five possible actions in each grid: stay(0), up(1), down(2), left(3), right(4)
        self.action_spaces = {a: spaces.Discrete(5) for a in self.possible_agents}
        OBSERVATION_DIM = 2*(len(self.agents)-1)+3*2+1
        self.observation_spaces = {
            a: spaces.Box(low=-(self.grid_size-1), high=self.grid_size-1, shape=(OBSERVATION_DIM,), dtype=np.float32) 
            for a in self.possible_agents
        }
        self.state_spaces = {a: None for a in self.possible_agents}

    def state(self):
        observations = self.gather_observations()
        global_state = []
        
        for agent in self.possible_agents:
            if agent in observations:
                global_state.append(observations[agent])
            else:
                # Se l'agente è morto/uscito, usa zeri
                dim = self.observation_spaces[agent].shape[0]
                global_state.append(np.zeros(dim, dtype=np.float32))
                
        return np.concatenate(global_state)

    # Boilerplate PettingZoo
    def observation_space(self, agent): return self.observation_spaces[agent]
    def action_space(self, agent): return self.action_spaces[agent]

    '''
    Step in the environment
    '''
    def step(self, actions):
        if not self.agents: return {}, {}, {}, {}, {}
        self.current_cycles += 1
        
        rewards = {a: -1 for a in self.agents}

        terminations = {a: False for a in self.agents}
        truncations = {a: False for a in self.agents}
        infos = {a: {"is_success":False} for a in self.agents}
        
        desired_positions = {}      
        button_pressed = False
        agents_desire_gate = []
        for agent, action in actions.items():
            current_pos = self.agent_positions[agent].copy()
            target_pos = current_pos.copy()

            if action == 1: target_pos[1] -= 1 
            elif action == 2: target_pos[1] += 1
            elif action == 3: target_pos[0] -= 1
            elif action == 4: target_pos[0] += 1

            # Monitor button, gate and walls
            is_wall = self.grid_map[target_pos[0], target_pos[1]] == 1
            is_gate = (target_pos == self.gate_pos).all()
            is_button = (target_pos == self.button1_pos).all() or (target_pos == self.button2_pos).all()
            
            if is_button:
                button_pressed = True
            if is_gate:
                agents_desire_gate.append((agent, current_pos))
            
            if is_wall and not is_gate:
                desired_positions[agent] = current_pos 
            else:
                desired_positions[agent] = target_pos
                        
        # If gate was open remove a wall, if gate was closed update the position of those who wanted to cross it
        self.gate_open = button_pressed
        if self.gate_open:
            self.grid_map[self.gate_pos[0], self.gate_pos[1]] = 0
        else:
            self.grid_map[self.gate_pos[0], self.gate_pos[1]] = 1
            for a in agents_desire_gate:
                agent = a[0]
                current_pos = a[1]
                desired_positions[agent] = current_pos 

        # Check for conflicts (more than one agents have the same desired position)
        final_positions = self.agent_positions.copy()
        target_counts = defaultdict(list)         # Key: tuple(x, y) of desired positions, Value: list of agents desiring it
        for agent, pos in desired_positions.items():
            pos_tuple = tuple(pos)
            target_counts[pos_tuple].append(agent)

        # Solve eventual conflicts
        for pos_tuple, agents_at_target in target_counts.items():      
            # Case 1: no contended position
            if len(agents_at_target) == 1:
                agent = agents_at_target[0]
                final_positions[agent] = desired_positions[agent]
            
            # Case 2: contended position
            else:
                one_agent_already_here_not_moving = None
                for agent in agents_at_target:
                    if tuple(self.agent_positions[agent]) == pos_tuple:
                        one_agent_already_here_not_moving = agent
                        break
                
                winning_agent = one_agent_already_here_not_moving if one_agent_already_here_not_moving else random.choice(agents_at_target)
                final_positions[winning_agent] = desired_positions[winning_agent]
                
                agents_at_target.remove(winning_agent)
                for losing_agent in agents_at_target[:]:
                    final_positions[losing_agent] = self.agent_positions[losing_agent] 
        self.agent_positions = final_positions

        # Negative reward if an agent is on the bottom area and is not pressing the button
        agents_upper_area = 0
        for a, pos in self.agent_positions.items():
            dist_target = np.linalg.norm(pos - self.target_final_pos)
            if pos[1]<4:                                # Agent on upper area
                rewards[a] = +1
                agents_upper_area+=1
            if (pos == self.button2_pos).all():     # Agent on button
                rewards[a] +=1
            if (pos == self.button1_pos).all():     # Agent on button
                rewards[a] += 1    
       
        if agents_upper_area == len(self.agents):
            rewards = {a: +100 for a in self.agents}
            terminations = {a: True for a in self.agents}
            infos = {a: {"is_success":True} for a in self.agents}

        if self.current_cycles >= self.max_cycles:
            truncations= {a: True for a in self.agents}
            rewards = {a: -100 for a in self.agents}

            
        
        if self.render_mode == "human":
            self.render()
            
        final_obs = self.gather_observations()
        self.agents = [a for a in self.agents if not terminations[a]]
        return final_obs, rewards, terminations, truncations, infos
   
    '''
    Determines initial condition of the simulation
    '''

    def generate_valid_position(self):
        while True:
            x = np.random.randint(self.x_range[0], self.x_range[1])
            y = np.random.randint(self.y_range[0], self.y_range[1])
            new_position = tuple((x, y))

            if new_position not in self.forbidden_position:
                return new_position
            
    def generate_set_initial_positions(self):
        set_initial_positions = set()
        while len(set_initial_positions)<len(self.possible_agents):
            new_pos = self.generate_valid_position()
            set_initial_positions.add(new_pos)
        return set_initial_positions
    
    def generate_test_values(self, agent_num):
        if agent_num==1:
            return[7, 9]
        else:
            return [9,13]

    def reset(self, seed=None, options=None):
        self.agents = self.possible_agents[:]
        set_initial_positions = list(self.generate_set_initial_positions())
        self.current_cycles = 0

        self.agent_positions = {}
        for i, agent_id in enumerate(self.agents):
            self.agent_positions[agent_id] = np.array(set_initial_positions[i])
        
        # To visualize the reset position if "human" mode on
        if self.render_mode == "human":
            self.render()         

        return self.gather_observations(), {a: {} for a in self.agents}
    
    '''
    Observation: [my_cur_pos, (other_cur) x number of other agents, button_pos, gate_pos, gate_open (1|0)]    '''
    def gather_observations(self):
        gate_status_info = np.array([int(self.gate_open)], dtype=np.float32)
        observations = {}
        for observing_agent in self.agents:
            obs_segments = []
            observing_agent_pos = self.agent_positions[observing_agent]
            
            for other_agent in self.agents:
                if other_agent != observing_agent:
                    obs_segments.append(self.agent_positions[other_agent] - observing_agent_pos)
            obs_segments.append(self.button1_pos- observing_agent_pos)
            obs_segments.append(self.button2_pos- observing_agent_pos)
            obs_segments.append(self.gate_pos -observing_agent_pos)
            obs_segments.append(gate_status_info)
            observations[observing_agent] = np.concatenate(obs_segments, dtype=np.float32)
        return observations

    '''
    Functions for Sprite rendering and loading
    '''    
    def _create_missing_sprite(self, text, bg_color, border_color = (0,0,0)):  
        error_sprite = pygame.Surface((self.cell_size, self.cell_size), pygame.SRCALPHA)
        error_sprite.fill((0, 0, 0, 0))
        center = (self.cell_size // 2, self.cell_size // 2)
        radius = int(self.cell_size * 0.4)
        pygame.draw.circle(error_sprite, bg_color, center, radius) 
        pygame.draw.circle(error_sprite, border_color, center, radius, 2)
        
        # Add text label
        try:
            font_size = int(self.cell_size * 0.22)
            font = pygame.font.Font(None, font_size)   
            text_color = (0, 0, 0) if sum(bg_color) > 300 else (255, 255, 255) 
            text_surface = font.render(text, True, text_color)
            text_rect = text_surface.get_rect(center=center)
            error_sprite.blit(text_surface, text_rect)
            
        except Exception as e:
            print(f"WARNING: Error while writing text inside missing sprite {text}. A missing sprite without text label will be used for this simulation.")
            pass
            
        return error_sprite
    
    def _load_and_scale_sprite(self, filename, component_name):
        path = os.path.join(SPRITES_DIR, filename)
    
        try:
            image = pygame.image.load(path).convert_alpha() 
            scaled_size = int(self.cell_size )
            return pygame.transform.scale(image, (scaled_size, scaled_size))
            
        except (FileNotFoundError, pygame.error) as e:
            print(f"WARNING! Sprite image {path} not found. Using default sprite for this simulation.")
    
            text = component_name.upper() if component_name else "ERROR"
            bg_color = (100, 100, 255) if "AGENT" in text else (128,128,128) # Blue agent, Gray fixed components
            return self._create_missing_sprite(text, bg_color)

    def render(self):
        if self.render_mode is None:
            return

        if self.window is None:
            pygame.init()
            pygame.display.init()
            pygame.font.init()
            self.window = pygame.display.set_mode((self.window_size, self.window_size))
            
            for agent_name in self.agents:
               # self.agent_sprites[agent_name] = self._load_and_scale_sprite(f"{agent_name}.png", agent_name)
               self.agent_sprites[agent_name] = self._load_and_scale_sprite(".png", agent_name)

            for name, data in self.fixed_components.items():
                self.component_sprites[name] = self._load_and_scale_sprite(data["file"], name)

                 
        if self.clock is None:
            self.clock = pygame.time.Clock()

        canvas = pygame.Surface((self.window_size, self.window_size))
        canvas.fill((220, 220, 220)) 
        pix_square_size = self.cell_size 
        sprite_offset = (pix_square_size - int(pix_square_size * 0.8)) // 2

        # Render walls
        for x in range(self.grid_size):
            for y in range(self.grid_size):
                if self.grid_map[x, y] == 1:
                    pygame.draw.rect(
                        canvas, 
                        (50, 50, 50),
                        pygame.Rect(x * pix_square_size, y * pix_square_size, pix_square_size, pix_square_size)
                    )

        # Render fixed components and agents
        for name, data in self.fixed_components.items():
            if self.gate_open and name == "gate_close":
                continue
            pos = data["pos"]
            x_coord = pos[0] * pix_square_size + sprite_offset
            y_coord = pos[1] * pix_square_size + sprite_offset
            sprite = self.component_sprites[name]
            canvas.blit(sprite, (x_coord, y_coord))

        for agent in self.agents:
            pos = self.agent_positions[agent]            
            x_coord = pos[0] * pix_square_size + sprite_offset
            y_coord = pos[1] * pix_square_size + sprite_offset
            
            sprite = self.agent_sprites[agent]
            canvas.blit(sprite, (x_coord, y_coord))

        # Render the grid
        for x in range(self.grid_size + 1):
            pygame.draw.line(
                canvas, 0, (0, pix_square_size * x), (self.window_size, pix_square_size * x), width=2
            )
            pygame.draw.line(
                canvas, 0, (pix_square_size * x, 0), (pix_square_size * x, self.window_size), width=2
            )

        # Display the render
        self.window.blit(canvas, canvas.get_rect())
        pygame.event.pump()
        pygame.display.update()
        self.clock.tick(4) # FPS

    def close(self):
        if self.window is not None:
            pygame.display.quit()
            pygame.quit()
# Out:
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %% [markdown]
# **Wrap the envornment in a PettingZoo env (for compatibility with Ray) and register it on Ray lib**

# %%
from ray.rllib.env.wrappers.pettingzoo_env import ParallelPettingZooEnv
from ray.tune.registry import register_env

def env_creator(config):
    return ParallelPettingZooEnv(
        MyGridWorld(render_mode=None, n_agents=4)
    )

register_env("my_gridworld", env_creator)

# %% [markdown]
# ## **IPPO - strict play settings**

# %% [markdown]
# Callback to register episode success rate

# %%
from ray.rllib.algorithms.callbacks import DefaultCallbacks

class SuccessMetricCallback(DefaultCallbacks):
    def on_episode_end(self, *, worker, base_env, policies, episode, **kwargs):
        
        is_success = False
        one_agent_id = list(episode.get_agents())[-1]
        last_info = episode.last_info_for(one_agent_id)
        is_success = last_info["is_success"]
       
        episode.custom_metrics["success_rate"] = int(is_success)

# %%
from ray.rllib.algorithms.ppo import PPOConfig

config = (
    PPOConfig()
    .environment(env="my_gridworld")
    .env_runners(num_env_runners=0)
    .callbacks(callbacks_class=SuccessMetricCallback)
    .multi_agent(
        policies={"shared_policy"},
        policy_mapping_fn=lambda agent_id, *args, **kwargs: "shared_policy",
    )
    .api_stack(
        enable_rl_module_and_learner=False,
        enable_env_runner_and_connector_v2=False
    )
    
    .evaluation(
        evaluation_interval=1,
        evaluation_duration=10,
        evaluation_duration_unit="episodes",
        evaluation_num_env_runners=1,
        
        evaluation_config={
            "explore": True,
        }
    )
    .training(
        lr=1e-4, 
        
        train_batch_size_per_learner=4000, 
        num_epochs=10, 
        entropy_coeff=0.05, 
        gamma=0.995,
        
        kl_coeff=0.2,
        kl_target=0.01
    )
)

# %% [markdown]
# ## **Wandb - One run of training**

# %%
import wandb
#wandb.init(project="gridworld_strictplay_2agents", name="densereward")
ppo = config.build_algo()
num_total_episodes = 0
for i in range(50):
    result = ppo.train()
    num_total_episodes += result['env_runners']['num_episodes']
    
    print(f"ITERATION {i}, num episode {num_total_episodes}".center(100,"-"))
    train_rew = round(result['env_runners']['episode_return_mean'], 2)
    train_steps_episode = round(result['env_runners']['episode_len_mean'], 2)
    train_success_rate = round(result['env_runners']['custom_metrics'].get('success_rate_mean', 0), 2) * 100
    print(f"""TRAINING\nRew:{train_rew} \nSteps per episode:{train_steps_episode} \nSuccess rate:{train_success_rate}%\n""")

    if 'evaluation' in result:
        testing_rew = round(result['evaluation']['env_runners']['episode_return_mean'], 2)
        testing_steps_episode = round(result['evaluation']['env_runners']['episode_len_mean'], 2)
        testing_success_rate = round(result['evaluation']['env_runners']['custom_metrics'].get('success_rate_mean', 0), 2) * 100
        print(f"""TESTING\nRew:{testing_rew} \nSteps per episode:{testing_steps_episode} \nSuccess rate:{testing_success_rate}%\n\n""")

    log_data = {
        "Episodes": num_total_episodes,

        "Training_steps_per_episode": train_steps_episode,
        "Training_success_rate_per_episode": train_success_rate,
        "Training_reward_per_episode": train_rew,

        "Testing_steps_per_episode": testing_steps_episode,
        "Testing_success_rate_per_episode": testing_success_rate,
        "Testing_reward_per_episode": testing_rew
    }
    #wandb.log(log_data)
#wandb.finish()

# %% [markdown]
# ## **Wandb, 3 runs of training to generate esteme**

# %%
import wandb
group_name = "sparse_4000"

for run_idx in range(1,4):
    print(f"\n{'='*40}")
    print(f"RUN NUMBER {run_idx}/3")
    print(f"{'='*40}\n")

    ppo = config.build_algo()
    wandb.init(
        project="gridworld_strictplay_4agents",
        group=group_name,           
        name=f"run_{run_idx}",    
        reinit=True 
    )
    file_name = f"{under_examination}_run_{run_idx}"
    
    num_total_episodes = 0
    for i in range(50):
        result = ppo.train()
        num_total_episodes += result['env_runners']['num_episodes']
        
        print(f"ITERATION {i}, num episode {num_total_episodes}".center(100,"-"))
        train_rew = round(result['env_runners']['episode_return_mean'], 2)
        train_steps_episode = round(result['env_runners']['episode_len_mean'], 2)
        train_success_rate = round(result['env_runners']['custom_metrics'].get('success_rate_mean', 0), 2) * 100
        print(f"""TRAINING\nRew:{train_rew} \nSteps per episode:{train_steps_episode} \nSuccess rate:{train_success_rate}%\n""")

        if 'evaluation' in result:
            testing_rew = round(result['evaluation']['env_runners']['episode_return_mean'], 2)
            testing_steps_episode = round(result['evaluation']['env_runners']['episode_len_mean'], 2)
            testing_success_rate = round(result['evaluation']['env_runners']['custom_metrics'].get('success_rate_mean', 0), 2) * 100
            print(f"""TESTING\nRew:{testing_rew} \nSteps per episode:{testing_steps_episode} \nSuccess rate:{testing_success_rate}%\n\n""")

        log_data = {
            "Episodes": num_total_episodes,

            "Training_steps_per_episode": train_steps_episode,
            "Training_success_rate_per_episode": train_success_rate,
            "Training_reward_per_episode": train_rew,

            "Testing_steps_per_episode": testing_steps_episode,
            "Testing_success_rate_per_episode": testing_success_rate,
            "Testing_reward_per_episode": testing_rew
        }
        wandb.log(log_data)
    save_model(ppo, file_name)
    wandb.finish()

print("FINISHED")
# Out:
# ========================================
# RUN NUMBER 1/3
# ========================================
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:527: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/google/api_core/_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2025-12-27 20:55:30,987	INFO worker.py:2007 -- Started a local Ray instance.
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/_private/worker.py:2046: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# [2025-12-27 20:55:32,869 E 2189838 2189838] core_worker.cc:2223: Actor with class name: 'RolloutWorker' and ID: '18a87a436588f31450ceb60901000000' has constructor arguments in the object store and max_restarts > 0. If the arguments in the object store go out of scope or are lost, the actor restart will fail. See https://github.com/ray-project/ray/issues/53727 for more details.
# (RolloutWorker pid=2190060) /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (RolloutWorker pid=2190060)   from pkg_resources import resource_stream, resource_exists
# 2025-12-27 20:55:36,008	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: 299011 (299011-unimore). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.17.9
# Run data is saved locally in <code>/home/terra/Desktop/unimore/distributed_project/src/policies/PPO/wandb/run-20251227_205537-ghrp79dl</code>
# Syncing run <strong><a href='https://wandb.ai/299011-unimore/gridworld_strictplay_4agents/runs/ghrp79dl' target="_blank">run_1</a></strong> to <a href='https://wandb.ai/299011-unimore/gridworld_strictplay_4agents' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/299011-unimore/gridworld_strictplay_4agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_strictplay_4agents</a>
#  View run at <a href='https://wandb.ai/299011-unimore/gridworld_strictplay_4agents/runs/ghrp79dl' target="_blank">https://wandb.ai/299011-unimore/gridworld_strictplay_4agents/runs/ghrp79dl</a>
# 2025-12-27 20:55:48,623	WARNING sgd.py:55 -- DeprecationWarning: `_get_slice_indices` has been deprecated. This will raise an error in the future!
# ------------------------------------ITERATION 0, num episode 40-------------------------------------
# TRAINING
# Rew:-793.38
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-789.9
# Steps per episode:100.0
# Success rate:0.0%
# (pid=gcs_server) [2025-12-27 20:56:00,177 E 2189887 2189887] (gcs_server) gcs_server.cc:303: Failed to establish connection to the event+metrics exporter agent. Events and metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (raylet) [2025-12-27 20:56:00,912 E 2190002 2190002] (raylet) main.cc:1032: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (RolloutWorker pid=2190060) [2025-12-27 20:56:01,759 E 2190060 2190176] core_worker_process.cc:842: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# [2025-12-27 20:56:01,893 E 2189838 2190055] core_worker_process.cc:842: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# ------------------------------------ITERATION 1, num episode 80-------------------------------------
# TRAINING
# Rew:-790.85
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-792.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 2, num episode 120------------------------------------
# TRAINING
# Rew:-790.96
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-791.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 3, num episode 160------------------------------------
# TRAINING
# Rew:-791.18
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-791.44
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 4, num episode 200------------------------------------
# TRAINING
# Rew:-788.3
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-792.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 5, num episode 240------------------------------------
# TRAINING
# Rew:-784.38
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-785.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 6, num episode 280------------------------------------
# TRAINING
# Rew:-782.44
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-773.44
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 7, num episode 320------------------------------------
# TRAINING
# Rew:-773.78
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-774.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 8, num episode 360------------------------------------
# TRAINING
# Rew:-772.74
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-782.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 9, num episode 400------------------------------------
# TRAINING
# Rew:-775.29
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-757.44
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 10, num episode 440------------------------------------
# TRAINING
# Rew:-768.41
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-768.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 11, num episode 480------------------------------------
# TRAINING
# Rew:-758.85
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-746.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 12, num episode 520------------------------------------
# TRAINING
# Rew:-751.11
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-738.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 13, num episode 560------------------------------------
# TRAINING
# Rew:-748.43
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-641.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 14, num episode 600------------------------------------
# TRAINING
# Rew:-716.78
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-589.44
# Steps per episode:99.56
# Success rate:11.0%
#
#
# -----------------------------------ITERATION 15, num episode 640------------------------------------
# TRAINING
# Rew:-653.87
# Steps per episode:99.24
# Success rate:3.0%
#
# TESTING
# Rew:-575.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 16, num episode 681------------------------------------
# TRAINING
# Rew:-588.37
# Steps per episode:98.63
# Success rate:7.000000000000001%
#
# TESTING
# Rew:-629.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 17, num episode 722------------------------------------
# TRAINING
# Rew:-546.71
# Steps per episode:98.43
# Success rate:11.0%
#
# TESTING
# Rew:-448.11
# Steps per episode:99.44
# Success rate:22.0%
#
#
# -----------------------------------ITERATION 18, num episode 765------------------------------------
# TRAINING
# Rew:-439.3
# Steps per episode:95.69
# Success rate:22.0%
#
# TESTING
# Rew:-506.89
# Steps per episode:95.89
# Success rate:22.0%
#
#
# -----------------------------------ITERATION 19, num episode 807------------------------------------
# TRAINING
# Rew:-433.64
# Steps per episode:94.66
# Success rate:23.0%
#
# TESTING
# Rew:-601.11
# Steps per episode:99.11
# Success rate:11.0%
#
#
# -----------------------------------ITERATION 20, num episode 849------------------------------------
# TRAINING
# Rew:-483.06
# Steps per episode:95.88
# Success rate:18.0%
#
# TESTING
# Rew:-445.44
# Steps per episode:96.22
# Success rate:22.0%
#
#
# -----------------------------------ITERATION 21, num episode 891------------------------------------
# TRAINING
# Rew:-441.18
# Steps per episode:95.0
# Success rate:23.0%
#
# TESTING
# Rew:-429.11
# Steps per episode:93.22
# Success rate:22.0%
#
#
# -----------------------------------ITERATION 22, num episode 935------------------------------------
# TRAINING
# Rew:-438.58
# Steps per episode:93.74
# Success rate:24.0%
#
# TESTING
# Rew:-316.78
# Steps per episode:88.33
# Success rate:33.0%
#
#
# -----------------------------------ITERATION 23, num episode 979------------------------------------
# TRAINING
# Rew:-290.4
# Steps per episode:91.6
# Success rate:39.0%
#
# TESTING
# Rew:-349.22
# Steps per episode:89.78
# Success rate:33.0%
#
#
# -----------------------------------ITERATION 24, num episode 1027-----------------------------------
# TRAINING
# Rew:-217.86
# Steps per episode:87.58
# Success rate:47.0%
#
# TESTING
# Rew:-423.33
# Steps per episode:97.33
# Success rate:22.0%
#
#
# -----------------------------------ITERATION 25, num episode 1074-----------------------------------
# TRAINING
# Rew:-198.66
# Steps per episode:84.97
# Success rate:51.0%
#
# TESTING
# Rew:-86.22
# Steps per episode:80.78
# Success rate:67.0%
#
#
# -----------------------------------ITERATION 26, num episode 1121-----------------------------------
# TRAINING
# Rew:-183.17
# Steps per episode:85.2
# Success rate:53.0%
#
# TESTING
# Rew:186.11
# Steps per episode:58.22
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 27, num episode 1172-----------------------------------
# TRAINING
# Rew:-114.94
# Steps per episode:81.84
# Success rate:63.0%
#
# TESTING
# Rew:101.22
# Steps per episode:71.11
# Success rate:78.0%
#
#
# -----------------------------------ITERATION 28, num episode 1227-----------------------------------
# TRAINING
# Rew:59.82
# Steps per episode:74.51
# Success rate:81.0%
#
# TESTING
# Rew:-30.0
# Steps per episode:78.78
# Success rate:67.0%
#
#
# -----------------------------------ITERATION 29, num episode 1284-----------------------------------
# TRAINING
# Rew:117.29
# Steps per episode:71.8
# Success rate:82.0%
#
# TESTING
# Rew:-187.56
# Steps per episode:81.89
# Success rate:67.0%
#
#
# -----------------------------------ITERATION 30, num episode 1337-----------------------------------
# TRAINING
# Rew:36.26
# Steps per episode:73.26
# Success rate:76.0%
#
# TESTING
# Rew:182.78
# Steps per episode:70.33
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 31, num episode 1392-----------------------------------
# TRAINING
# Rew:29.69
# Steps per episode:73.91
# Success rate:77.0%
#
# TESTING
# Rew:80.78
# Steps per episode:68.11
# Success rate:78.0%
#
#
# -----------------------------------ITERATION 32, num episode 1440-----------------------------------
# TRAINING
# Rew:16.16
# Steps per episode:77.73
# Success rate:75.0%
#
# TESTING
# Rew:95.0
# Steps per episode:66.44
# Success rate:78.0%
#
#
# -----------------------------------ITERATION 33, num episode 1493-----------------------------------
# TRAINING
# Rew:-8.01
# Steps per episode:79.31
# Success rate:71.0%
#
# TESTING
# Rew:167.11
# Steps per episode:67.33
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 34, num episode 1551-----------------------------------
# TRAINING
# Rew:90.17
# Steps per episode:72.6
# Success rate:79.0%
#
# TESTING
# Rew:299.22
# Steps per episode:62.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 35, num episode 1610-----------------------------------
# TRAINING
# Rew:182.33
# Steps per episode:66.91
# Success rate:88.0%
#
# TESTING
# Rew:37.78
# Steps per episode:76.78
# Success rate:78.0%
#
#
# -----------------------------------ITERATION 36, num episode 1664-----------------------------------
# TRAINING
# Rew:74.87
# Steps per episode:71.53
# Success rate:79.0%
#
# TESTING
# Rew:-53.67
# Steps per episode:78.78
# Success rate:67.0%
#
#
# -----------------------------------ITERATION 37, num episode 1721-----------------------------------
# TRAINING
# Rew:54.39
# Steps per episode:71.84
# Success rate:77.0%
#
# TESTING
# Rew:165.22
# Steps per episode:73.11
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 38, num episode 1775-----------------------------------
# TRAINING
# Rew:81.85
# Steps per episode:72.41
# Success rate:80.0%
#
# TESTING
# Rew:157.44
# Steps per episode:67.0
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 39, num episode 1834-----------------------------------
# TRAINING
# Rew:93.02
# Steps per episode:70.96
# Success rate:81.0%
#
# TESTING
# Rew:-167.11
# Steps per episode:79.78
# Success rate:56.00000000000001%
#
#
# -----------------------------------ITERATION 40, num episode 1885-----------------------------------
# TRAINING
# Rew:80.78
# Steps per episode:71.57
# Success rate:80.0%
#
# TESTING
# Rew:262.44
# Steps per episode:65.67
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 41, num episode 1940-----------------------------------
# TRAINING
# Rew:58.78
# Steps per episode:74.66
# Success rate:79.0%
#
# TESTING
# Rew:70.89
# Steps per episode:71.89
# Success rate:78.0%
#
#
# -----------------------------------ITERATION 42, num episode 1997-----------------------------------
# TRAINING
# Rew:100.95
# Steps per episode:71.78
# Success rate:82.0%
#
# TESTING
# Rew:-169.0
# Steps per episode:70.44
# Success rate:56.00000000000001%
#
#
# -----------------------------------ITERATION 43, num episode 2055-----------------------------------
# TRAINING
# Rew:173.9
# Steps per episode:68.63
# Success rate:91.0%
#
# TESTING
# Rew:292.67
# Steps per episode:54.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 44, num episode 2112-----------------------------------
# TRAINING
# Rew:161.55
# Steps per episode:69.16
# Success rate:91.0%
#
# TESTING
# Rew:45.56
# Steps per episode:71.33
# Success rate:78.0%
#
#
# -----------------------------------ITERATION 45, num episode 2165-----------------------------------
# TRAINING
# Rew:101.14
# Steps per episode:72.35
# Success rate:84.0%
#
# TESTING
# Rew:55.78
# Steps per episode:79.89
# Success rate:78.0%
#
#
# -----------------------------------ITERATION 46, num episode 2219-----------------------------------
# TRAINING
# Rew:55.32
# Steps per episode:74.56
# Success rate:78.0%
#
# TESTING
# Rew:67.33
# Steps per episode:71.33
# Success rate:78.0%
#
#
# -----------------------------------ITERATION 47, num episode 2280-----------------------------------
# TRAINING
# Rew:129.99
# Steps per episode:69.76
# Success rate:84.0%
#
# TESTING
# Rew:169.22
# Steps per episode:70.11
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 48, num episode 2340-----------------------------------
# TRAINING
# Rew:156.9
# Steps per episode:66.06
# Success rate:87.0%
#
# TESTING
# Rew:196.22
# Steps per episode:62.89
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 49, num episode 2399-----------------------------------
# TRAINING
# Rew:101.67
# Steps per episode:68.34
# Success rate:83.0%
#
# TESTING
# Rew:176.89
# Steps per episode:61.67
# Success rate:89.0%
#
#
# Model saved into /home/terra/Desktop/unimore/distributed_project/src/policies/PPO/models/strictplay_4agents_sparsereward_run_1
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇██</td></tr><tr><td>Testing_reward_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▂▂▂▃▃▃▃▄▄▆▇▇▆▇▇▇▇▆▆▇▇█▇▅█▆▇▇▇</td></tr><tr><td>Testing_steps_per_episode</td><td>███████████████▇▇▇▆▆▅▂▄▅▃▃▃▃▄▅▄▃▃▄▃▁▅▄▃▂</td></tr><tr><td>Testing_success_rate_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▃▃▃▃▃▃▆▇▆▆▇▆▆▇▆▆▇▇█▆▅█▆▆▇▇</td></tr><tr><td>Training_reward_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▂▂▃▄▃▄▄▅▅▅▆▇▇▇▇▇█▇▇▇▇▇▇█▇▇█▇</td></tr><tr><td>Training_steps_per_episode</td><td>███████████████▇▇▇▇▆▅▅▄▃▂▂▃▄▁▂▂▂▂▃▂▁▂▃▂▁</td></tr><tr><td>Training_success_rate_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▃▂▃▃▄▅▅▆▇▇▇▇▆█▇▇▇▇▇▇█▇▇▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>2399</td></tr><tr><td>Testing_reward_per_episode</td><td>176.89</td></tr><tr><td>Testing_steps_per_episode</td><td>61.67</td></tr><tr><td>Testing_success_rate_per_episode</td><td>89.0</td></tr><tr><td>Training_reward_per_episode</td><td>101.67</td></tr><tr><td>Training_steps_per_episode</td><td>68.34</td></tr><tr><td>Training_success_rate_per_episode</td><td>83.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">run_1</strong> at: <a href='https://wandb.ai/299011-unimore/gridworld_strictplay_4agents/runs/ghrp79dl' target="_blank">https://wandb.ai/299011-unimore/gridworld_strictplay_4agents/runs/ghrp79dl</a><br/> View project at: <a href='https://wandb.ai/299011-unimore/gridworld_strictplay_4agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_strictplay_4agents</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251227_205537-ghrp79dl/logs</code>
# wandb version 0.23.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# ========================================
# RUN NUMBER 2/3
# ========================================
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:527: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# (RolloutWorker pid=2190061) /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (RolloutWorker pid=2190061)   from pkg_resources import resource_stream, resource_exists
# (pid=2190065) [2025-12-27 20:56:01,885 E 2190065 2190580] core_worker_process.cc:842: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14 [repeated 11x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# 2025-12-27 21:09:24,534	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Tracking run with wandb version 0.17.9
# Run data is saved locally in <code>/home/terra/Desktop/unimore/distributed_project/src/policies/PPO/wandb/run-20251227_210924-w2ly1i3a</code>
# Syncing run <strong><a href='https://wandb.ai/299011-unimore/gridworld_strictplay_4agents/runs/w2ly1i3a' target="_blank">run_2</a></strong> to <a href='https://wandb.ai/299011-unimore/gridworld_strictplay_4agents' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/299011-unimore/gridworld_strictplay_4agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_strictplay_4agents</a>
#  View run at <a href='https://wandb.ai/299011-unimore/gridworld_strictplay_4agents/runs/w2ly1i3a' target="_blank">https://wandb.ai/299011-unimore/gridworld_strictplay_4agents/runs/w2ly1i3a</a>
# ------------------------------------ITERATION 0, num episode 40-------------------------------------
# TRAINING
# Rew:-792.78
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-791.4
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 1, num episode 80-------------------------------------
# TRAINING
# Rew:-791.99
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-793.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 2, num episode 120------------------------------------
# TRAINING
# Rew:-792.24
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-793.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 3, num episode 160------------------------------------
# TRAINING
# Rew:-793.14
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-793.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 4, num episode 200------------------------------------
# TRAINING
# Rew:-792.96
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-777.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 5, num episode 240------------------------------------
# TRAINING
# Rew:-791.65
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-792.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 6, num episode 280------------------------------------
# TRAINING
# Rew:-790.25
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-791.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 7, num episode 320------------------------------------
# TRAINING
# Rew:-789.4
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-785.44
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 8, num episode 360------------------------------------
# TRAINING
# Rew:-787.71
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-784.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 9, num episode 400------------------------------------
# TRAINING
# Rew:-786.69
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-784.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 10, num episode 440------------------------------------
# TRAINING
# Rew:-782.46
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-780.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 11, num episode 480------------------------------------
# TRAINING
# Rew:-779.77
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-776.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 12, num episode 520------------------------------------
# TRAINING
# Rew:-774.81
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-781.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 13, num episode 560------------------------------------
# TRAINING
# Rew:-773.3
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-760.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 14, num episode 600------------------------------------
# TRAINING
# Rew:-764.01
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-741.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 15, num episode 640------------------------------------
# TRAINING
# Rew:-747.88
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-696.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 16, num episode 680------------------------------------
# TRAINING
# Rew:-728.26
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-687.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 17, num episode 720------------------------------------
# TRAINING
# Rew:-718.57
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-765.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 18, num episode 760------------------------------------
# TRAINING
# Rew:-719.51
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-691.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 19, num episode 800------------------------------------
# TRAINING
# Rew:-711.94
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-621.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 20, num episode 840------------------------------------
# TRAINING
# Rew:-706.92
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-684.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 21, num episode 880------------------------------------
# TRAINING
# Rew:-693.77
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-670.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 22, num episode 920------------------------------------
# TRAINING
# Rew:-667.4
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-688.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 23, num episode 960------------------------------------
# TRAINING
# Rew:-656.08
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-660.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 24, num episode 1000-----------------------------------
# TRAINING
# Rew:-667.46
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-655.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 25, num episode 1040-----------------------------------
# TRAINING
# Rew:-678.79
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-690.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 26, num episode 1080-----------------------------------
# TRAINING
# Rew:-672.69
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-666.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 27, num episode 1120-----------------------------------
# TRAINING
# Rew:-656.27
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-613.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 28, num episode 1160-----------------------------------
# TRAINING
# Rew:-635.44
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-635.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 29, num episode 1200-----------------------------------
# TRAINING
# Rew:-622.07
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-647.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 30, num episode 1240-----------------------------------
# TRAINING
# Rew:-633.87
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-610.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 31, num episode 1280-----------------------------------
# TRAINING
# Rew:-640.33
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-630.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 32, num episode 1320-----------------------------------
# TRAINING
# Rew:-632.55
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-562.44
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 33, num episode 1360-----------------------------------
# TRAINING
# Rew:-625.09
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-632.44
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 34, num episode 1400-----------------------------------
# TRAINING
# Rew:-625.17
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-694.44
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 35, num episode 1440-----------------------------------
# TRAINING
# Rew:-643.02
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-662.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 36, num episode 1480-----------------------------------
# TRAINING
# Rew:-644.56
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-684.44
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 37, num episode 1520-----------------------------------
# TRAINING
# Rew:-656.17
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-742.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 38, num episode 1560-----------------------------------
# TRAINING
# Rew:-674.84
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-723.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 39, num episode 1600-----------------------------------
# TRAINING
# Rew:-685.77
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-741.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 40, num episode 1640-----------------------------------
# TRAINING
# Rew:-691.16
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-647.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 41, num episode 1680-----------------------------------
# TRAINING
# Rew:-695.78
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-704.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 42, num episode 1720-----------------------------------
# TRAINING
# Rew:-692.73
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-673.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 43, num episode 1760-----------------------------------
# TRAINING
# Rew:-685.87
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-696.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 44, num episode 1800-----------------------------------
# TRAINING
# Rew:-681.28
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-680.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 45, num episode 1840-----------------------------------
# TRAINING
# Rew:-684.48
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-692.44
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 46, num episode 1880-----------------------------------
# TRAINING
# Rew:-675.72
# Steps per episode:99.84
# Success rate:1.0%
#
# TESTING
# Rew:-674.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 47, num episode 1920-----------------------------------
# TRAINING
# Rew:-654.79
# Steps per episode:99.84
# Success rate:1.0%
#
# TESTING
# Rew:-710.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 48, num episode 1960-----------------------------------
# TRAINING
# Rew:-660.81
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-671.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 49, num episode 2000-----------------------------------
# TRAINING
# Rew:-651.8
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-634.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# Model saved into /home/terra/Desktop/unimore/distributed_project/src/policies/PPO/models/strictplay_4agents_sparsereward_run_2
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>Testing_reward_per_episode</td><td>▁▁▁▁▁▁▁▁▁▂▁▂▄▄▂▄▄▅▄▅▄▅▆▆▇▆█▆▅▄▃▃▅▄▅▄▄▅▄▆</td></tr><tr><td>Testing_steps_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Testing_success_rate_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Training_reward_per_episode</td><td>▁▁▁▁▁▁▁▁▁▂▂▂▃▄▄▄▅▅▆▇▆▆▇██▇██▇▇▇▆▅▅▅▅▆▆▇▇</td></tr><tr><td>Training_steps_per_episode</td><td>█████████████████████████████████████▁▁█</td></tr><tr><td>Training_success_rate_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁██▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>2000</td></tr><tr><td>Testing_reward_per_episode</td><td>-634.0</td></tr><tr><td>Testing_steps_per_episode</td><td>100.0</td></tr><tr><td>Testing_success_rate_per_episode</td><td>0.0</td></tr><tr><td>Training_reward_per_episode</td><td>-651.8</td></tr><tr><td>Training_steps_per_episode</td><td>100.0</td></tr><tr><td>Training_success_rate_per_episode</td><td>0.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">run_2</strong> at: <a href='https://wandb.ai/299011-unimore/gridworld_strictplay_4agents/runs/w2ly1i3a' target="_blank">https://wandb.ai/299011-unimore/gridworld_strictplay_4agents/runs/w2ly1i3a</a><br/> View project at: <a href='https://wandb.ai/299011-unimore/gridworld_strictplay_4agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_strictplay_4agents</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251227_210924-w2ly1i3a/logs</code>
# wandb version 0.23.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# ========================================
# RUN NUMBER 3/3
# ========================================
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:527: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# (RolloutWorker pid=2190059) /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (RolloutWorker pid=2190059)   from pkg_resources import resource_stream, resource_exists
# 2025-12-27 21:24:02,510	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Tracking run with wandb version 0.17.9
# Run data is saved locally in <code>/home/terra/Desktop/unimore/distributed_project/src/policies/PPO/wandb/run-20251227_212402-qlebypcp</code>
# Syncing run <strong><a href='https://wandb.ai/299011-unimore/gridworld_strictplay_4agents/runs/qlebypcp' target="_blank">run_3</a></strong> to <a href='https://wandb.ai/299011-unimore/gridworld_strictplay_4agents' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/299011-unimore/gridworld_strictplay_4agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_strictplay_4agents</a>
#  View run at <a href='https://wandb.ai/299011-unimore/gridworld_strictplay_4agents/runs/qlebypcp' target="_blank">https://wandb.ai/299011-unimore/gridworld_strictplay_4agents/runs/qlebypcp</a>
# ------------------------------------ITERATION 0, num episode 40-------------------------------------
# TRAINING
# Rew:-792.78
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-792.8
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 1, num episode 80-------------------------------------
# TRAINING
# Rew:-792.72
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-793.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 2, num episode 120------------------------------------
# TRAINING
# Rew:-792.91
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-777.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 3, num episode 160------------------------------------
# TRAINING
# Rew:-792.47
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-793.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 4, num episode 200------------------------------------
# TRAINING
# Rew:-791.24
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-767.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 5, num episode 240------------------------------------
# TRAINING
# Rew:-788.67
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-793.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 6, num episode 280------------------------------------
# TRAINING
# Rew:-787.96
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-794.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 7, num episode 320------------------------------------
# TRAINING
# Rew:-789.9
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-788.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 8, num episode 360------------------------------------
# TRAINING
# Rew:-783.74
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-791.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 9, num episode 400------------------------------------
# TRAINING
# Rew:-779.33
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-776.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 10, num episode 440------------------------------------
# TRAINING
# Rew:-776.94
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-776.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 11, num episode 480------------------------------------
# TRAINING
# Rew:-776.4
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-782.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 12, num episode 520------------------------------------
# TRAINING
# Rew:-776.39
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-787.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 13, num episode 560------------------------------------
# TRAINING
# Rew:-776.27
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-736.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 14, num episode 600------------------------------------
# TRAINING
# Rew:-778.13
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-774.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 15, num episode 640------------------------------------
# TRAINING
# Rew:-776.36
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-745.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 16, num episode 680------------------------------------
# TRAINING
# Rew:-768.31
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-789.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 17, num episode 720------------------------------------
# TRAINING
# Rew:-762.48
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-761.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 18, num episode 760------------------------------------
# TRAINING
# Rew:-760.63
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-723.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 19, num episode 800------------------------------------
# TRAINING
# Rew:-759.67
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-759.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 20, num episode 840------------------------------------
# TRAINING
# Rew:-765.69
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-768.11
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 21, num episode 880------------------------------------
# TRAINING
# Rew:-762.47
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-735.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 22, num episode 920------------------------------------
# TRAINING
# Rew:-749.86
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-752.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 23, num episode 960------------------------------------
# TRAINING
# Rew:-758.75
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-785.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 24, num episode 1000-----------------------------------
# TRAINING
# Rew:-763.01
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-755.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 25, num episode 1040-----------------------------------
# TRAINING
# Rew:-757.61
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-770.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 26, num episode 1080-----------------------------------
# TRAINING
# Rew:-760.67
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-765.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 27, num episode 1120-----------------------------------
# TRAINING
# Rew:-746.67
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-755.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 28, num episode 1160-----------------------------------
# TRAINING
# Rew:-739.63
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-690.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 29, num episode 1200-----------------------------------
# TRAINING
# Rew:-737.75
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-736.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 30, num episode 1240-----------------------------------
# TRAINING
# Rew:-726.29
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-742.44
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 31, num episode 1280-----------------------------------
# TRAINING
# Rew:-722.13
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-737.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 32, num episode 1320-----------------------------------
# TRAINING
# Rew:-731.36
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-726.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 33, num episode 1360-----------------------------------
# TRAINING
# Rew:-743.04
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-738.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 34, num episode 1400-----------------------------------
# TRAINING
# Rew:-739.95
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-721.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 35, num episode 1440-----------------------------------
# TRAINING
# Rew:-739.44
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-722.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 36, num episode 1480-----------------------------------
# TRAINING
# Rew:-724.49
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-739.44
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 37, num episode 1520-----------------------------------
# TRAINING
# Rew:-726.12
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-752.44
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 38, num episode 1560-----------------------------------
# TRAINING
# Rew:-735.84
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-748.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 39, num episode 1600-----------------------------------
# TRAINING
# Rew:-741.3
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-718.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 40, num episode 1640-----------------------------------
# TRAINING
# Rew:-726.22
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-667.0
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 41, num episode 1680-----------------------------------
# TRAINING
# Rew:-706.95
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-656.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 42, num episode 1720-----------------------------------
# TRAINING
# Rew:-693.65
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-704.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 43, num episode 1760-----------------------------------
# TRAINING
# Rew:-676.95
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-639.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 44, num episode 1800-----------------------------------
# TRAINING
# Rew:-661.26
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-680.89
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 45, num episode 1840-----------------------------------
# TRAINING
# Rew:-653.09
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-668.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 46, num episode 1880-----------------------------------
# TRAINING
# Rew:-650.98
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-588.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 47, num episode 1920-----------------------------------
# TRAINING
# Rew:-661.92
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-668.67
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 48, num episode 1960-----------------------------------
# TRAINING
# Rew:-678.17
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-606.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 49, num episode 2000-----------------------------------
# TRAINING
# Rew:-660.41
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-649.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# Model saved into /home/terra/Desktop/unimore/distributed_project/src/policies/PPO/models/strictplay_4agents_sparsereward_run_3
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>Testing_reward_per_episode</td><td>▁▁▂▁▁▁▁▁▂▁▁▃▃▁▂▃▂▃▂▁▂▂▂▅▃▃▃▃▃▃▂▃▅▆▄▆▅█▅▆</td></tr><tr><td>Testing_steps_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Testing_success_rate_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Training_reward_per_episode</td><td>▁▁▁▁▁▁▁▁▂▂▂▂▂▂▃▃▂▃▃▃▃▃▃▄▄▄▄▃▄▄▄▄▄▅▆▇██▇█</td></tr><tr><td>Training_steps_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Training_success_rate_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>2000</td></tr><tr><td>Testing_reward_per_episode</td><td>-649.33</td></tr><tr><td>Testing_steps_per_episode</td><td>100.0</td></tr><tr><td>Testing_success_rate_per_episode</td><td>0.0</td></tr><tr><td>Training_reward_per_episode</td><td>-660.41</td></tr><tr><td>Training_steps_per_episode</td><td>100.0</td></tr><tr><td>Training_success_rate_per_episode</td><td>0.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">run_3</strong> at: <a href='https://wandb.ai/299011-unimore/gridworld_strictplay_4agents/runs/qlebypcp' target="_blank">https://wandb.ai/299011-unimore/gridworld_strictplay_4agents/runs/qlebypcp</a><br/> View project at: <a href='https://wandb.ai/299011-unimore/gridworld_strictplay_4agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_strictplay_4agents</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251227_212402-qlebypcp/logs</code>
# wandb version 0.23.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# FINISHED

# %% [markdown]
# ## **Save the agents model**

# %%
import os
def save_model(ppo, file_name):
    current_dir = os.getcwd()
    model_dir = os.path.join(current_dir, "models")
    checkpoint_name = os.path.join(model_dir, file_name)
    ppo.save(checkpoint_name)

    print(f"Model saved into {checkpoint_name}")

# %% [markdown]
# ## **Load agents**

# %%
from ray.rllib.algorithms.ppo import PPO
import os

def load_model(file_name):
    current_dir = os.getcwd()
    model_dir = os.path.join(current_dir, "models")
    checkpoint_name = os.path.join(model_dir, file_name)

    ppo = PPO.from_checkpoint(checkpoint_name)
    return ppo

# %%
import os

current_dir = os.getcwd()
model_dir = os.path.join(current_dir, "models")

for filename in os.listdir(model_dir):
    if "best" in filename and under_examination in filename:
        matching_file = filename
        break

file_path = os.path.join(model_dir, matching_file)
ppo = load_model(file_path)

# %% [markdown]
# ## **Graphically test the agent**

# %%
POLICY_ID = "shared_policy" 

env = MyGridWorld(grid_size=15, n_agents=4, render_mode="human")
obs, _ = env.reset()

i = 0
while i<3:
    actions = {}
    for agent_id, agent_obs in obs.items():
        actions[agent_id] = ppo.compute_single_action(
            agent_obs, 
            policy_id=POLICY_ID,
            explore=False
        )
    
    obs, rewards, terminations, truncations, infos = env.step(actions)

    if any(terminations.values()) or any(truncations.values()):
        obs, _ = env.reset()
        i+=1
env.close()
