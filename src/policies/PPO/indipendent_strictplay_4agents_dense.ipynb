# %% [markdown]
# # **My custom env - dense reward**
#
# **Environment classe pasted here in order to make it accessible to all the workers of Ray.**
#
# It is equivalent to /myenv_6_dense_reward.py

# %%
under_examination = "strictplay_4agents_densereward"

# %%
import sys, os
from pathlib import Path

current_dir = Path(os.getcwd()) 
pointed_dir = current_dir

while True:
    if pointed_dir.is_dir() and "distributed_project" == str(pointed_dir).split("/")[-1]:
        project_dir = pointed_dir
        print(f"Project dir found: {project_dir}")
        break
    
    if pointed_dir == pointed_dir.parent:
        print("Error while looking for 'distributed_project', project dir")
        break
        
    pointed_dir = pointed_dir.parent
# Out:
# Project dir found: /home/terra/Desktop/unimore/distributed_project

# %%
import numpy as np
import functools
import gymnasium as gym
from gymnasium import spaces
from pettingzoo import ParallelEnv
import pygame 
import os
from collections import defaultdict
import random

SPRITES_DIR = f"{project_dir}/sprites"


class MyGridWorld(ParallelEnv):
    metadata = {"render_modes": ["human"], "name": "custom_grid_v0"}

    def __init__(self, render_mode=None, n_agents = 2, grid_size=15):
        if grid_size<8:
            print("Error, need to insert a grid size greater or equal to 8")
        self.grid_size = grid_size
        self.render_mode = render_mode

        ######## Agents, fixed components, and forbidden positions
        self.possible_agents = [f"agent{i}" for i in range(1, n_agents+1)]
        self.agents = self.possible_agents[:]
        self.gate_open = False

        self.fixed_components = {
            "button1":  {"pos": np.array([self.grid_size//2+2, 1+3+2]), "file": "button.png"},
            "button2":  {"pos": np.array([self.grid_size//2+2, 1+1]), "file": "button.png"},

            "gate_open":  {"pos": np.array([self.grid_size//2, 1+3]), "file": "gate_open.png"},
            "gate_close":  {"pos": np.array([self.grid_size//2, 1+3]), "file": "gate_close.png"}   
        }
        self.button1_pos = self.fixed_components["button1"]["pos"]
        self.button2_pos = self.fixed_components["button2"]["pos"]

        self.gate_pos = self.fixed_components["gate_open"]["pos"] 
        self.target_final_pos = self.gate_pos+[0, -1]

        self.x_range = (1, self.grid_size-1-1)
        self.y_range = (1+3+1, self.grid_size-1-1)
        self.forbidden_position = {tuple(self.button1_pos)}    

        self.max_cycles = 100
        self.current_cycles = 0
        ######## Pygame graphic configuration 
        self.window_size = 810
        self.cell_size = self.window_size // self.grid_size
        self.window = None
        self.clock = None
        
        # Walls
        self.grid_map = np.zeros((self.grid_size, self.grid_size))
        self.grid_map[0, :] = 1
        self.grid_map[:, 0] = 1
        self.grid_map[-1, :] = 1
        self.grid_map[:, -1] = 1
        self.grid_map[ :, 1+3] = 1

        # Sprites 
        self.agent_sprites = {}
        self.component_sprites = {}

        ######## Action space and observation space
        # Five possible actions in each grid: stay(0), up(1), down(2), left(3), right(4)
        self.action_spaces = {a: spaces.Discrete(5) for a in self.possible_agents}
        OBSERVATION_DIM = 2*(len(self.agents)-1)+3*2+1
        self.observation_spaces = {
            a: spaces.Box(low=-(self.grid_size-1), high=self.grid_size-1, shape=(OBSERVATION_DIM,), dtype=np.float32) 
            for a in self.possible_agents
        }
        self.state_spaces = {a: None for a in self.possible_agents}

    def state(self):
        observations = self.gather_observations()
        global_state = []
        
        for agent in self.possible_agents:
            if agent in observations:
                global_state.append(observations[agent])
            else:
                # Se l'agente è morto/uscito, usa zeri
                dim = self.observation_spaces[agent].shape[0]
                global_state.append(np.zeros(dim, dtype=np.float32))
                
        return np.concatenate(global_state)

    # Boilerplate PettingZoo
    def observation_space(self, agent): return self.observation_spaces[agent]
    def action_space(self, agent): return self.action_spaces[agent]

    '''
    Step in the environment
    '''
    def step(self, actions):
        if not self.agents: return {}, {}, {}, {}, {}
        self.current_cycles += 1
        
        rewards = {a: 0 for a in self.agents}

        terminations = {a: False for a in self.agents}
        truncations = {a: False for a in self.agents}
        infos = {a: {"is_success":False} for a in self.agents}
        
        desired_positions = {}      
        button_pressed = False
        agents_desire_gate = []
        for agent, action in actions.items():
            current_pos = self.agent_positions[agent].copy()
            target_pos = current_pos.copy()

            if action == 1: target_pos[1] -= 1 
            elif action == 2: target_pos[1] += 1
            elif action == 3: target_pos[0] -= 1
            elif action == 4: target_pos[0] += 1

            # Monitor button, gate and walls
            is_wall = self.grid_map[target_pos[0], target_pos[1]] == 1
            is_gate = (target_pos == self.gate_pos).all()
            is_button = (target_pos == self.button1_pos).all() or (target_pos == self.button2_pos).all()
            
            if is_button:
                button_pressed = True
            if is_gate:
                agents_desire_gate.append((agent, current_pos))
            
            if is_wall and not is_gate:
                desired_positions[agent] = current_pos 
            else:
                desired_positions[agent] = target_pos
                        
        # If gate was open remove a wall, if gate was closed update the position of those who wanted to cross it
        self.gate_open = button_pressed
        if self.gate_open:
            self.grid_map[self.gate_pos[0], self.gate_pos[1]] = 0
        else:
            self.grid_map[self.gate_pos[0], self.gate_pos[1]] = 1
            for a in agents_desire_gate:
                agent = a[0]
                current_pos = a[1]
                desired_positions[agent] = current_pos 

        # Check for conflicts (more than one agents have the same desired position)
        final_positions = self.agent_positions.copy()
        target_counts = defaultdict(list)         # Key: tuple(x, y) of desired positions, Value: list of agents desiring it
        for agent, pos in desired_positions.items():
            pos_tuple = tuple(pos)
            target_counts[pos_tuple].append(agent)

        # Solve eventual conflicts
        for pos_tuple, agents_at_target in target_counts.items():      
            # Case 1: no contended position
            if len(agents_at_target) == 1:
                agent = agents_at_target[0]
                final_positions[agent] = desired_positions[agent]
            
            # Case 2: contended position
            else:
                one_agent_already_here_not_moving = None
                for agent in agents_at_target:
                    if tuple(self.agent_positions[agent]) == pos_tuple:
                        one_agent_already_here_not_moving = agent
                        break
                
                winning_agent = one_agent_already_here_not_moving if one_agent_already_here_not_moving else random.choice(agents_at_target)
                final_positions[winning_agent] = desired_positions[winning_agent]
                
                agents_at_target.remove(winning_agent)
                for losing_agent in agents_at_target[:]:
                    final_positions[losing_agent] = self.agent_positions[losing_agent] 
        self.agent_positions = final_positions

        # Negative reward if an agent is on the bottom area and is not pressing the button
        agents_upper_area = 0
        for a, pos in self.agent_positions.items():
            dist_target = np.linalg.norm(pos - self.target_final_pos)
            if pos[1]<4:                                # Agent on upper area
                rewards[a] = +0.5
                agents_upper_area+=1

                if (pos == self.button2_pos).all():
                    rewards[a] +=0.3
            else:
                rewards[a] -= (dist_target * 0.05)      # Agent on bottom area

                if (pos == self.button1_pos).all():     # Agent on button
                    rewards[a] += 0.3     
       
        if agents_upper_area == len(self.agents):
            rewards = {a: +100 for a in self.agents}
            terminations = {a: True for a in self.agents}
            infos = {a: {"is_success":True} for a in self.agents}

        if self.current_cycles >= self.max_cycles:
            truncations= {a: True for a in self.agents}
            
        
        if self.render_mode == "human":
            self.render()
            
        final_obs = self.gather_observations()
        self.agents = [a for a in self.agents if not terminations[a]]
        return final_obs, rewards, terminations, truncations, infos
   
    '''
    Determines initial condition of the simulation
    '''

    def generate_valid_position(self):
        while True:
            x = np.random.randint(self.x_range[0], self.x_range[1])
            y = np.random.randint(self.y_range[0], self.y_range[1])
            new_position = tuple((x, y))

            if new_position not in self.forbidden_position:
                return new_position
            
    def generate_set_initial_positions(self):
        set_initial_positions = set()
        while len(set_initial_positions)<len(self.possible_agents):
            new_pos = self.generate_valid_position()
            set_initial_positions.add(new_pos)
        return set_initial_positions
    
    def generate_test_values(self, agent_num):
        if agent_num==1:
            return[7, 9]
        else:
            return [9,13]

    def reset(self, seed=None, options=None):
        self.agents = self.possible_agents[:]
        set_initial_positions = list(self.generate_set_initial_positions())
        self.current_cycles = 0

        self.agent_positions = {}
        for i, agent_id in enumerate(self.agents):
            self.agent_positions[agent_id] = np.array(set_initial_positions[i])
        
        # To visualize the reset position if "human" mode on
        if self.render_mode == "human":
            self.render()         

        return self.gather_observations(), {a: {} for a in self.agents}
    
    '''
    Observation: [my_cur_pos, (other_cur) x number of other agents, button_pos, gate_pos, gate_open (1|0)]    '''
    def gather_observations(self):
        gate_status_info = np.array([int(self.gate_open)], dtype=np.float32)
        observations = {}
        for observing_agent in self.agents:
            obs_segments = []
            observing_agent_pos = self.agent_positions[observing_agent]
            
            for other_agent in self.agents:
                if other_agent != observing_agent:
                    obs_segments.append(self.agent_positions[other_agent] - observing_agent_pos)
            obs_segments.append(self.button1_pos- observing_agent_pos)
            obs_segments.append(self.button2_pos- observing_agent_pos)
            obs_segments.append(self.gate_pos -observing_agent_pos)
            obs_segments.append(gate_status_info)
            observations[observing_agent] = np.concatenate(obs_segments, dtype=np.float32)
        return observations

    '''
    Functions for Sprite rendering and loading
    '''    
    def _create_missing_sprite(self, text, bg_color, border_color = (0,0,0)):  
        error_sprite = pygame.Surface((self.cell_size, self.cell_size), pygame.SRCALPHA)
        error_sprite.fill((0, 0, 0, 0))
        center = (self.cell_size // 2, self.cell_size // 2)
        radius = int(self.cell_size * 0.4)
        pygame.draw.circle(error_sprite, bg_color, center, radius) 
        pygame.draw.circle(error_sprite, border_color, center, radius, 2)
        
        # Add text label
        try:
            font_size = int(self.cell_size * 0.22)
            font = pygame.font.Font(None, font_size)   
            text_color = (0, 0, 0) if sum(bg_color) > 300 else (255, 255, 255) 
            text_surface = font.render(text, True, text_color)
            text_rect = text_surface.get_rect(center=center)
            error_sprite.blit(text_surface, text_rect)
            
        except Exception as e:
            print(f"WARNING: Error while writing text inside missing sprite {text}. A missing sprite without text label will be used for this simulation.")
            pass
            
        return error_sprite
    
    def _load_and_scale_sprite(self, filename, component_name):
        path = os.path.join(SPRITES_DIR, filename)
    
        try:
            image = pygame.image.load(path).convert_alpha() 
            scaled_size = int(self.cell_size )
            return pygame.transform.scale(image, (scaled_size, scaled_size))
            
        except (FileNotFoundError, pygame.error) as e:
            print(f"WARNING! Sprite image {path} not found. Using default sprite for this simulation.")
    
            text = component_name.upper() if component_name else "ERROR"
            bg_color = (100, 100, 255) if "AGENT" in text else (128,128,128) # Blue agent, Gray fixed components
            return self._create_missing_sprite(text, bg_color)

    def render(self):
        if self.render_mode is None:
            return

        if self.window is None:
            pygame.init()
            pygame.display.init()
            pygame.font.init()
            self.window = pygame.display.set_mode((self.window_size, self.window_size))
            
            for agent_name in self.agents:
               # self.agent_sprites[agent_name] = self._load_and_scale_sprite(f"{agent_name}.png", agent_name)
               self.agent_sprites[agent_name] = self._load_and_scale_sprite(".png", agent_name)

            for name, data in self.fixed_components.items():
                self.component_sprites[name] = self._load_and_scale_sprite(data["file"], name)

                 
        if self.clock is None:
            self.clock = pygame.time.Clock()

        canvas = pygame.Surface((self.window_size, self.window_size))
        canvas.fill((220, 220, 220)) 
        pix_square_size = self.cell_size 
        sprite_offset = (pix_square_size - int(pix_square_size * 0.8)) // 2

        # Render walls
        for x in range(self.grid_size):
            for y in range(self.grid_size):
                if self.grid_map[x, y] == 1:
                    pygame.draw.rect(
                        canvas, 
                        (50, 50, 50),
                        pygame.Rect(x * pix_square_size, y * pix_square_size, pix_square_size, pix_square_size)
                    )

        # Render fixed components and agents
        for name, data in self.fixed_components.items():
            if self.gate_open and name == "gate_close":
                continue
            pos = data["pos"]
            x_coord = pos[0] * pix_square_size + sprite_offset
            y_coord = pos[1] * pix_square_size + sprite_offset
            sprite = self.component_sprites[name]
            canvas.blit(sprite, (x_coord, y_coord))

        for agent in self.agents:
            pos = self.agent_positions[agent]            
            x_coord = pos[0] * pix_square_size + sprite_offset
            y_coord = pos[1] * pix_square_size + sprite_offset
            
            sprite = self.agent_sprites[agent]
            canvas.blit(sprite, (x_coord, y_coord))

        # Render the grid
        for x in range(self.grid_size + 1):
            pygame.draw.line(
                canvas, 0, (0, pix_square_size * x), (self.window_size, pix_square_size * x), width=2
            )
            pygame.draw.line(
                canvas, 0, (pix_square_size * x, 0), (pix_square_size * x, self.window_size), width=2
            )

        # Display the render
        self.window.blit(canvas, canvas.get_rect())
        pygame.event.pump()
        pygame.display.update()
        self.clock.tick(4) # FPS

    def close(self):
        if self.window is not None:
            pygame.display.quit()
            pygame.quit()
# Out:
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %% [markdown]
# **Wrap the envornment in a PettingZoo env (for compatibility with Ray) and register it on Ray lib**

# %%
from ray.rllib.env.wrappers.pettingzoo_env import ParallelPettingZooEnv
from ray.tune.registry import register_env

def env_creator(config):
    return ParallelPettingZooEnv(
        MyGridWorld(render_mode=None, n_agents=4)
    )

register_env("my_gridworld", env_creator)

# %% [markdown]
# ## **IPPO - strict play settings**

# %% [markdown]
# Callback to register episode success rate

# %%
from ray.rllib.algorithms.callbacks import DefaultCallbacks

class SuccessMetricCallback(DefaultCallbacks):
    def on_episode_end(self, *, worker, base_env, policies, episode, **kwargs):
        
        is_success = False
        one_agent_id = list(episode.get_agents())[-1]
        last_info = episode.last_info_for(one_agent_id)
        is_success = last_info["is_success"]
       
        episode.custom_metrics["success_rate"] = int(is_success)

# %%
from ray.rllib.algorithms.ppo import PPOConfig

config = (
    PPOConfig()
    .environment(env="my_gridworld")
    .env_runners(num_env_runners=0)
    .callbacks(callbacks_class=SuccessMetricCallback)
    .multi_agent(
        policies={"shared_policy"},
        policy_mapping_fn=lambda agent_id, *args, **kwargs: "shared_policy",
    )
    .api_stack(
        enable_rl_module_and_learner=False,
        enable_env_runner_and_connector_v2=False
    )
    
    .evaluation(
        evaluation_interval=1,
        evaluation_duration=10,
        evaluation_duration_unit="episodes",
        evaluation_num_env_runners=1,
        
        evaluation_config={
            "explore": True,
        }
    )
    .training(
    lr=1e-4,
    train_batch_size_per_learner=4000,
    num_epochs=5,
    entropy_coeff=0.01,
    kl_coeff=0.2,
    kl_target=0.01
    )

)

# %% [markdown]
# ## **Wandb - One run of training**

# %%
import wandb
#wandb.init(project="gridworld_looseplay_2agents", name="densereward")
ppo = config.build_algo()
num_total_episodes = 0
for i in range(50):
    result = ppo.train()
    num_total_episodes += result['env_runners']['num_episodes']
    
    print(f"ITERATION {i}, num episode {num_total_episodes}".center(100,"-"))
    train_rew = round(result['env_runners']['episode_return_mean'], 2)
    train_steps_episode = round(result['env_runners']['episode_len_mean'], 2)
    train_success_rate = round(result['env_runners']['custom_metrics'].get('success_rate_mean', 0), 2) * 100
    print(f"""TRAINING\nRew:{train_rew} \nSteps per episode:{train_steps_episode} \nSuccess rate:{train_success_rate}%\n""")

    if 'evaluation' in result:
        testing_rew = round(result['evaluation']['env_runners']['episode_return_mean'], 2)
        testing_steps_episode = round(result['evaluation']['env_runners']['episode_len_mean'], 2)
        testing_success_rate = round(result['evaluation']['env_runners']['custom_metrics'].get('success_rate_mean', 0), 2) * 100
        print(f"""TESTING\nRew:{testing_rew} \nSteps per episode:{testing_steps_episode} \nSuccess rate:{testing_success_rate}%\n\n""")

    log_data = {
        "Episodes": num_total_episodes,

        "Training_steps_per_episode": train_steps_episode,
        "Training_success_rate_per_episode": train_success_rate,
        "Training_reward_per_episode": train_rew,

        "Testing_steps_per_episode": testing_steps_episode,
        "Testing_success_rate_per_episode": testing_success_rate,
        "Testing_reward_per_episode": testing_rew
    }
    #wandb.log(log_data)
#wandb.finish()

# %% [markdown]
# ## **Wandb, 3 runs of training to generate esteme**

# %%
import wandb
group_name = "dense"

for run_idx in range(1,4):
    print(f"\n{'='*40}")
    print(f"RUN NUMBER {run_idx}/3")
    print(f"{'='*40}\n")

    ppo = config.build_algo()
    wandb.init(
        project="gridworld_strictplay_4agents",
        group=group_name,           
        name=f"run_{run_idx}",    
        reinit=True 
    )
    file_name = f"{under_examination}_run_{run_idx}"
    
    num_total_episodes = 0
    for i in range(50):
        result = ppo.train()
        num_total_episodes += result['env_runners']['num_episodes']
        
        print(f"ITERATION {i}, num episode {num_total_episodes}".center(100,"-"))
        train_rew = round(result['env_runners']['episode_return_mean'], 2)
        train_steps_episode = round(result['env_runners']['episode_len_mean'], 2)
        train_success_rate = round(result['env_runners']['custom_metrics'].get('success_rate_mean', 0), 2) * 100
        print(f"""TRAINING\nRew:{train_rew} \nSteps per episode:{train_steps_episode} \nSuccess rate:{train_success_rate}%\n""")

        if 'evaluation' in result:
            testing_rew = round(result['evaluation']['env_runners']['episode_return_mean'], 2)
            testing_steps_episode = round(result['evaluation']['env_runners']['episode_len_mean'], 2)
            testing_success_rate = round(result['evaluation']['env_runners']['custom_metrics'].get('success_rate_mean', 0), 2) * 100
            print(f"""TESTING\nRew:{testing_rew} \nSteps per episode:{testing_steps_episode} \nSuccess rate:{testing_success_rate}%\n\n""")

        log_data = {
            "Episodes": num_total_episodes,

            "Training_steps_per_episode": train_steps_episode,
            "Training_success_rate_per_episode": train_success_rate,
            "Training_reward_per_episode": train_rew,

            "Testing_steps_per_episode": testing_steps_episode,
            "Testing_success_rate_per_episode": testing_success_rate,
            "Testing_reward_per_episode": testing_rew
        }
        wandb.log(log_data)
    save_model(ppo, file_name)
    wandb.finish()

print("FINISHED")
# Out:
# ========================================
# RUN NUMBER 1/3
# ========================================
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:527: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/google/api_core/_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2025-12-27 11:58:49,085	INFO worker.py:2007 -- Started a local Ray instance.
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/_private/worker.py:2046: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# [2025-12-27 11:58:50,911 E 858607 858607] core_worker.cc:2223: Actor with class name: 'RolloutWorker' and ID: '41a89da2481d58dba8f1d75801000000' has constructor arguments in the object store and max_restarts > 0. If the arguments in the object store go out of scope or are lost, the actor restart will fail. See https://github.com/ray-project/ray/issues/53727 for more details.
# (RolloutWorker pid=858853) /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (RolloutWorker pid=858853)   from pkg_resources import resource_stream, resource_exists
# 2025-12-27 11:58:53,912	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: 299011 (299011-unimore). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.17.9
# Run data is saved locally in <code>/home/terra/Desktop/unimore/distributed_project/src/policies/PPO/wandb/run-20251227_115855-sftqux00</code>
# Syncing run <strong><a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/sftqux00' target="_blank">run_1</a></strong> to <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_4agents</a>
#  View run at <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/sftqux00' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/sftqux00</a>
# 2025-12-27 11:59:05,649	WARNING sgd.py:55 -- DeprecationWarning: `_get_slice_indices` has been deprecated. This will raise an error in the future!
# ------------------------------------ITERATION 0, num episode 40-------------------------------------
# TRAINING
# Rew:-136.74
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-104.43
# Steps per episode:100.0
# Success rate:0.0%
# (pid=gcs_server) [2025-12-27 11:59:18,198 E 858680 858680] (gcs_server) gcs_server.cc:303: Failed to establish connection to the event+metrics exporter agent. Events and metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (raylet) [2025-12-27 11:59:19,010 E 858794 858794] (raylet) main.cc:1032: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (RolloutWorker pid=858853) [2025-12-27 11:59:19,697 E 858853 858989] core_worker_process.cc:842: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# [2025-12-27 11:59:19,912 E 858607 858847] core_worker_process.cc:842: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# ------------------------------------ITERATION 1, num episode 80-------------------------------------
# TRAINING
# Rew:-116.58
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-52.64
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 2, num episode 120------------------------------------
# TRAINING
# Rew:-92.4
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-24.53
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 3, num episode 160------------------------------------
# TRAINING
# Rew:-59.11
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-26.44
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 4, num episode 200------------------------------------
# TRAINING
# Rew:-34.98
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-29.62
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 5, num episode 240------------------------------------
# TRAINING
# Rew:-21.94
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-4.92
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 6, num episode 280------------------------------------
# TRAINING
# Rew:-16.9
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-28.66
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 7, num episode 320------------------------------------
# TRAINING
# Rew:-15.63
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-15.54
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 8, num episode 360------------------------------------
# TRAINING
# Rew:-16.81
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-31.17
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 9, num episode 400------------------------------------
# TRAINING
# Rew:-19.36
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-25.22
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 10, num episode 440------------------------------------
# TRAINING
# Rew:-25.14
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-20.94
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 11, num episode 480------------------------------------
# TRAINING
# Rew:-27.02
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-27.86
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 12, num episode 520------------------------------------
# TRAINING
# Rew:-32.29
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-30.93
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 13, num episode 560------------------------------------
# TRAINING
# Rew:-26.9
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-44.55
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 14, num episode 600------------------------------------
# TRAINING
# Rew:-26.38
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-45.05
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 15, num episode 640------------------------------------
# TRAINING
# Rew:-32.86
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-33.38
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 16, num episode 680------------------------------------
# TRAINING
# Rew:-43.86
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-25.78
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 17, num episode 720------------------------------------
# TRAINING
# Rew:-46.15
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-48.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 18, num episode 760------------------------------------
# TRAINING
# Rew:-45.04
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-37.05
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 19, num episode 800------------------------------------
# TRAINING
# Rew:-43.39
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-50.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 20, num episode 840------------------------------------
# TRAINING
# Rew:-43.05
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-37.27
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 21, num episode 880------------------------------------
# TRAINING
# Rew:-43.24
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-49.4
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 22, num episode 920------------------------------------
# TRAINING
# Rew:-42.36
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-29.83
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 23, num episode 960------------------------------------
# TRAINING
# Rew:-41.4
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-46.37
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 24, num episode 1000-----------------------------------
# TRAINING
# Rew:-37.9
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-14.36
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 25, num episode 1040-----------------------------------
# TRAINING
# Rew:-37.83
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-41.21
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 26, num episode 1080-----------------------------------
# TRAINING
# Rew:-36.27
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-27.56
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 27, num episode 1120-----------------------------------
# TRAINING
# Rew:-33.16
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-20.02
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 28, num episode 1160-----------------------------------
# TRAINING
# Rew:-26.0
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-27.96
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 29, num episode 1200-----------------------------------
# TRAINING
# Rew:-27.42
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-27.42
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 30, num episode 1240-----------------------------------
# TRAINING
# Rew:-28.07
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-34.21
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 31, num episode 1280-----------------------------------
# TRAINING
# Rew:-27.8
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-40.76
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 32, num episode 1320-----------------------------------
# TRAINING
# Rew:-25.47
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-32.85
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 33, num episode 1360-----------------------------------
# TRAINING
# Rew:-24.25
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-26.94
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 34, num episode 1400-----------------------------------
# TRAINING
# Rew:-25.93
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-33.46
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 35, num episode 1440-----------------------------------
# TRAINING
# Rew:-27.49
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-15.25
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 36, num episode 1480-----------------------------------
# TRAINING
# Rew:-25.36
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-27.85
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 37, num episode 1520-----------------------------------
# TRAINING
# Rew:-24.76
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-16.85
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 38, num episode 1560-----------------------------------
# TRAINING
# Rew:-27.73
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-20.84
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 39, num episode 1600-----------------------------------
# TRAINING
# Rew:-29.35
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:4.92
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 40, num episode 1640-----------------------------------
# TRAINING
# Rew:-22.92
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-20.52
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 41, num episode 1680-----------------------------------
# TRAINING
# Rew:-21.02
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-34.35
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 42, num episode 1720-----------------------------------
# TRAINING
# Rew:-19.13
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:2.99
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 43, num episode 1760-----------------------------------
# TRAINING
# Rew:-20.31
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-7.4
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 44, num episode 1800-----------------------------------
# TRAINING
# Rew:-21.6
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-39.05
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 45, num episode 1840-----------------------------------
# TRAINING
# Rew:-17.61
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-39.38
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 46, num episode 1880-----------------------------------
# TRAINING
# Rew:-15.77
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-32.65
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 47, num episode 1920-----------------------------------
# TRAINING
# Rew:-18.23
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-33.17
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 48, num episode 1960-----------------------------------
# TRAINING
# Rew:-20.56
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-14.59
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 49, num episode 2000-----------------------------------
# TRAINING
# Rew:-20.45
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-14.33
# Steps per episode:100.0
# Success rate:0.0%
#
#
# Model saved into /home/terra/Desktop/unimore/distributed_project/src/policies/PPO/models/loosplay_4agents_densereward_run_1
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>Testing_reward_per_episode</td><td>▁▄▆▆▇▆▇▆▆▆▆▅▆▆▅▅▅▅▆▅▅▆▇▆▆▅▆▆▇▆▇▆▆▆█▇▅▆▆▇</td></tr><tr><td>Testing_steps_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Testing_success_rate_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Training_reward_per_episode</td><td>▁▂▄▅████▇▇▇▇▇▆▆▆▆▆▆▇▇▇▇▇▇▇▇█▇▇▇▇████████</td></tr><tr><td>Training_steps_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Training_success_rate_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>2000</td></tr><tr><td>Testing_reward_per_episode</td><td>-14.33</td></tr><tr><td>Testing_steps_per_episode</td><td>100.0</td></tr><tr><td>Testing_success_rate_per_episode</td><td>0.0</td></tr><tr><td>Training_reward_per_episode</td><td>-20.45</td></tr><tr><td>Training_steps_per_episode</td><td>100.0</td></tr><tr><td>Training_success_rate_per_episode</td><td>0.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">run_1</strong> at: <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/sftqux00' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/sftqux00</a><br/> View project at: <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_4agents</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251227_115855-sftqux00/logs</code>
# wandb version 0.23.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# ========================================
# RUN NUMBER 2/3
# ========================================
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:527: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# (RolloutWorker pid=858855) /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (RolloutWorker pid=858855)   from pkg_resources import resource_stream, resource_exists
# (pid=858859) [2025-12-27 11:59:19,850 E 858859 859293] core_worker_process.cc:842: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14 [repeated 11x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# 2025-12-27 12:10:30,779	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Tracking run with wandb version 0.17.9
# Run data is saved locally in <code>/home/terra/Desktop/unimore/distributed_project/src/policies/PPO/wandb/run-20251227_121030-wa44ew7h</code>
# Syncing run <strong><a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/wa44ew7h' target="_blank">run_2</a></strong> to <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_4agents</a>
#  View run at <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/wa44ew7h' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/wa44ew7h</a>
# ------------------------------------ITERATION 0, num episode 40-------------------------------------
# TRAINING
# Rew:-144.18
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-113.15
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 1, num episode 80-------------------------------------
# TRAINING
# Rew:-120.78
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-45.14
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 2, num episode 120------------------------------------
# TRAINING
# Rew:-87.29
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-23.72
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 3, num episode 160------------------------------------
# TRAINING
# Rew:-47.61
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-9.14
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 4, num episode 200------------------------------------
# TRAINING
# Rew:-25.79
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-0.24
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 5, num episode 240------------------------------------
# TRAINING
# Rew:-11.35
# Steps per episode:99.66
# Success rate:1.0%
#
# TESTING
# Rew:21.48
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 6, num episode 280------------------------------------
# TRAINING
# Rew:-6.06
# Steps per episode:99.66
# Success rate:1.0%
#
# TESTING
# Rew:3.84
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 7, num episode 320------------------------------------
# TRAINING
# Rew:-0.56
# Steps per episode:99.66
# Success rate:1.0%
#
# TESTING
# Rew:-10.08
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 8, num episode 360------------------------------------
# TRAINING
# Rew:2.51
# Steps per episode:99.98
# Success rate:1.0%
#
# TESTING
# Rew:-7.71
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 9, num episode 400------------------------------------
# TRAINING
# Rew:4.66
# Steps per episode:99.98
# Success rate:1.0%
#
# TESTING
# Rew:-8.03
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 10, num episode 440------------------------------------
# TRAINING
# Rew:-2.62
# Steps per episode:99.93
# Success rate:1.0%
#
# TESTING
# Rew:-34.52
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 11, num episode 480------------------------------------
# TRAINING
# Rew:-3.82
# Steps per episode:99.76
# Success rate:2.0%
#
# TESTING
# Rew:-7.55
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 12, num episode 521------------------------------------
# TRAINING
# Rew:-5.22
# Steps per episode:99.36
# Success rate:3.0%
#
# TESTING
# Rew:58.4
# Steps per episode:98.44
# Success rate:11.0%
#
#
# -----------------------------------ITERATION 13, num episode 561------------------------------------
# TRAINING
# Rew:17.51
# Steps per episode:98.52
# Success rate:7.000000000000001%
#
# TESTING
# Rew:7.05
# Steps per episode:100.0
# Success rate:0.0%
#
#
# -----------------------------------ITERATION 14, num episode 602------------------------------------
# TRAINING
# Rew:25.56
# Steps per episode:98.32
# Success rate:8.0%
#
# TESTING
# Rew:34.01
# Steps per episode:100.0
# Success rate:11.0%
#
#
# -----------------------------------ITERATION 15, num episode 642------------------------------------
# TRAINING
# Rew:15.51
# Steps per episode:98.8
# Success rate:6.0%
#
# TESTING
# Rew:69.62
# Steps per episode:98.22
# Success rate:22.0%
#
#
# -----------------------------------ITERATION 16, num episode 684------------------------------------
# TRAINING
# Rew:28.76
# Steps per episode:97.68
# Success rate:10.0%
#
# TESTING
# Rew:60.7
# Steps per episode:92.89
# Success rate:22.0%
#
#
# -----------------------------------ITERATION 17, num episode 727------------------------------------
# TRAINING
# Rew:52.44
# Steps per episode:94.83
# Success rate:17.0%
#
# TESTING
# Rew:178.89
# Steps per episode:82.33
# Success rate:44.0%
#
#
# -----------------------------------ITERATION 18, num episode 774------------------------------------
# TRAINING
# Rew:116.97
# Steps per episode:88.97
# Success rate:31.0%
#
# TESTING
# Rew:139.67
# Steps per episode:93.22
# Success rate:33.0%
#
#
# -----------------------------------ITERATION 19, num episode 826------------------------------------
# TRAINING
# Rew:214.18
# Steps per episode:81.14
# Success rate:52.0%
#
# TESTING
# Rew:414.74
# Steps per episode:49.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 20, num episode 885------------------------------------
# TRAINING
# Rew:313.62
# Steps per episode:71.92
# Success rate:74.0%
#
# TESTING
# Rew:413.4
# Steps per episode:41.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 21, num episode 954------------------------------------
# TRAINING
# Rew:368.81
# Steps per episode:61.31
# Success rate:88.0%
#
# TESTING
# Rew:415.28
# Steps per episode:47.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 22, num episode 1031-----------------------------------
# TRAINING
# Rew:389.95
# Steps per episode:54.96
# Success rate:94.0%
#
# TESTING
# Rew:412.88
# Steps per episode:61.67
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 23, num episode 1112-----------------------------------
# TRAINING
# Rew:396.47
# Steps per episode:51.18
# Success rate:96.0%
#
# TESTING
# Rew:418.51
# Steps per episode:55.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 24, num episode 1189-----------------------------------
# TRAINING
# Rew:395.05
# Steps per episode:51.67
# Success rate:95.0%
#
# TESTING
# Rew:416.11
# Steps per episode:52.0
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 25, num episode 1276-----------------------------------
# TRAINING
# Rew:408.09
# Steps per episode:46.84
# Success rate:98.0%
#
# TESTING
# Rew:409.66
# Steps per episode:47.0
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 26, num episode 1354-----------------------------------
# TRAINING
# Rew:397.86
# Steps per episode:49.52
# Success rate:96.0%
#
# TESTING
# Rew:409.71
# Steps per episode:39.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 27, num episode 1441-----------------------------------
# TRAINING
# Rew:401.98
# Steps per episode:46.79
# Success rate:98.0%
#
# TESTING
# Rew:411.63
# Steps per episode:37.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 28, num episode 1538-----------------------------------
# TRAINING
# Rew:410.56
# Steps per episode:41.04
# Success rate:100.0%
#
# TESTING
# Rew:408.2
# Steps per episode:40.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 29, num episode 1633-----------------------------------
# TRAINING
# Rew:398.89
# Steps per episode:42.06
# Success rate:98.0%
#
# TESTING
# Rew:408.09
# Steps per episode:41.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 30, num episode 1731-----------------------------------
# TRAINING
# Rew:410.67
# Steps per episode:40.54
# Success rate:100.0%
#
# TESTING
# Rew:406.86
# Steps per episode:45.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 31, num episode 1827-----------------------------------
# TRAINING
# Rew:407.72
# Steps per episode:41.66
# Success rate:99.0%
#
# TESTING
# Rew:372.39
# Steps per episode:50.78
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 32, num episode 1930-----------------------------------
# TRAINING
# Rew:409.6
# Steps per episode:38.9
# Success rate:99.0%
#
# TESTING
# Rew:418.81
# Steps per episode:50.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 33, num episode 2026-----------------------------------
# TRAINING
# Rew:414.15
# Steps per episode:41.53
# Success rate:100.0%
#
# TESTING
# Rew:415.07
# Steps per episode:36.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 34, num episode 2130-----------------------------------
# TRAINING
# Rew:407.41
# Steps per episode:38.52
# Success rate:99.0%
#
# TESTING
# Rew:412.61
# Steps per episode:30.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 35, num episode 2248-----------------------------------
# TRAINING
# Rew:409.6
# Steps per episode:34.06
# Success rate:100.0%
#
# TESTING
# Rew:405.13
# Steps per episode:31.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 36, num episode 2371-----------------------------------
# TRAINING
# Rew:407.15
# Steps per episode:32.53
# Success rate:100.0%
#
# TESTING
# Rew:408.87
# Steps per episode:35.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 37, num episode 2485-----------------------------------
# TRAINING
# Rew:405.1
# Steps per episode:34.96
# Success rate:99.0%
#
# TESTING
# Rew:411.16
# Steps per episode:40.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 38, num episode 2602-----------------------------------
# TRAINING
# Rew:408.63
# Steps per episode:34.25
# Success rate:100.0%
#
# TESTING
# Rew:416.2
# Steps per episode:42.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 39, num episode 2696-----------------------------------
# TRAINING
# Rew:415.47
# Steps per episode:42.14
# Success rate:100.0%
#
# TESTING
# Rew:416.0
# Steps per episode:46.0
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 40, num episode 2787-----------------------------------
# TRAINING
# Rew:417.59
# Steps per episode:44.22
# Success rate:99.0%
#
# TESTING
# Rew:415.34
# Steps per episode:38.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 41, num episode 2885-----------------------------------
# TRAINING
# Rew:405.87
# Steps per episode:41.12
# Success rate:98.0%
#
# TESTING
# Rew:416.27
# Steps per episode:39.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 42, num episode 2992-----------------------------------
# TRAINING
# Rew:409.88
# Steps per episode:37.35
# Success rate:99.0%
#
# TESTING
# Rew:408.69
# Steps per episode:29.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 43, num episode 3109-----------------------------------
# TRAINING
# Rew:411.16
# Steps per episode:34.19
# Success rate:100.0%
#
# TESTING
# Rew:406.57
# Steps per episode:28.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 44, num episode 3228-----------------------------------
# TRAINING
# Rew:412.52
# Steps per episode:33.68
# Success rate:100.0%
#
# TESTING
# Rew:414.48
# Steps per episode:35.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 45, num episode 3346-----------------------------------
# TRAINING
# Rew:410.4
# Steps per episode:33.88
# Success rate:100.0%
#
# TESTING
# Rew:410.08
# Steps per episode:29.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 46, num episode 3459-----------------------------------
# TRAINING
# Rew:411.27
# Steps per episode:35.56
# Success rate:100.0%
#
# TESTING
# Rew:409.06
# Steps per episode:32.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 47, num episode 3575-----------------------------------
# TRAINING
# Rew:412.35
# Steps per episode:34.29
# Success rate:100.0%
#
# TESTING
# Rew:412.4
# Steps per episode:34.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 48, num episode 3686-----------------------------------
# TRAINING
# Rew:411.52
# Steps per episode:36.12
# Success rate:100.0%
#
# TESTING
# Rew:423.41
# Steps per episode:38.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 49, num episode 3797-----------------------------------
# TRAINING
# Rew:415.23
# Steps per episode:36.09
# Success rate:100.0%
#
# TESTING
# Rew:413.51
# Steps per episode:32.22
# Success rate:100.0%
#
#
# Model saved into /home/terra/Desktop/unimore/distributed_project/src/policies/PPO/models/loosplay_4agents_densereward_run_2
# VBox(children=(Label(value='0.002 MB of 0.027 MB uploaded\r'), FloatProgress(value=0.08473553425630102, max=1.…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>▁▁▁▁▁▁▂▂▂▂▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>Testing_reward_per_episode</td><td>▁▂▂▂▃▃▂▂▂▂▃▃▃▃▅▄█████████▇██████████████</td></tr><tr><td>Testing_steps_per_episode</td><td>█████████████▇▆▇▂▃▄▄▃▂▂▂▃▃▃▂▁▂▂▂▂▂▁▁▁▁▂▁</td></tr><tr><td>Testing_success_rate_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▂▁▃▃▄▃█████████▇██████████████</td></tr><tr><td>Training_reward_per_episode</td><td>▁▁▂▂▃▃▃▃▃▃▃▃▃▃▃▄▇▇██████████████████████</td></tr><tr><td>Training_steps_per_episode</td><td>██████████████▇▇▅▄▃▃▂▃▂▂▂▂▂▂▁▁▁▁▂▂▂▁▁▁▁▁</td></tr><tr><td>Training_success_rate_per_episode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▃▆▇██████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>3797</td></tr><tr><td>Testing_reward_per_episode</td><td>413.51</td></tr><tr><td>Testing_steps_per_episode</td><td>32.22</td></tr><tr><td>Testing_success_rate_per_episode</td><td>100.0</td></tr><tr><td>Training_reward_per_episode</td><td>415.23</td></tr><tr><td>Training_steps_per_episode</td><td>36.09</td></tr><tr><td>Training_success_rate_per_episode</td><td>100.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">run_2</strong> at: <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/wa44ew7h' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/wa44ew7h</a><br/> View project at: <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_4agents</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251227_121030-wa44ew7h/logs</code>
# wandb version 0.23.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# ========================================
# RUN NUMBER 3/3
# ========================================
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:527: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# (RolloutWorker pid=858852) /home/terra/anaconda3/envs/MARL/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (RolloutWorker pid=858852)   from pkg_resources import resource_stream, resource_exists
# 2025-12-27 12:21:43,251	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Tracking run with wandb version 0.17.9
# Run data is saved locally in <code>/home/terra/Desktop/unimore/distributed_project/src/policies/PPO/wandb/run-20251227_122143-un1j07cx</code>
# Syncing run <strong><a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/un1j07cx' target="_blank">run_3</a></strong> to <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_4agents</a>
#  View run at <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/un1j07cx' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/un1j07cx</a>
# ------------------------------------ITERATION 0, num episode 40-------------------------------------
# TRAINING
# Rew:-138.5
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-84.57
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 1, num episode 80-------------------------------------
# TRAINING
# Rew:-110.57
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-38.95
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 2, num episode 120------------------------------------
# TRAINING
# Rew:-82.29
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:-23.72
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 3, num episode 160------------------------------------
# TRAINING
# Rew:-50.85
# Steps per episode:100.0
# Success rate:0.0%
#
# TESTING
# Rew:17.65
# Steps per episode:100.0
# Success rate:0.0%
#
#
# ------------------------------------ITERATION 4, num episode 200------------------------------------
# TRAINING
# Rew:-30.85
# Steps per episode:99.55
# Success rate:1.0%
#
# TESTING
# Rew:18.18
# Steps per episode:94.44
# Success rate:11.0%
#
#
# ------------------------------------ITERATION 5, num episode 242------------------------------------
# TRAINING
# Rew:8.52
# Steps per episode:97.92
# Success rate:9.0%
#
# TESTING
# Rew:90.66
# Steps per episode:95.78
# Success rate:22.0%
#
#
# ------------------------------------ITERATION 6, num episode 283------------------------------------
# TRAINING
# Rew:36.71
# Steps per episode:97.14
# Success rate:14.000000000000002%
#
# TESTING
# Rew:105.3
# Steps per episode:92.44
# Success rate:33.0%
#
#
# ------------------------------------ITERATION 7, num episode 329------------------------------------
# TRAINING
# Rew:95.53
# Steps per episode:92.72
# Success rate:28.000000000000004%
#
# TESTING
# Rew:318.5
# Steps per episode:75.78
# Success rate:78.0%
#
#
# ------------------------------------ITERATION 8, num episode 384------------------------------------
# TRAINING
# Rew:234.86
# Steps per episode:79.22
# Success rate:60.0%
#
# TESTING
# Rew:403.12
# Steps per episode:63.11
# Success rate:100.0%
#
#
# ------------------------------------ITERATION 9, num episode 444------------------------------------
# TRAINING
# Rew:330.76
# Steps per episode:68.83
# Success rate:82.0%
#
# TESTING
# Rew:361.36
# Steps per episode:61.89
# Success rate:89.0%
#
#
# -----------------------------------ITERATION 10, num episode 506------------------------------------
# TRAINING
# Rew:378.56
# Steps per episode:64.41
# Success rate:93.0%
#
# TESTING
# Rew:401.05
# Steps per episode:56.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 11, num episode 575------------------------------------
# TRAINING
# Rew:387.17
# Steps per episode:60.13
# Success rate:96.0%
#
# TESTING
# Rew:404.98
# Steps per episode:50.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 12, num episode 658------------------------------------
# TRAINING
# Rew:397.19
# Steps per episode:48.81
# Success rate:99.0%
#
# TESTING
# Rew:393.91
# Steps per episode:43.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 13, num episode 744------------------------------------
# TRAINING
# Rew:399.89
# Steps per episode:46.4
# Success rate:100.0%
#
# TESTING
# Rew:403.96
# Steps per episode:44.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 14, num episode 839------------------------------------
# TRAINING
# Rew:401.43
# Steps per episode:43.14
# Success rate:99.0%
#
# TESTING
# Rew:400.62
# Steps per episode:35.67
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 15, num episode 938------------------------------------
# TRAINING
# Rew:401.98
# Steps per episode:40.39
# Success rate:100.0%
#
# TESTING
# Rew:403.57
# Steps per episode:45.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 16, num episode 1040-----------------------------------
# TRAINING
# Rew:403.48
# Steps per episode:39.33
# Success rate:100.0%
#
# TESTING
# Rew:404.55
# Steps per episode:39.67
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 17, num episode 1150-----------------------------------
# TRAINING
# Rew:402.17
# Steps per episode:36.05
# Success rate:100.0%
#
# TESTING
# Rew:404.48
# Steps per episode:35.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 18, num episode 1257-----------------------------------
# TRAINING
# Rew:395.24
# Steps per episode:37.44
# Success rate:99.0%
#
# TESTING
# Rew:403.82
# Steps per episode:26.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 19, num episode 1384-----------------------------------
# TRAINING
# Rew:401.89
# Steps per episode:31.56
# Success rate:100.0%
#
# TESTING
# Rew:405.73
# Steps per episode:29.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 20, num episode 1513-----------------------------------
# TRAINING
# Rew:402.66
# Steps per episode:31.02
# Success rate:100.0%
#
# TESTING
# Rew:401.09
# Steps per episode:28.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 21, num episode 1640-----------------------------------
# TRAINING
# Rew:403.21
# Steps per episode:31.63
# Success rate:100.0%
#
# TESTING
# Rew:408.93
# Steps per episode:35.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 22, num episode 1761-----------------------------------
# TRAINING
# Rew:404.62
# Steps per episode:33.02
# Success rate:100.0%
#
# TESTING
# Rew:406.84
# Steps per episode:26.0
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 23, num episode 1893-----------------------------------
# TRAINING
# Rew:405.78
# Steps per episode:30.18
# Success rate:100.0%
#
# TESTING
# Rew:408.7
# Steps per episode:32.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 24, num episode 2035-----------------------------------
# TRAINING
# Rew:404.66
# Steps per episode:28.33
# Success rate:100.0%
#
# TESTING
# Rew:402.28
# Steps per episode:29.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 25, num episode 2182-----------------------------------
# TRAINING
# Rew:404.67
# Steps per episode:27.13
# Success rate:100.0%
#
# TESTING
# Rew:404.48
# Steps per episode:26.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 26, num episode 2323-----------------------------------
# TRAINING
# Rew:405.43
# Steps per episode:28.48
# Success rate:100.0%
#
# TESTING
# Rew:404.34
# Steps per episode:29.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 27, num episode 2463-----------------------------------
# TRAINING
# Rew:405.49
# Steps per episode:28.49
# Success rate:100.0%
#
# TESTING
# Rew:409.29
# Steps per episode:33.67
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 28, num episode 2606-----------------------------------
# TRAINING
# Rew:404.96
# Steps per episode:27.9
# Success rate:100.0%
#
# TESTING
# Rew:403.96
# Steps per episode:34.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 29, num episode 2752-----------------------------------
# TRAINING
# Rew:405.18
# Steps per episode:27.45
# Success rate:100.0%
#
# TESTING
# Rew:405.15
# Steps per episode:28.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 30, num episode 2900-----------------------------------
# TRAINING
# Rew:404.25
# Steps per episode:26.95
# Success rate:100.0%
#
# TESTING
# Rew:410.21
# Steps per episode:32.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 31, num episode 3040-----------------------------------
# TRAINING
# Rew:405.68
# Steps per episode:28.71
# Success rate:100.0%
#
# TESTING
# Rew:406.38
# Steps per episode:27.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 32, num episode 3184-----------------------------------
# TRAINING
# Rew:405.84
# Steps per episode:27.82
# Success rate:100.0%
#
# TESTING
# Rew:407.2
# Steps per episode:25.0
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 33, num episode 3324-----------------------------------
# TRAINING
# Rew:408.13
# Steps per episode:28.36
# Success rate:100.0%
#
# TESTING
# Rew:407.9
# Steps per episode:26.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 34, num episode 3473-----------------------------------
# TRAINING
# Rew:407.92
# Steps per episode:26.98
# Success rate:100.0%
#
# TESTING
# Rew:407.22
# Steps per episode:27.0
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 35, num episode 3623-----------------------------------
# TRAINING
# Rew:407.06
# Steps per episode:26.59
# Success rate:100.0%
#
# TESTING
# Rew:408.33
# Steps per episode:24.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 36, num episode 3768-----------------------------------
# TRAINING
# Rew:407.58
# Steps per episode:27.65
# Success rate:100.0%
#
# TESTING
# Rew:403.94
# Steps per episode:27.22
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 37, num episode 3914-----------------------------------
# TRAINING
# Rew:406.07
# Steps per episode:27.38
# Success rate:100.0%
#
# TESTING
# Rew:407.25
# Steps per episode:29.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 38, num episode 4057-----------------------------------
# TRAINING
# Rew:407.29
# Steps per episode:27.99
# Success rate:100.0%
#
# TESTING
# Rew:406.88
# Steps per episode:26.0
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 39, num episode 4201-----------------------------------
# TRAINING
# Rew:405.71
# Steps per episode:27.83
# Success rate:100.0%
#
# TESTING
# Rew:408.0
# Steps per episode:24.67
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 40, num episode 4353-----------------------------------
# TRAINING
# Rew:406.31
# Steps per episode:26.34
# Success rate:100.0%
#
# TESTING
# Rew:405.33
# Steps per episode:25.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 41, num episode 4497-----------------------------------
# TRAINING
# Rew:405.22
# Steps per episode:27.72
# Success rate:100.0%
#
# TESTING
# Rew:408.16
# Steps per episode:26.78
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 42, num episode 4637-----------------------------------
# TRAINING
# Rew:398.8
# Steps per episode:28.6
# Success rate:99.0%
#
# TESTING
# Rew:404.8
# Steps per episode:19.89
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 43, num episode 4800-----------------------------------
# TRAINING
# Rew:405.27
# Steps per episode:24.53
# Success rate:100.0%
#
# TESTING
# Rew:403.28
# Steps per episode:24.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 44, num episode 4967-----------------------------------
# TRAINING
# Rew:405.35
# Steps per episode:23.98
# Success rate:100.0%
#
# TESTING
# Rew:404.24
# Steps per episode:21.44
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 45, num episode 5130-----------------------------------
# TRAINING
# Rew:405.14
# Steps per episode:24.49
# Success rate:100.0%
#
# TESTING
# Rew:407.6
# Steps per episode:25.67
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 46, num episode 5289-----------------------------------
# TRAINING
# Rew:405.6
# Steps per episode:25.11
# Success rate:100.0%
#
# TESTING
# Rew:407.11
# Steps per episode:31.33
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 47, num episode 5435-----------------------------------
# TRAINING
# Rew:407.1
# Steps per episode:27.48
# Success rate:100.0%
#
# TESTING
# Rew:410.27
# Steps per episode:25.56
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 48, num episode 5590-----------------------------------
# TRAINING
# Rew:406.67
# Steps per episode:25.77
# Success rate:100.0%
#
# TESTING
# Rew:409.02
# Steps per episode:27.11
# Success rate:100.0%
#
#
# -----------------------------------ITERATION 49, num episode 5733-----------------------------------
# TRAINING
# Rew:408.0
# Steps per episode:28.03
# Success rate:100.0%
#
# TESTING
# Rew:405.2
# Steps per episode:24.0
# Success rate:100.0%
#
#
# Model saved into /home/terra/Desktop/unimore/distributed_project/src/policies/PPO/models/loosplay_4agents_densereward_run_3
# VBox(children=(Label(value='0.002 MB of 0.026 MB uploaded\r'), FloatProgress(value=0.0870341360340996, max=1.0…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇██</td></tr><tr><td>Testing_reward_per_episode</td><td>▁▂▂▂▃▄▇█████████████████████████████████</td></tr><tr><td>Testing_steps_per_episode</td><td>█████▇▆▅▄▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▂▁▂▂▂▁▂▁▁▂▂▁▁</td></tr><tr><td>Testing_success_rate_per_episode</td><td>▁▁▁▁▃▃▆█████████████████████████████████</td></tr><tr><td>Training_reward_per_episode</td><td>▁▁▂▂▃▃▄▆████████████████████████████████</td></tr><tr><td>Training_steps_per_episode</td><td>██████▇▆▅▄▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Training_success_rate_per_episode</td><td>▁▁▁▁▂▂▃▅████████████████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Episodes</td><td>5733</td></tr><tr><td>Testing_reward_per_episode</td><td>405.2</td></tr><tr><td>Testing_steps_per_episode</td><td>24.0</td></tr><tr><td>Testing_success_rate_per_episode</td><td>100.0</td></tr><tr><td>Training_reward_per_episode</td><td>408.0</td></tr><tr><td>Training_steps_per_episode</td><td>28.03</td></tr><tr><td>Training_success_rate_per_episode</td><td>100.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">run_3</strong> at: <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/un1j07cx' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_4agents/runs/un1j07cx</a><br/> View project at: <a href='https://wandb.ai/299011-unimore/gridworld_looseplay_4agents' target="_blank">https://wandb.ai/299011-unimore/gridworld_looseplay_4agents</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251227_122143-un1j07cx/logs</code>
# wandb version 0.23.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# FINISHED

# %% [markdown]
# ## **Save the agents model**

# %%
import os
def save_model(ppo, file_name):
    current_dir = os.getcwd()
    model_dir = os.path.join(current_dir, "models")
    checkpoint_name = os.path.join(model_dir, file_name)
    ppo.save(checkpoint_name)

    print(f"Model saved into {checkpoint_name}")

# %% [markdown]
# ## **Load agents**

# %%
from ray.rllib.algorithms.ppo import PPO
import os

def load_model(file_name):
    current_dir = os.getcwd()
    model_dir = os.path.join(current_dir, "models")
    checkpoint_name = os.path.join(model_dir, file_name)

    ppo = PPO.from_checkpoint(checkpoint_name)
    return ppo

# %%
import os

current_dir = os.getcwd()
model_dir = os.path.join(current_dir, "models")

for filename in os.listdir(model_dir):
    if "best" in filename and under_examination in filename:
        matching_file = filename
        break

file_path = os.path.join(model_dir, matching_file)
ppo = load_model(file_path)

# %% [markdown]
# ## **Graphically test the agent**

# %%
POLICY_ID = "shared_policy" 

env = MyGridWorld(grid_size=15, n_agents=4, render_mode="human")
obs, _ = env.reset()

i = 0
while i<3:
    actions = {}
    for agent_id, agent_obs in obs.items():
        actions[agent_id] = ppo.compute_single_action(
            agent_obs, 
            policy_id=POLICY_ID,
            explore=True
        )
    
    obs, rewards, terminations, truncations, infos = env.step(actions)

    if any(terminations.values()) or any(truncations.values()):
        obs, _ = env.reset()
        i+=1
env.close()
# Out:
# WARNING! Sprite image /home/terra/Desktop/unimore/distributed_project/sprites/.png not found. Using default sprite for this simulation.
# WARNING! Sprite image /home/terra/Desktop/unimore/distributed_project/sprites/.png not found. Using default sprite for this simulation.
# WARNING! Sprite image /home/terra/Desktop/unimore/distributed_project/sprites/.png not found. Using default sprite for this simulation.
# WARNING! Sprite image /home/terra/Desktop/unimore/distributed_project/sprites/.png not found. Using default sprite for this simulation.
# 2025-12-27 12:35:47,660	WARNING 3385272411.py:10 -- DeprecationWarning: `compute_single_action` has been deprecated. `Algorithm.compute_single_action` should no longer be used. Get the RLModule instance through `Algorithm.get_module([module ID])`, then compute actions through `RLModule.forward_inference({'obs': [obs batch]})`. This will raise an error in the future!
